# %%
cd ../../src
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
import os
from pandas import DataFrame, read_table, notnull, MultiIndex, datetime

# %%
firehose_path = '/cellar/data/TCGA/'
date = '20121024'
date_ = '_'.join([date[:4], date[4:6], date[6:8]])
stddata_path = firehose_path + 'stddata__' + date_
cancers = os.listdir(stddata_path)

# %%
clin_file = lambda c: '/'.join([stddata_path, c, date,'Clinical', c]) + '.clin.merged.txt'

# %%
clin = dict((c,read_table(clin_file(c), index_col=0)) for c in cancers
             if os.path.isfile(clin_file(c)))
common = set.intersection(*map(lambda v: set(v.index), clin.values()))

# %%
keeper_columns = ['bcrpatientbarcode', 'gender', 'daystoinitialpathologicdiagnosis',
                  'daystobirth', 'race', 'icdo3histology', 'vitalstatus', 
                  'patientid', 'tissuesourcesite','daystodeath',
                  'ageatinitialpathologicdiagnosis', 'daystolastfollowup',
                  'ethnicity']
keeper_columns = map(lambda s: 'patient.' + s, keeper_columns)

# %%
from pandas import Panel, DataFrame, Series
meta_data = {}

# %%
for c,br in clin.iteritems():
    meta = br.ix[keeper_columns]
    meta = DataFrame(meta.T.as_matrix(), columns=map(lambda s: s.split('.')[-1], 
                     meta.index), index=meta.ix['patient.bcrpatientbarcode'])
    #meta = meta.dropna(how='all', axis=[0,1])
    assert sum(meta['daystoinitialpathologicdiagnosis'] == 0) == 0
    meta_data[c] = meta

# %%
figsize(11,5)
num_dead = DataFrame(dict((c, meta.groupby('gender').count().ix[:,0]) for 
                  c,meta in meta_data.iteritems())).T
num_dead.plot(kind='bar', stacked=True)
ylabel('Number of Patients')

# %%
figsize(11,5)
num_dead = DataFrame(dict((c, meta.groupby('race').count().ix[:,0]) for 
                  c,meta in meta_data.iteritems())).T
num_dead.plot(kind='bar', stacked=True)
ylabel('Number of Patients')

# %%
figsize(11,5)
num_dead = DataFrame(dict((c, meta.groupby('vitalstatus').count().ix[:,0]) for 
                  c,meta in meta_data.iteritems())).T
num_dead.plot(kind='bar', stacked=True)
ylabel('Number of Patients')

# %% [markdown]
# #Format BRCA Clinical Data

# %%
cancer = 'THCA'
br = clin[cancer]

# %%
cols = [c for c, vals in br.iterrows() if (sum(notnull(vals)) > len(vals)*.5)
        and len(set(vals.dropna())) > 1 and ('admin' not in c) and (c not in common)
        and ('patient.drugs.drug' not in c) and ('patient.followups.followup' not in c)
        and ('patient.radiations' not in c)]

# %%
figsize(5,3)
for col in cols:
    br.ix[col].value_counts().plot(kind='bar', title=col)
    show()

# %%
c  = DataFrame(index=br.columns)
c['tumor_stage'] = br.ix['patient.ajcctumorstagecode'].map(lambda s: 
                                  s.replace('a','').replace('b','').replace('c',''),
                                  na_action='ignore')
c['hist_type'] = br.ix['patient.histologicaltype']
c['tumor_focality'] = br.ix['patient.clinicalcqcf.tumorfocality']
c['neo_depth'] = br.ix['patient.neoplasmdimension.neoplasmdepth']
c['neo_length'] = br.ix['patient.neoplasmdimension.neoplasmdepth']
c['neo_width'] = br.ix['patient.neoplasmdimension.neoplasmwidth']
c['neo_length'] = br.ix['patient.neoplasmdimension.neoplasmlength']
c['neo_area'] = (c[['neo_depth', 'neo_width', 'neo_length']].astype(float).product(1)**(1./3))
c['tumor_t1t2'] = c.tumor_stage.isin(['t1','t2'])
c = c.rename(index=br.ix['patient.bcrpatientbarcode'])

# %%
followup = br.select(lambda s: s.startswith('patient.followups.followup'))
mIdx = map(lambda s: ('.'.join(s.split('.')[:4]), '.'.join(s.split('.')[4:])), 
           followup.index)
mIdx = MultiIndex.from_tuples(mIdx)
followup = DataFrame(followup.as_matrix(), index=mIdx, columns=br.ix['patient.bcrpatientbarcode'])
keep = map(lambda s: type(s) == str, followup.columns)
followup = followup.ix[:,keep]
followup = followup.dropna(how='all', axis=[0,1])

# %%
patient_followup = {}
for patient, d in followup.iteritems():
    df = d.unstack().dropna(how='all', axis=[0,1])
    to_date = lambda s: datetime(int(s[0]), int(s[1]), int(s[2])) if notnull(s[0]) else nan
    #_date = df[['yearofformcompletion','monthofformcompletion', 'dayofformcompletion']]
    #_date = Series(_date.apply(to_date, 1), name='dateofformcompletion')
    #df = df.select(lambda s: 'formcompletion' not in s, 1).join(_date)
    patient_followup[patient] = df

# %%
counts = DataFrame()
for d,df in patient_followup.iteritems():
    s = Series(ones(len(df.columns)), index=df.columns, name=d)
    counts = counts.join(s, how='outer')
counts = counts.sum(1)
np.sort(counts)
# Out:
# daystodeath                                                      1
# i131subsequentadministereddose                                   1
# newtumor.radiationtherapyadministereddosetext                    1
# newtumor.radiosensitizingagentadministeredindicator              1
# newtumor.therapeuticprocedurenewneoplasmrequiredadditionaltherapytype     6
# newtumor.additionalradiationtherapy                              7
# newtumor.daystoadditionalsurgerymetastaticprocedure              7
# newtumor.histologicdiseaseprogressionpresentindicator            7
# newtumor.i131totaladministeredpreparationtechnique               7
# newtumor.radiationtherapyadministeredpreparationtechniquetext     7
# newtumor.thyroidglandcarcinomainvolvementregionallymphnodetype     7
# newtumor.additionalpharmaceuticaltherapy                         8
# newtumor.additionalsurgerylocoregionalprocedure                  8
# newtumor.newneoplasmconfirmeddiagnosismethodname                 9
# newtumor.newneoplasmeventoccurrenceanatomicsite                  9
# newtumor.newneoplasmeventtype                                    9
# newtumor.daystonewtumoreventafterinitialtreatment               10
# radiationtherapyadministeredpreparationtechniquetext            17
# i131totaladministereddose                                       19
# i131firstadministereddose                                       25
# i131totaladministeredpreparationtechnique                       26
# postsurgicalprocedureassessmentthyroidglandcarcinomastatus      32
# daystolastfollowup                                              34
# bcrfollowupbarcode                                              35
# bcrfollowupuuid                                                 35
# dayofformcompletion                                             35
# followupcasereportformsubmissionreason                          35
# monthofformcompletion                                           35
# newtumor.newtumoreventafterinitialtreatment                     35
# personneoplasmcancerstatus                                      35
# radiationtherapy                                                35
# targetedmoleculartherapy                                        35
# vitalstatus                                                     35
# yearofformcompletion                                            35

# %%
figsize(5,3)
df = DataFrame(dict((pat, vals.ix[-1]) for pat, vals in patient_followup.iteritems())).T
for test,vals in df.iteritems():
    if len(set(vals)) < 20:
        vals.value_counts().plot(kind='bar', title=test)
        plt.show()

# %%
followup_vars = DataFrame({
    'therapy' : df.targetedmoleculartherapy,
    'radiation' : df.radiationtherapy})

# %%
t = df[['daystonewtumoreventafterinitialtreatment']].astype(float)
time_to_event = t.min(1).dropna()
time_to_event.name = 'days_to_event'
event = Series(time_to_event > 0, name='new_tumor')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-2f075d1a6592> in <module>()
# ----> 1 t = df[['daystonewtumoreventafterinitialtreatment']].astype(float)
#       2 time_to_event = t.min(1).dropna()
#       3 time_to_event.name = 'days_to_event'
#       4 event = Series(time_to_event > 0, name='new_tumor')
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getitem__(self, key)
#    1772             if com._is_bool_indexer(key):
#    1773                 key = np.asarray(key, dtype=bool)
# -> 1774             return self._getitem_array(key)
#    1775         elif isinstance(self.columns, MultiIndex):
#    1776             return self._getitem_multilevel(key)
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in _getitem_array(self, key)
#    1797                 mask = indexer == -1
#    1798                 if mask.any():
# -> 1799                     raise KeyError("No column(s) named: %s" % str(key[mask]))
#    1800                 result = self.reindex(columns=key)
#    1801                 if result.columns.name is None:
#
# KeyError: 'No column(s) named: [daystonewtumoreventafterinitialtreatment]'

# %%
from Processing.Helpers import match_series
figsize(6,4)
d = timeline.daystodeath.dropna().astype(int)
scatter(*match_series(timeline.event_free_survival,d))
plot([0,4000],[0,4000]);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-1b147680f512> in <module>()
#       2 figsize(6,4)
#       3 d = timeline.daystodeath.dropna().astype(int)
# ----> 4 scatter(*match_series(timeline.event_free_survival,d))
#       5 plot([0,4000],[0,4000]);
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getattr__(self, name)
#    1849             return self[name]
#    1850         raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1851                              (type(self).__name__, name))
#    1852
#    1853     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'event_free_survival'

# %%
meta = meta_data[cancer]
timeline = meta[['daystodeath', 'daystolastfollowup']]
#timeline = timeline.join(time_to_event).astype(float)
event_free_survival = Series(timeline.min(1), name='event_free_survival')
timeline = timeline.join(event_free_survival).join(meta.daystobirth)

# %%
timeline = timeline.astype(float)

# %%
cl = c.join(timeline)
cl = cl.join(meta[['vitalstatus','gender','tissuesourcesite']])

cl['age']  = cl['daystobirth'].astype(float) / -365.
cl['days'] = cl[['daystolastfollowup','daystodeath']].astype(float).max(1)
cl['deceased'] = (cl.vitalstatus.dropna() == 'deceased').astype(int)
#cl['new_tumor'] = (cl['new_tumor'].dropna() == 'yes').astype(int)
#cl['event'] = (cl['deceased'] + cl['new_tumor']).clip_upper(1)

#cl['event'] = cl.event.fillna(0)

# %%
cl = cl.rename(index=str.upper)
out_path = '/'.join([stddata_path, cancer, date,'Clinical']) + '/' + 'compiled.csv'
cl.to_csv(out_path)

# %%
cl
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 218 entries, TCGA-BJ-A0YZ to TCGA-J8-A3O2
# Data columns:
# tumor_stage            218  non-null values
# hist_type              218  non-null values
# tumor_focality         216  non-null values
# neo_depth              167  non-null values
# neo_length             204  non-null values
# neo_width              179  non-null values
# neo_area               211  non-null values
# tumor_t1t2             218  non-null values
# daystodeath            1  non-null values
# daystolastfollowup     217  non-null values
# event_free_survival    0  non-null values
# daystobirth            218  non-null values
# vitalstatus            218  non-null values
# gender                 218  non-null values
# tissuesourcesite       218  non-null values
# age                    218  non-null values
# days                   218  non-null values
# deceased               218  non-null values
# dtypes: bool(1), float64(7), int64(1), object(9)
