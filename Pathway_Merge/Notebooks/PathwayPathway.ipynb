# %%
cd ../src/
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
import pandas as pandas
from Data.Pathways import read_in_pathways
from Processing.Clinical import ClinicalObject

pandas.set_printoptions(max_columns=300)

# %%
firehose_path = '/cellar/users/agross/Data/TCGA/'
date = '20120825'
date_ = '_'.join([date[:4], date[4:6], date[6:8]])
pathway_file = '/cellar/users/agross/Data/GeneSets/c2.cp.v3.0.symbols_edit.csv'
gene_sets, gene_lookup = read_in_pathways(pathway_file)

# %%
def get_cancer(cancer, data_type):
    try:
        data_path = firehose_path + 'analyses__' + date_ + '/' + cancer + '/' + date + '/'
        cancer_obj = ClinicalObject(cancer, data_path, gene_sets, data_type)
        #cancer_obj.filter_bad_pathways(gene_lookup)
        return (data_type, cancer_obj)
    except:
        return (data_type, data_type + ' is broken.')

# %%
cancer = 'LAML'
data_types = ['mutation','expression']

# %%
r = [get_cancer(cancer, data_type) for data_type in data_types]
clinical = dict(((k,v) for k,v in r if type(v) != str and len(v.q_pathways) > 0))

# %%
exp = clinical['expression']
mut = clinical['mutation']
mut.filter_bad_pathways(gene_lookup)

# %%
good_pathways = exp.q_pathways.survival[exp.q_pathways.survival < .2]
np.sort(good_pathways)
# Out:
# BIOCARTA_FEEDER_PATHWAY                                         0.070787
# REACTOME_CHOLESTEROL_BIOSYNTHESIS                               0.083388
# REACTOME_UNFOLDED_PROTEIN_RESPONSE                              0.151452
# BIOCARTA_LAIR_PATHWAY                                           0.158464
# REACTOME_TRANSFORMATION_OF_LANOSTEROL_TO_CHOLESTEROL            0.158464
# BIOCARTA_BARRESTIN_PATHWAY                                      0.181670
# BIOCARTA_CELL2CELL_PATHWAY                                      0.181670
# BIOCARTA_DNAFRAGMENT_PATHWAY                                    0.181670
# BIOCARTA_FIBRINOLYSIS_PATHWAY                                   0.181670
# BIOCARTA_GRANULOCYTES_PATHWAY                                   0.181670
# BIOCARTA_IL1R_PATHWAY                                           0.181670
# BIOCARTA_KREB_PATHWAY                                           0.181670
# BIOCARTA_MONOCYTE_PATHWAY                                       0.181670
# BIOCARTA_NFKB_PATHWAY                                           0.181670
# BIOCARTA_NKCELLS_PATHWAY                                        0.181670
# BIOCARTA_P35ALZHEIMERS_PATHWAY                                  0.181670
# BIOCARTA_PLATELETAPP_PATHWAY                                    0.181670
# BIOCARTA_PTDINS_PATHWAY                                         0.181670
# BIOCARTA_UCALPAIN_PATHWAY                                       0.181670
# KEGG_RETINOL_METABOLISM                                         0.181670
# KEGG_STEROID_BIOSYNTHESIS                                       0.181670
# REACTOME_CDT1_ASSOCIATION_WITH_THE_CDC6_ORC_ORIGIN_COMPLEX      0.181670
# REACTOME_CITRIC_ACID_CYCLE                                      0.181670
# REACTOME_CYTOCHROME_P450_ARRANGED_BY_SUBSTRATE_TYPE             0.181670
# REACTOME_ERKS_ARE_INACTIVATED                                   0.181670
# REACTOME_FURTHER_PLATELET_RELEASATE                             0.181670
# REACTOME_MICRORNA_BIOGENESIS                                    0.181670
# REACTOME_M_G1_TRANSITION                                        0.181670
# REACTOME_ORC1_REMOVAL_FROM_CHROMATIN                            0.181670
# REACTOME_P53_INDEPENDENT_DNA_DAMAGE_RESPONSE                    0.181670
# REACTOME_PECAM1_INTERACTIONS                                    0.181670
# REACTOME_POST_CHAPERONIN_TUBULIN_FOLDING_PATHWAY                0.181670
# REACTOME_REGULATION_OF_ORNITHINE_DECARBOXYLASE                  0.181670
# REACTOME_RNA_POLYMERASE_III_CHAIN_ELONGATION                    0.181670
# REACTOME_RNA_POLYMERASE_III_TRANSCRIPTION_TERMINATION           0.181670
# REACTOME_SIGNALING_BY_TGF_BETA                                  0.181670
# REACTOME_SIGNALING_BY_VEGF                                      0.181670
# REACTOME_STABILIZATION_OF_P53                                   0.181670
# REACTOME_TRAFFICKING_OF_GLUR2_CONTAINING_AMPA_RECEPTORS         0.181670
# REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3G                   0.181670
# REACTOME_VIRAL_DSRNA_TLR3_TRIF_COMPLEX_ACTIVATES_RIP1           0.181670
# REACTOME_VIRAL_MESSENGER_RNA_SYNTHESIS                          0.181670
# REACTOME_XENOBIOTICS                                            0.181670
# REACTOME_ACTIVATION_OF_CHAPERONES_BY_IRE1_ALPHA                 0.181902
# REACTOME_REMOVAL_OF_THE_FLAP_INTERMEDIATE_FROM_THE_C_STRAND     0.181902
# REACTOME_RNA_POLYMERASE_III_TRANSCRIPTION_INITIATION_FROM_TYPE_3_PROMOTER    0.181902
# REACTOME_SEMA3A_PLEXIN_REPULSION_SIGNALING_BY_INHIBITING_INTEGRIN_ADHESION    0.181902
# REACTOME_AUTODEGRADATION_OF_CDH1_BY_CDH1_APC                    0.187831
# REACTOME_CELLEXTRACELLULAR_MATRIX_INTERACTIONS                  0.187831
# KEGG_LINOLEIC_ACID_METABOLISM                                   0.190811
# KEGG_PROTEASOME                                                 0.190811
# REACTOME_INTEGRIN_ALPHAIIBBETA3_SIGNALING                       0.190811
# REACTOME_PLATELET_AGGREGATION_PLUG_FORMATION                    0.190811
# REACTOME_SIGNALING_BY_WNT                                       0.190811
# BIOCARTA_RHO_PATHWAY                                            0.196898
# Name: survival, Length: 55

# %%
from Libraries.HClust import heatmap, YellowBlackBlue

# %%
c = exp.pc.ix[good_pathways.index]
row_method = 'complete'
column_method = 'complete'
row_metric = 'euclidean'
column_metric = 'euclidean'
color_gradient = 'red_black_green'

# %%
heatmap(c.as_matrix(), c.index, c.columns, row_method,
            column_method, row_metric, column_metric,
            YellowBlackBlue())
# Out:
# Performing hiearchical clustering using euclidean for columns and euclidean for rows
# Column clustering completed in 0.4 seconds
# Row clustering completed in 0.1 seconds

# %%
exp_path = exp.q_pathways[exp.q_pathways.survival < .1].index
mut_path = mut.q_pathways[mut.q_pathways.survival < 1].index
len(exp_path), len(mut_path)
# Out:
# (2, 396)

# %%
exp_df = exp.pc.ix[exp_path]
mut_df = mut.meta_matrix.ix[mut_path]

# %%
from scipy.stats import f_oneway
def anova(hit_vec, response_vec):
    hit_vec = hit_vec.reindex_like(response_vec)
    return f_oneway(*[response_vec[hit_vec == num].dropna() 
                      for num in set(hit_vec.dropna())])[1]

# %%
df =  pandas.DataFrame(dict((m,dict((p, anova(mut_vec, exp_vec)) for p,exp_vec in exp_df.iterrows()))
                       for m, mut_vec in mut_df.iterrows()))

# %%
from Processing.Helpers import match_series
def split_a_by_b(a,b):
    a, b = match_series(a, b)
    groups = [a[b==num] for num in set(b)]
    return groups

# %%
from Reports.Figures import histo_compare

# %%
histo_compare(mut.meta_matrix.ix['BIOCARTA_ATRBRCA_PATHWAY'],
              exp.pc.ix['BIOCARTA_FEEDER_PATHWAY'])

# %%
np.sort(df.ix['BIOCARTA_FEEDER_PATHWAY']).head()
# Out:
# REACTOME_DNA_REPLICATION_PRE_INITIATION    0.000250
# SIG_PIP3_SIGNALING_IN_B_LYMPHOCYTES        0.001435
# REACTOME_G1_S_TRANSITION                   0.001936
# BIOCARTA_BAD_PATHWAY                       0.002911
# KEGG_CELL_CYCLE                            0.003270
# Name: BIOCARTA_FEEDER_PATHWAY
