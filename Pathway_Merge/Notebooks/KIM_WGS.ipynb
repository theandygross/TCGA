# %%
cd ../src
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
import os as os
import pickle as pickle
import subprocess
import pandas as pd

from Processing.Tests import run_feature_matrix, SurvivalTest

# %%
def fancy_raster(df, cluster=False, cmap=cm.get_cmap('Spectral'), norm=None, ax=None):
    if cluster:
        d = dist.pdist(df)
        D = dist.squareform(d)
        Y = sch.linkage(D)
        Z = sch.dendrogram(Y, no_plot=True)
        order = Z['leaves']
        df = df.ix[order, order]
    
    if ax is None:
        fig, ax = plt.subplots(1,1, figsize=(12,8))
    img = ax.imshow(df, interpolation='Nearest', cmap=cmap, norm=norm)
    ax.set_yticks(range(len(df.index)))
    ax.set_yticklabels(df.index)
    ax.set_xticks(arange(len(df.columns)))
    ax.set_xticklabels(df.columns, rotation=360-90, ha='center');
    ax.hlines(arange(len(df.index)-1)+.5, -.5, len(df.columns)-.5, 
              color='white', lw=6)
    ax.vlines(arange(len(df.columns)-1)+.5, -.5, len(df.index)-.5, 
              color='white', lw=6)
    
    if cluster:
        icoord = array(Z['icoord']) - array(Z['icoord']).min()
        icoord = icoord * ((len(Z['leaves']) - 1) / icoord.max())
    
        dcoord = -1*array(Z['dcoord']) - .7 
        for i,z,c in zip(icoord, dcoord, Z['color_list']):
            ax.plot(i,z,color=c, lw=2, alpha=.8)
            
        ax.tick_params(axis='x', top='off')
        ax.set_frame_on(False)
    return img

# %%
mut_orig = pd.read_csv('/cellar/users/agross/mutations_2.csv')
genes = mut_orig.gene.unique()
genes = [s for g in map(lambda s: s.split(','), genes) for s in g]

# %%
result_path = '/scratch/TCGA/Firehose__2012_01_16/ucsd_analyses'
run = sorted(os.listdir(result_path))[0]
run = pickle.load(open('/'.join([result_path, run, 'RunObject.p']), 'rb'))

# %%
from Reports.Figures import fancy_raster

# %%
s = pd.concat([pd.Series(ones(len(run.gene_lookup[g])), run.gene_lookup[g]) for g in genes if g in run.gene_lookup], keys=[g for g in genes if g in run.gene_lookup])
g = s.groupby(level=1).size().order()
s = s.unstack()

# %%
s = pd.concat([pd.Series(ones(len(run.gene_lookup[g])), run.gene_lookup[g]) for g in genes if g in run.gene_lookup], keys=[g for g in genes if g in run.gene_lookup])
g = s.groupby(level=1).size().order()
s = s.unstack()
#s = s.unstack().select(lambda s: s.startswith('REACTOME'), axis=1)
s = s[s.sum(1) > 0]
s = s[sorted(s.columns, key=lambda s: len(run.gene_sets[s]), reverse=True)]
s = s.T.drop_duplicates().T
#s = s.rename(columns=lambda c: ' '.join(c.split('_')[1:]))

# %%
pathways = '\n'.join([g + '\t' + '\t'.join(run.gene_sets[g]) for g in s.columns])

# %%
f = open('/cellar/users/agross/pathways.tab', 'wb')
f.write(pathways)
f.close()

# %%
s=s.ix[sorted(s.index, key=lambda r: (sum(s.ix[r]), (s.ix[r].fillna(0).argmax())), reverse=True)]
s=s.ix[:,sorted(s.columns, key=lambda r: (sum(s[r]), (-s[r].fillna(0).argmax())), reverse=True)]

fig, ax = subplots(figsize=(10,8))
fancy_raster(s.T, ax=ax)
ax.grid(alpha=.5)
#fig.savefig('/cellar/users/agross/pathways_hit.png')

# %%
cancer = run.load_cancer('BRCA')
clinical = cancer.load_clinical()
global_vars = cancer.load_global_vars()

# %%
her2 = clinical.clinical.her2 == 'positive'
pr = clinical.clinical.PR == 'positive'
er = clinical.clinical.ER == 'negative'

# %%
pat = er[(er * pr * her2) == True].index

# %%
mut = cancer.load_data('MAF')
mut.uncompress()

# %%
pat
# Out:
# Index([TCGA-C8-A1HF, TCGA-E9-A1N9, TCGA-E9-A1NC], dtype=object)

# %%
pat = mut.df.ix[:,pat].ix[:,0]
set(pat[pat > 0].index).intersection(set(genes))
# Out:
# set([])

# %%
figsize(9,5)
mut.df.ix[genes].dropna().sum(1).order().tail(20).plot(kind='bar')

# %%
her2_counts = mut.df.ix[genes,her2[her2].index].dropna(how='all')

# %%
her2_counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140 entries, ABHD12 to KIRREL2
# Columns: 149 entries, TCGA-A1-A0SM to TCGA-GM-A2DA
# dtypes: float64(149)

# %%
her2_counts.sum(1)[her2_counts.sum(1) > 0].order().tail(10).plot(kind='bar')

# %%
clinical.clinical.ix[['TCGA-BH-A18P','TCGA-A8-A06X']].T
# Out:
#                  TCGA-BH-A18P TCGA-A8-A06X
# PR                   negative     negative
# her2_chem            positive     positive
# neo_status         with tumor          NaN
# her2_fish            positive          NaN
# ER                   positive     positive
# her2                 positive     positive
# triple_neg              False        False
# vitalstatus          deceased     deceased
# gender                 female       female
# tissuesourcesite           bh           a8
# age                  60.88219     77.63562
# race                    white          NaN
# deceased                    1            1

# %%
cesc = run.load_cancer('CESC')

# %%
c = cesc.load_clinical()
maf = cesc.load_data('MAF')
maf.uncompress()

# %%
counts = (maf.df.ix[genes] > 0).sum()
pd.concat([counts, maf.df.sum(), counts / maf.df.sum()], axis=1).sort(columns=2).tail(10)
# Out:
#               0    1         2
# TCGA-C5-A1MF  2   87  0.022989
# TCGA-C5-A1MN  3  128  0.023438
# TCGA-C5-A1M9  1   39  0.025641
# TCGA-C5-A1BE  2   76  0.026316
# TCGA-C5-A1M5  2   66  0.030303
# TCGA-DR-A0ZL  2   61  0.032787
# TCGA-C5-A1ML  3   66  0.045455
# TCGA-C5-A1MI  3   51  0.058824
# TCGA-C5-A1M7  6  101  0.059406
# TCGA-C5-A1MQ  3   38  0.078947

# %%
maf.df.ix[genes].groupby(level=0).size().order().tail(10).plot(kind='bar')

# %%
lengths = pd.read_csv('/cellar/users/agross/Data/GeneSets/coding_lengths.csv', squeeze=True, index_col=0)

# %%
c = maf.df.groupby(level=0).count().order()
pd.concat([c,lengths], axis=1).dropna().sort(columns=0).tail(20)
# Out:
#          0       1
# TNIK     4    5806
# DNAH2    4   13505
# FAT4     4   16110
# SMG1     5   16065
# CELSR2   5   10540
# SRCAP    5   10474
# NFE2L2   5    2855
# UBR4     5   15882
# BRWD1    5   17886
# PTPN13   5    8577
# MYH9     5    7505
# APOB     5   14121
# KIF16B   5    5262
# MLL2     6   19419
# MUC17    6   14350
# RYR2     7   16365
# MLL3     8   16862
# MUC16    8   43816
# PIK3CA   9    3709
# TTN     18  109223

# %%
run.data_path
# Out:
# '/scratch/TCGA/Firehose__2012_01_16/'

# %%
maf = pd.read_table(run.data_path + '/'.join(['analyses', 'CESC', 'MutSigNozzleReport2',  'CESC' + '-TP.final_analysis_set.maf']))

# %%
mll = maf[maf.Hugo_Symbol == 'FLG']

# %%
mll.ix[:,:9]
# Out:
#      Hugo_Symbol  Entrez_Gene_Id         Center  NCBI_Build Chromosome  \
# 1977         FLG            2312  broad.mit.edu          37          1
# 1978         FLG            2312  broad.mit.edu          37          1
# 2510         FLG            2312  broad.mit.edu          37          1
# 2511         FLG            2312  broad.mit.edu          37          1
# 3137         FLG            2312  broad.mit.edu          37          1
# 5908         FLG            2312  broad.mit.edu          37          1
# 5909         FLG            2312  broad.mit.edu          37          1
#
#       Start_position  End_position Strand Variant_Classification
# 1977       152276558     152276558      +      Missense_Mutation
# 1978       152286055     152286055      +      Nonsense_Mutation
# 2510       152281453     152281453      +      Missense_Mutation
# 2511       152282510     152282510      +      Missense_Mutation
# 3137       152284693     152284693      +      Missense_Mutation
# 5908       152281070     152281070      +      Missense_Mutation
# 5909       152281894     152281894      +      Missense_Mutation

# %%
(mll.Start_position - 152278433).order()
# Out:
# 1977   -1875
# 5908    2637
# 2510    3020
# 5909    3461
# 2511    4077
# 3137    6260
# 1978    7622
# Name: Start_position

# %%
mut_orig[mut_orig.gene == 'FLG'].T.dropna()[:10]
# Out:
#                           43
# Index                  52426
# source              Illumina
# gene                     FLG
# chrom                      1
# start              152278433
# end                152278434
# type                     snv
# ref                        T
# alt                        G
# variant_function  exonic=FLG

# %%
cancer = run.load_cancer('BRCA')

# %%
rna = cancer.load_data('mRNASeq')
maf = cancer.load_data('MAF')
maf.uncompress()

# %%
from Reports.Figures import *

# %%
# Out:
#                                                                                                   43
# Index                                                                                          52426
# source                                                                                      Illumina
# gene                                                                                             FLG
# chrom                                                                                              1
# start                                                                                      152278433
# end                                                                                        152278434
# type                                                                                             snv
# ref                                                                                                T
# alt                                                                                                G
# variant_function                                                                          exonic=FLG
# exonic_function                                    nonsynonymous_SNV=FLG:NM_002016:exon3:c.A8928C...
# tfbs
# snp135                                                                                    rs61816760
# dgv                                                              Name=74713,104995,64943,37082,84573
# segdup                                                            Score=0.929016;Name=chr1:152280691
# ljb_all                                                                                     0.164048
# Unnamed: 22
# VEST                                                                                          0.1690
# p-value                                                                                       0.6265
# FDR                                                                                                1
# CHASM                                                                                         0.6940
# p-value.1                                                                                     0.3584
# FDR.1                                                                                            0.9
# GeneCards summary (from http://www.genecards.org)  The protein encoded by this gene is an interme...
# Number of retrieved articles from PubMed                                                          58
# PubMed search term                                 http://www.ncbi.nlm.nih.gov/pubmed?term=FLG[TI...
# dbSNP                                                                                     rs61816760
# 1000 Genomes allele frequency                                                                      0
# ESP6500 allele frequency (European American)                                                       0
# ESP6500 allele frequency (African American)                                                        0

# %%
maf = pd.read_table(run.data_path + '/'.join(['analyses', 'BRCA', 'MutSigNozzleReport2',  'BRCA' + '-TP.final_analysis_set.maf']))

# %%
cdh1 = maf[maf.gene == 'CDH1'].ix[:,:9]
cdh1
# Out:
#       Hugo_Symbol  Entrez_Gene_Id            Center  NCBI_Build Chromosome  \
# 46           CDH1             999  genome.wustl.edu          37         16
# 2317         CDH1             999  genome.wustl.edu          37         16
# 2331         CDH1             999  genome.wustl.edu          37         16
# 2769         CDH1             999  genome.wustl.edu          37         16
# 3196         CDH1             999  genome.wustl.edu          37         16
# 3238         CDH1             999  genome.wustl.edu          37         16
# 3352         CDH1             999  genome.wustl.edu          37         16
# 3719         CDH1             999  genome.wustl.edu          37         16
# 5771         CDH1             999  genome.wustl.edu          37         16
# 7699         CDH1             999  genome.wustl.edu          37         16
# 9327         CDH1             999  genome.wustl.edu          37         16
# 9362         CDH1             999  genome.wustl.edu          37         16
# 9441         CDH1             999  genome.wustl.edu          37         16
# 9528         CDH1             999  genome.wustl.edu          37         16
# 9559         CDH1             999  genome.wustl.edu          37         16
# 9596         CDH1             999  genome.wustl.edu          37         16
# 9671         CDH1             999  genome.wustl.edu          37         16
# 9719         CDH1             999  genome.wustl.edu          37         16
# 9811         CDH1             999  genome.wustl.edu          37         16
# 13156        CDH1             999  genome.wustl.edu          37         16
# 13190        CDH1             999  genome.wustl.edu          37         16
# 13622        CDH1             999  genome.wustl.edu          37         16
# 15962        CDH1             999  genome.wustl.edu          37         16
# 16956        CDH1             999  genome.wustl.edu          37         16
# 17383        CDH1             999  genome.wustl.edu          37         16
# 17920        CDH1             999  genome.wustl.edu          37         16
# 19413        CDH1             999  genome.wustl.edu          37         16
# 20360        CDH1             999  genome.wustl.edu          37         16
# 21418        CDH1             999  genome.wustl.edu          37         16
# 22399        CDH1             999  genome.wustl.edu          37         16
# 23206        CDH1             999  genome.wustl.edu          37         16
# 23577        CDH1             999  genome.wustl.edu          37         16
# 27135        CDH1             999  genome.wustl.edu          37         16
# 27806        CDH1             999  genome.wustl.edu          37         16
#
#        Start_position  End_position Strand Variant_Classification
# 46           68844139      68844139      +      Missense_Mutation
# 2317         68844098      68844098      +            Splice_Site
# 2331         68849628      68849628      +      Nonsense_Mutation
# 2769         68772203      68772204      +        Frame_Shift_Ins
# 3196         68862179      68862180      +        Frame_Shift_Ins
# 3238         68867233      68867234      +        Frame_Shift_Ins
# 3352         68846043      68846043      +        Frame_Shift_Del
# 3719         68835596      68835596      +      Nonsense_Mutation
# 5771         68857331      68857337      +        Frame_Shift_Del
# 7699         68844139      68844139      +      Missense_Mutation
# 9327         68842438      68842439      +           In_Frame_Ins
# 9362         68856129      68856129      +            Splice_Site
# 9441         68845625      68845625      +        Frame_Shift_Del
# 9528         68842427      68842444      +           In_Frame_Del
# 9559         68862203      68862204      +        Frame_Shift_Ins
# 9596         68844139      68844139      +      Missense_Mutation
# 9671         68849604      68849604      +      Nonsense_Mutation
# 9719         68847278      68847279      +        Frame_Shift_Ins
# 9811         68835596      68835596      +      Nonsense_Mutation
# 13156        68857485      68857485      +        Frame_Shift_Del
# 13190        68849648      68849648      +        Frame_Shift_Del
# 13622        68846121      68846127      +        Frame_Shift_Del
# 15962        68849608      68849608      +        Frame_Shift_Del
# 16956        68845601      68845615      +           In_Frame_Del
# 17383        68844104      68844105      +        Frame_Shift_Del
# 17920        68772218      68772218      +      Nonsense_Mutation
# 19413        68844191      68844191      +      Missense_Mutation
# 20360        68842414      68842414      +        Frame_Shift_Del
# 21418        68862178      68862179      +        Frame_Shift_Ins
# 22399        68844099      68844099      +            Splice_Site
# 23206        68855935      68855936      +        Frame_Shift_Ins
# 23577        68772257      68772257      +        Frame_Shift_Del
# 27135        68845762      68845762      +                 Silent
# 27806        68845685      68845686      +        Frame_Shift_Ins

# %%
mut[mut.gene == 'CDH1'].T.dropna()
# Out:
#                                                                                                  408
# Index                                                                                          25476
# source                                                                         Illumina, StrelkaPass
# gene                                                                                            CDH1
# chrom                                                                                             16
# start                                                                                       68853208
# end                                                                                         68853209
# type                                                                                             snv
# ref                                                                                                A
# alt                                                                                                G
# variant_function                                                                         exonic=CDH1
# exonic_function                                    nonsynonymous_SNV=CDH1:NM_004360:exon11:c.A159...
# tfbs
# dgv                                                                                       Name=77388
# ljb_all                                                                                     0.823815
# Unnamed: 22
# VEST                                                                                          0.0860
# p-value                                                                                       0.8591
# FDR                                                                                                1
# CHASM                                                                                         0.7680
# p-value.1                                                                                     0.5722
# FDR.1                                                                                            0.9
# GeneCards summary (from http://www.genecards.org)  This gene is a classical cadherin from the cad...
# Number of retrieved articles from PubMed                                                         620
# PubMed search term                                 http://www.ncbi.nlm.nih.gov/pubmed?term=CDH1[T...
# dbSNP
# 1000 Genomes allele frequency                                                                      0
# ESP6500 allele frequency (European American)                                                       0
# ESP6500 allele frequency (African American)                                                        0
