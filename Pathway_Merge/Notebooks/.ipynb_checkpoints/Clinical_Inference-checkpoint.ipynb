# %% [markdown]
# #Predicting Clinical Variables

# %%
cd ../src
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from Processing.Imports import *
from Figures.Survival import survival_stat_plot
from Stats.Survival import log_rank
from Figures.Survival import survival_and_stats

# %%
run = get_run('/cellar/data/TCGA/Firehose__2013_04_21/', 'Run_all')

cancer = run.load_cancer('HNSC')
clinical = cancer.load_clinical()
global_vars = cancer.load_global_vars()

mut = cancer.load_data('Mutation')
mut.uncompress()
meth = cancer.load_data('Methylation')
cn = cancer.load_data('CN_broad')
cn.uncompress()
rna = cancer.load_data('mRNASeq')
rppa  = cancer.load_data('RPPA')
mirna = cancer.load_data('miRNASeq')
age = clinical.clinical.age.astype(float)

hpv_all = pd.read_csv('/cellar/users/agross/hpv_summary_3_20_13_distribute.csv', index_col=0)
hpv = hpv_all.Molecular_HPV.map({0:'HPV-', 1:'HPV+'})
hpv.name = 'HPV'

# %%
from Data.ProcessClinical import format_survival_from_data_portal
path  = '/cellar/users/agross/Data/TCGA/HNSC_Followup/'
survival, timeline = format_survival_from_data_portal(path, cancer.name)
clinical.survival = survival
clinical.artificially_censor(5)
age = timeline.age

# %%
clin = pd.read_table(path + 'clinical_patient_hnsc.txt', index_col=0, na_values=['[Not Available]','[Not Evaluated]'])
status = clin[['hpv_status_by_ish_testing','hpv_status_by_p16_testing']]
hpv_clin = (status.dropna(how='all') == 'Positive').sum(1) > 0
hpv = hpv.ix[true_index(hpv_clin).union(hpv.index)].fillna('HPV+')

neg = (status.dropna(how='all') != 'Positive').sum(1) == 2
neg = true_index(combine(neg, hpv.ix[neg.index].isnull()) == 'both')
for i in neg:
    hpv = hpv.set_value(i, 'HPV-')

# %%
surv = clinical.survival.survival_5y

# %%
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import auc_score
from sklearn.svm import SVC

def SVC_fill(feature, df):
    gg = df.apply(lambda s: to_quants(s, std=1) > 0)
    diff = screen_feature(feature, fisher_exact_test, gg)
    dd = diff[diff.p < .05]
    
    pats = gg.columns.intersection(feature.index)
    mat = gg.ix[dd.index]
    X = mat.ix[:, pats].T.as_matrix()
    Y = (feature)
    Y = np.array(Y.ix[pats])
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, test_size=0.35, random_state=5796543)
    
    tuned_parameters = [{'kernel': ['rbf'], 'gamma': [0, .1, .05, .01, 1e-3, 1e-4, 1e-5],
                         'C': [.1, 1, 10, 100, 1000], 'class_weight': ['auto']},
                        {'kernel': ['linear'], 'C': [1, 10, 100, 1000], 'class_weight': ['auto']},
                        {'kernel': ['poly'],  'C': [1, 10, 100, 1000], 'class_weight': ['auto']}]
    
    clf = GridSearchCV(SVC(C=1), tuned_parameters, score_func=auc_score)
    clf.fit(X_train, y_train, cv=5);
    best = clf.best_estimator_
    auc = clf.score(X, Y)
    
    mat_all = gg.ix[mat.index].T.as_matrix()
    inferred = best.predict(mat_all)
    inferred = pd.Series(inferred, index=gg.columns)
    fun = pd.Series(best.decision_function(mat_all)[:,0], mat.columns)
    f = feature.copy()
    f = f.ix[inferred.index]
    f[f.isnull()] = inferred[f.isnull()]
    filled_feature = f.astype(float)
    return {'auc': auc, 'model': best, 'decision_function': fun,
            'inferred_values': inferred, 'filled_feature': filled_feature}

# %% [markdown]
# ##HPV

# %%
ret = SVC_fill(hpv=='HPV+', rna.features.ix['real'])
ret['auc']
# Out:
# 0.98615916955017302

# %%
fun = ret['decision_function']
violin_plot_pandas(hpv, fun)

# %% [markdown]
# * It looks like we have one patient mis-classified
# * They have 40 reads mapping to HPV33, and high expression of p16
# * WGS is pending, will probably find more reads

# %%
true_index(combine(hpv.dropna()=='HPV+', ret['decision_function'] < 0) == 'both')
# Out:
# Index([u'TCGA-BA-4077', u'TCGA-CV-6961', u'TCGA-HD-7832'], dtype=object)

# %%
true_index(combine(hpv.dropna()=='HPV-', ret['decision_function'] > 0) == 'both')
# Out:
# Index([u'TCGA-CR-6467'], dtype=object)

# %%
hpv_all.ix[['TCGA-CR-6467', 'TCGA-BA-4077', u'TCGA-CV-6961', u'TCGA-HD-7832']].dropna(how='all', axis=1).T
# Out:
#                                   TCGA-CR-6467    TCGA-BA-4077 TCGA-CV-6961    TCGA-HD-7832
# Tumor_Site                              Tonsil  Base of Tongue  Oral Tongue  Floor of Mouth
# Clinical_HPVSite_Indicator                   1               1            0               0
# Clinical_HPV_Interpretation            Missing        positive     negative        negative
# Molecular_HPV                                0               1            1               1
# Clinical_Staining                      Missing               1            1         Missing
# p16_OUTSIDE_BCR_Update                     NaN               1            1             NaN
# Harvard_HPV.LowPass.Done                   NaN               1          NaN             NaN
# LowPassHarvard.Strain                      NaN           hpv16          NaN             NaN
# LowPassHarvard.Call                        NaN        definite          NaN             NaN
# WGS_Broad                                  NaN               1            1             NaN
# WGS_Baylor                          1, pending             NaN          NaN             NaN
# WGS_HPV16                                  NaN        1.69e+04     8.81e+03             NaN
# WGS_HPV33                                  NaN               0            0             NaN
# Broad.Exome                                  1               1            1               0
# Broad.Exome.HPV16                            0              26           13               0
# Broad.Exome.HPV33                           40               0            0               0
# Broad.Exome.HPV35                            0               0            0               0
# RNA_type_16                                  0           11271        14467               0
# RNA_type_18                                  0               0            0               0
# RNA_type_2                                   0               0            0               0
# RNA_type_33                                  0               0            0           15781
# RNA_type_35                                  0               0            0               0
# maxSequencingSource          Broad.Exome.HPV33       WGS_HPV16  RNA_type_16     RNA_type_33
# maxSequencingCount                          40           16880        14467           15781

# %%
hpv_inferred = ret['filled_feature']
hpv_inferred = (hpv_inferred == 1).combine_first(hpv=='HPV+')

# %%
get_surv_fit_lr(surv, hpv_inferred)
# Out:
#            Stats          Median Survival             5y Survival               Log-Rank
#       # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2        p
#                                                                                      9.8  0.00175
# False        270      111             2.7   1.9  4.58       0.403  0.325  0.498
# True          46        8            4.82  4.79   NaN       0.494  0.265  0.921

# %%
survival_and_stats(hpv_inferred, surv)

# %% [markdown]
# ##Get rid of HPV for expression correlations

# %%
filters = pd.concat([age>=100, hpv_inferred], axis=1)
clinical_filter = filters.sum(1) == 0
keepers_o = true_index(clinical_filter)

# %%
stage = clinical.clinical.tumorstage.ix[keepers_o].fillna('nx')
stage = stage.dropna().map(lambda s: s.replace('a','').replace('b',''))

lymph_stage = clinical.clinical.lymphnodepathologicspread.ix[keepers_o]
lymph_stage = lymph_stage.replace('nx', nan).dropna().map(lambda s: s[:2])

age = age
old_age = (age >= 75).map({True: 'Age > 75', False: 'Age < 75'})
pack_years = py = clinical.clinical.numberpackyearssmoked.dropna().astype(float)

group = [['oral tongue','oral cavity','floor of mouth','buccal mucosa','alveolar ridge','hard palate','lip'],
         ['oropharynx','tonsil','base of tongue'],
         #['hypopharynx'],
         ['larynx']]
groups = ['oral cavity','oropharynx','larynx']
tumor_subdivision = pd.Series({idx: groups[i] for i,g in enumerate(group) for idx,j in 
                               clinical.clinical.neoplasmanatomicsubdivision.iteritems() if j in g})

invasion = clinical.clinical.perineuralinvasionpresent.replace('nan', nan)
invasion = invasion.fillna('Missing')

spread = clinical.clinical.presenceofpathologicalnodalextracapsularspread
spread = spread.map({'no extranodal extension': 'no', 'microscopic extension':'yes', 
                     'gross extension':'yes'}).dropna()

year = clinical.clinical.yearofinitialpathologicdiagnosis
year = year.replace('[Discrepancy]', nan).astype(float)

lymph = lymph_stage.ix[keepers_o] != 'n0'
lymph_status = combine(lymph, spread.ix[keepers_o]=='yes')
lymph_status = lymph_status.map({'neither': 'n0', lymph.name: 'lymph_node', 'both': 'extra_capsular_spread'})
lymph_status = (lymph_status == 'extra_capsular_spread').astype(float)

# %%
try:
    rna = pickle.load(open(cancer.path + '/mRNASeq/store/no_hpv.p', 'rb'))
    meth = pickle.load(open(cancer.path + '/Methylation/store/no_hpv.p', 'rb'))
    mirna = pickle.load(open(cancer.path + '/miRNASeq/store/no_hpv.p', 'rb'))
except:
    from Initialization.InitializeReal import RealDataset
    from Processing.Helpers import make_path_dump
    rna = RealDataset(run, cancer, 'mRNASeq', keepers_o)
    meth = RealDataset(run, cancer, 'Methylation', keepers_o)
    mirna = RealDataset(run, cancer, 'miRNASeq', keepers_o, create_meta_features=False)
    
    make_path_dump(rna, rna.path + '/store/no_hpv.p')
    make_path_dump(meth, meth.pth + '/store/no_hpv.p')
    make_path_dump(mirna, mirna.path + '/store/no_hpv.p')

# %% [markdown]
# ##Smoking

# %%
smoker = clinical.clinical.tobaccosmokinghistoryindicator
smoker = smoker[smoker.isin(['current smoker','lifelong non-smoker'])] == 'lifelong non-smoker'

# %%
clinical.clinical.tobaccosmokinghistoryindicator.value_counts()
# Out:
# current smoker                                 106
# current reformed smoker for < or = 15 years     86
# lifelong non-smoker                             66
# current reformed smoker for > 15 years          58
# dtype: int64

# %%
def exp_change(s):
    '''
    Calculates an anova for the change in expression across a variable
    on the second level of a MultiIndex. (eg. tumor/normal).
    '''
    return Tests.anova(pd.Series(s.index.get_level_values(1), s.index), s)

def extract_features(df):
    df_n = df.xs('01', level=1, axis=1)
    binary = df_n > -1
    binary = binary[binary.sum(1).isin(range(20, df.shape[1]/2))]
    
    real = df_n.ix[df_n.index.diff(binary.index)]
    singles = real[((real.max(1) - real.min(1)) > 1)]
    singles = singles[(singles.std(1) > .25)]
    ch = df.ix[singles.index].apply(exp_change, 1)
    singles = df_n.ix[true_index(ch.p < .01)]
    return binary, singles, real

# %%
df = rna.df

df_n = df.xs('01', level=1, axis=1)
binary = df_n > -1
binary = binary[binary.sum(1).isin(range(20, df.shape[1]/2))]

real = df_n.ix[df_n.index.diff(binary.index)]

singles = real[((real.max(1) - real.min(1)) > 1)]
singles = singles[(singles.std(1) > .5)]
ch = df.ix[singles.index].apply(exp_change, 1)

# %%
background = real.ix[true_index(ch.p > .1)]

# %%
ret = SVC_fill(smoker, background.ix[:, keepers_o])
ret['auc']
# Out:
# 0.8896551724137931

# %%
ret = SVC_fill(smoker, rna.features.ix['real', keepers_o])
ret['auc']
# Out:
# 0.91724137931034477

# %%
figsize(10,6)
fun = ret['decision_function']
violin_plot_pandas(clinical.clinical.tobaccosmokinghistoryindicator, fun)

# %%
get_surv_fit_lr(surv, clinical.clinical.tobaccosmokinghistoryindicator)
# Out:
#                                             Stats          Median Survival             5y Survival               Log-Rank
#                                        # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2       p
#                                                                                                                      10.9  0.0281
# current smoker                                106       43             2.2  1.43  4.36        0.24  0.123  0.469
# current reformed smoker for < or               86       35            2.58   2.3   NaN         NaN    NaN    NaN
# lifelong non-smoker                            66       21            4.82  3.53   NaN       0.443  0.278  0.705
# current reformed smoker for > 15 years         58       17             NaN   NaN   NaN       0.641  0.505  0.815

# %%
smoker_inferred = 1.*(ret['filled_feature']==False)

# %%
get_surv_fit_lr(surv, smoker_inferred)
# Out:
#        Stats          Median Survival             5y Survival               Log-Rank
#   # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2       p
#                                                                                 5.82  0.0158
# 1        167       75             2.2   1.6     4       0.326  0.236  0.452
# 0        135       42            4.71  2.96   NaN       0.498  0.381  0.653

# %%
survival_and_stats(smoker, surv)

# %%
survival_and_stats(smoker_inferred, surv)

# %% [markdown]
# ##Drinking

# %%
figsize(6,4)
clinical.clinical.amountofalcoholconsumptionperday.astype(float).hist()

# %%
clinical.clinical.alcoholhistorydocumented.value_counts()
# Out:
# yes    221
# no     100
# dtype: int64

# %%
freq = clinical.clinical.frequencyofalcoholconsumption.astype(float)
count = clinical.clinical.amountofalcoholconsumptionperday.astype(float)
drinker = (freq * count).dropna()
drinker = drinker[(drinker < 8) + (drinker > 21)]
drinker = drinker > 10

# %%
drinker.value_counts()
# Out:
# False    54
# True     40
# dtype: int64

# %%
ret = SVC_fill(drinker, rna.features.ix['real', keepers_o])
ret['auc']
# Out:
# 0.94936708860759489

# %%
fun = ret['decision_function']
violin_plot_pandas(drinker, fun)

# %%
series_scatter((freq * count).dropna(), fun)

# %%
get_surv_fit_lr(surv, drinker*1.)
# Out:
#        Stats          Median Survival             5y Survival               Log-Rank
#   # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2      p
#                                                                                 2.58  0.108
# 0         54       10             NaN  4.82   NaN       0.661  0.485  0.902
# 1         40       11               4  2.16   NaN       0.387  0.161  0.928

# %%
drinker_inferred = 1.*ret['inferred_values'] #ret['filled_feature']

# %%
get_surv_fit_lr(surv, drinker_inferred)
# Out:
#        Stats          Median Survival             5y Survival               Log-Rank
#   # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2        p
#                                                                                 9.69  0.00185
# 0        159       46             NaN  4.49   NaN       0.543   0.44  0.671
# 1        143       71             1.9  1.49  2.84       0.252  0.157  0.403

# %%
draw_survival_curves(drinker_inferred, surv, show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %% [markdown]
# ##Perineural Invasion

# %%
ret = SVC_fill(invasion[invasion.isin(['yes','no'])]=='yes', rna.features.ix['real', keepers_o])
ret['auc']
# Out:
# 0.91469194312796209

# %%
invasion_inferred = ret['filled_feature']

# %%
get_surv_fit_lr(surv, invasion)
# Out:
#              Stats          Median Survival             5y Survival               Log-Rank
#         # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2       p
#                                                                                       6.92  0.0315
# yes            115       52            2.58  1.42   NaN       0.376  0.271   0.52
# no             110       31            4.82     4   NaN       0.492  0.332  0.729
# Missing        102       40            3.53  2.16   NaN       0.377  0.262  0.544

# %%
get_surv_fit_lr(surv, invasion_inferred)
# Out:
#        Stats          Median Survival             5y Survival               Log-Rank
#   # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2      p
#                                                                                  4.6  0.032
# 1        159       69             2.5  1.54  4.49        0.33  0.237   0.46
# 0        143       48            4.36   2.3   NaN       0.494  0.386  0.633

# %%
survival_and_stats(invasion_inferred, surv)

# %% [markdown]
# ##Extra-Capsular Spread

# %%
ret = SVC_fill(spread=='yes', rna.features.ix['real', keepers_o])
ret['auc']
# Out:
# 0.93193717277486909

# %%
fun = ret['decision_function']
violin_plot_pandas(spread, fun)

# %%
spread_inferred = ret['filled_feature']

# %%
get_surv_fit_lr(surv, spread)
# Out:
#          Stats          Median Survival             5y Survival               Log-Rank
#     # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2         p
#                                                                                   12.2  0.000468
# no         146       49            4.49  2.96   NaN       0.486  0.377  0.628
# yes         57       31            1.35  1.24  2.08       0.267  0.156  0.456

# %%
get_surv_fit_lr(surv, spread_inferred)
# Out:
#        Stats          Median Survival             5y Survival               Log-Rank
#   # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2         p
#                                                                                 12.1  0.000492
# 0        236       80            4.49   2.7   NaN       0.443  0.351  0.559
# 1         66       37            1.42  1.25  2.16       0.259  0.155  0.434

# %%
get_surv_fit_lr(surv, ret['inferred_values']*1.)
# Out:
#        Stats          Median Survival             5y Survival               Log-Rank
#   # Patients # Events          Median Lower Upper        Surv  Lower  Upper     chi2         p
#                                                                                 11.3  0.000794
# 0        243       82            4.49  2.58   NaN       0.446  0.355  0.559
# 1         59       35            1.42  1.25  2.16        0.24  0.134  0.431

# %%
survival_and_stats(spread, surv)

# %%
survival_and_stats(spread_inferred, surv)

# %%
clinical_processed = pd.concat({'spread': spread, 'spread_inferred': spread_inferred,
                                'invasion': invasion, 'invasion_inferred': invasion_inferred,
                                'hpv': hpv, 'hpv_inferred': hpv_inferred,
                                'smoker': smoker, 'smoker_inferred': smoker_inferred,
                                'drinker': drinker, 'drinker_inferred': drinker_inferred,
                                'stage': stage,
                                'lymph_stage': lymph_stage,
                                'age': age, 'old_age': old_age,
                                'pack_years': pack_years,
                                'year': year,
                                'pre_2000': (year < 2000).map({True: 'pre_2000', False: 'post_2000'}),
                                'lymph_status': lymph_status,
                                'tumor_subdivision': tumor_subdivision}, axis=1)

# %%
clinical_processed.to_csv(cancer.path + '/Clinical/clinical_processed.csv')

# %%
del_3p = cn.df.ix['Deletion'].ix['3p14.2'].ix[0].dropna() == -1
del_3p.name = '3p14.2+/-'
amp_12q = cn.features.ix['Amplification'].ix['12q15'].ix[0]>0
amp_12q.name = 'amp12q'
p53_mut = mut.features.ix['TP53']
p53_mut = mut.features.ix['TP53']
muc5b = mut.features.ix['MUC5B']
two_hit = combine(del_3p, p53_mut)=='both'
two_hit.name = 'two_hit'
spread_inferred.name = 'spread'

# %%
subtypes = combine(two_hit, muc5b).dropna().ix[keepers_o]
subtypes = subtypes.map({'neither': 1, 'MUC5B': 1, 'two_hit': 2, 'both': 4})
subtypes.ix[combine(spread_inferred==1, subtypes==2)=='both'] = 3
#subtypes.ix[true_index(combine(amp_12q, subtypes==1)=='both')] = 5
subtypes = subtypes.ix[keepers_o].dropna()
subtypes.name = 'subtypes'
get_surv_fit_lr(surv, subtypes)
# Out:
#        Stats          Median Survival              5y Survival               Log-Rank
#   # Patients # Events          Median  Lower Upper        Surv  Lower  Upper     chi2         p
#                                                                                  43.9  1.59e-09
# 2        116       49            2.58   1.81   NaN       0.399  0.285  0.558
# 1         74       19             NaN   4.71   NaN        0.61  0.465  0.801
# 3         52       29             1.5   1.25  2.84       0.245  0.133  0.452
# 4         17       13           0.964  0.756   NaN         NaN    NaN    NaN

# %%
global_vars.mutation.rate_non.hist()

# %%
survival_and_stats(subtypes, surv, figsize=(5,4), order=[3,2,1,0])

# %%
draw_survival_curves(subtypes, surv, old_age, show=True)
# Out:
# <img src='data:image/png;base64,...'>
