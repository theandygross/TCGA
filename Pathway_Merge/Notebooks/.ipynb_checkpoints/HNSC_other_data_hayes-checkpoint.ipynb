# %%
cd ../src/
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
from Processing.Imports import *

# %%
clinical = pd.read_csv('/cellar/users/agross/Data/HanesExp/clinical.csv', index_col=0)

# %%
clinical = pd.read_csv('/cellar/users/agross/Data/HNSC_50/clinical.csv', index_col=0)
days = clinical['Overall Survival (years)'] * 365
event = (clinical['Overall Survival'] == 1)*1.
surv = pd.concat([days, event], axis=1, keys=['days','event']).stack()

s = surv
years = 5.
df = s.unstack().copy()
df['event'] = df.event * (df.days < int(365.25*years))
df['days'] = df.days.clip_upper(int((365.25*years)))
surv = df.stack()

# %%
t = pd.read_table('/cellar/users/agross/Data/HanesExp/GSE39368-GPL9053_series_matrix.txt', skiprows=range(89), index_col=0, comment='!')
t = t.dropna()

# %%
ann = pd.read_table('/cellar/users/agross/Data/HanesExp/agilent_44k.txt', delimiter='\t', index_col=0)
t = t.join(ann.ORF).set_index('ORF')

# %%
t = t.groupby(axis=0, level=0).mean()

# %%
mm = pd.read_csv('/cellar/users/agross/Data/HanesExp/microarray_map.csv', index_col=0, header=None, squeeze=True)
mm = mm.map(lambda s: s.split(' ')[-1])
mm.name = 'Annon_ID'

# %%
t = t.T.join(mm).set_index('Annon_ID').T

# %%
df = t

# %%
from Figures.R_Wrappers import *
from Initialization.InitializeReal import *

# %%
hpv = clinical['HPV Status']

# %%
hpv.value_counts()
# Out:
# HPV-       82
# HPV+       14
# Unknown     1
# dtype: int64

# %%
hpv = clinical['HPV Status']
draw_survival_curves(clinical.Differentation.dropna(), surv, show=True, show_legend=True)
# Out:
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-36-7194b9eeb98d> in <module>()
#       1 hpv = clinical['HPV Status']
# ----> 2 draw_survival_curves(clinical.Differentation.dropna(), surv, show=True, show_legend=True)
#
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src/Figures/R_Wrappers.pyc in draw_survival_curves(feature, surv, assignment, filename, show, title, labels, colors, ann, show_legend, q, std)
#      65         f = feature.ix[assignment[assignment==value].index]
#      66         if len(f.unique()) > 1:
# ---> 67             plot_me(f, name(value))
#      68
#      69     if show_legend == True:
#
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src/Figures/R_Wrappers.pyc in plot_me(sub_f, label)
#      47             sub_f = to_quants(sub_f, q=q, std=std)
#      48
# ---> 49         m = get_cox_ph(surv, sub_f, formula=fmla)
#      50         r_data = m.rx2('call')[2]
#      51         p = log_rank(sub_f, surv)['p']
#
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src/Stats/Survival.pyc in get_cox_ph(surv, feature, covariates, formula, interactions, get_model, print_desc)
#     211         df, _ = process_covariates(surv, feature, covariates)
#     212         fmla = robjects.Formula(formula)
# --> 213         s = survival.coxph(fmla, df)
#     214
#     215     if print_desc:
#
# /cellar/users/agross/anaconda2/lib/python2.7/site-packages/rpy2/robjects/functions.pyc in __call__(self, *args, **kwargs)
#      84                 v = kwargs.pop(k)
#      85                 kwargs[r_k] = v
# ---> 86         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#
# /cellar/users/agross/anaconda2/lib/python2.7/site-packages/rpy2/robjects/functions.pyc in __call__(self, *args, **kwargs)
#      33         for k, v in kwargs.iteritems():
#      34             new_kwargs[k] = conversion.py2ri(v)
# ---> 35         res = super(Function, self).__call__(*new_args, **new_kwargs)
#      36         res = conversion.ri2py(res)
#      37         return res
#
# RRuntimeError: Error in (function (formula, data, weights, subset, na.action, init, control,  :
#   No (non-missing) observations

# %%
pd.crosstab(clinical.Differentation, clinical['Expression Subtype'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-91a8dd3472db> in <module>()
# ----> 1 pd.crosstab(clinical.Differentation, clinical['Expression Subtype'])
#
# /cellar/users/agross/anaconda2/lib/python2.7/site-packages/pandas-0.12.0_152_ge9db624-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getattr__(self, name)
#    2076             return self[name]
#    2077         raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2078                              (type(self).__name__, name))
#    2079
#    2080     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Differentation'

# %%
draw_survival_curves(hpv.dropna(), surv, show=True, ann='p')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-afb6a09f22e8> in <module>()
# ----> 1 draw_survival_curves(hpv.dropna(), surv, show=True, ann='p')
#
# NameError: name 'hpv' is not defined

# %%
draw_survival_curves(clinical['Expression Subtype'], surv, hpv, show=True, ann='p')
# Out:
# <img src='data:image/png;base64,...'>

# %%
run = get_run('/cellar/data/TCGA/Firehose__2013_04_21/', 'Run_all')

# %%
gene_vec, pct_var, pat_vec = extract_geneset_pcs(df, r.gene_sets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-084383ce4c78> in <module>()
# ----> 1 gene_vec, pct_var, pat_vec = extract_geneset_pcs(df, r.gene_sets)
#
# NameError: name 'df' is not defined

# %%
from Stats.Survival import *

# %%
def stratified_cox(surv, feature, strata):
    fmla = 'Surv(days, event) ~ feature + strata({})'.format(strata.name)
    chi2 = get_cox_ph_ms(surv, feature, covariates=pd.concat([strata], axis=1),  
                         return_val='model', formula=fmla)[3][0]
    return chi2
def cox(surv, feature):
    fmla = 'Surv(days, event) ~ feature'
    chi2 = get_cox_ph_ms(surv, feature, return_val='model', formula=fmla)[3][0]
    return chi2

def cox_screen(df, surv):
    stat = df.apply(lambda s: cox(surv, s), 1)
    rr = pd.concat([pd.Series(chi2.sf(stat, 1), index=stat.index), stat], axis=1, keys=['p','chi2'])
    rr['q'] = bhCorrection(rr.p)
    rr = rr.sort('p')
    return rr

# %%
rr = cox_screen(pat_vec, surv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8cad8eae7893> in <module>()
# ----> 1 rr = cox_screen(pat_vec, surv)
#
# NameError: name 'pat_vec' is not defined

# %%
has_data = ((df.T.xs('01', level=1).T < -1).sum(1)) < (df.T.groupby(level=1).size()['01'] - 10)
df = df.ix[has_data]
df = df[df.T.xs('01', level=1).std() > .5]

ch = df.apply(exp_change, 1)
singles = df.ix[true_index(bhCorrection(ch.p) < .0001)]

ss = singles.apply(var_change, 1)
singles = singles.ix[true_index(bhCorrection(ss.p) < .1)]
singles = singles.T.xs('01', level=1).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ce3e24755af8> in <module>()
# ----> 1 has_data = ((df.T.xs('01', level=1).T < -1).sum(1)) < (df.T.groupby(level=1).size()['01'] - 10)
#       2 df = df.ix[has_data]
#       3 df = df[df.T.xs('01', level=1).std() > .5]
#       4
#       5 ch = df.apply(exp_change, 1)
#
# NameError: name 'df' is not defined

# %%
draw_survival_curves(t.ix['POLH'], surv, show=True, show_legend=False, ann='p', std=1)
# Out:
# <img src='data:image/png;base64,...'>

# %%
dd = ((df.T - df.mean(1))/ df.std(1)).T

# %%
pc1 = frame_svd(dd)[2][0]

# %%
draw_survival_curves(pc1, surv, show=True, std=1)
# Out:
# <img src='data:image/png;base64,...'>

# %%
from Stats.Survival import *

# %%
hpv.value_counts().to_dict()
# Out:
# {'HPV+': 14, 'HPV-': 82, 'Unknown': 1}

# %%
len(true_index(hpv!='HPV+'))
# Out:
# 124

# %%
len(true_index(hpv!='HPV+'))
# Out:
# 124

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17109 entries, 15E1.2 to tcag7.1314
# Columns: 138 entries, nan to nan
# dtypes: float64(138)

# %%
dff = df.ix[:, true_index(hpv!='HPV+')].dropna(how='all')

# %%
background = pd.read_csv('bg', index_col=0)['0']
bg = dff.ix[background.index].dropna()

bg = ((bg.T - bg.mean(1)) / bg.std(1)).T
U, S, pc = frame_svd(bg)

pc.ix[:,:5].apply(cox, args=(surv,)).T
# Out:
#          LR     p
# 0  2.39e-01  0.63
# 1  1.11e+00  0.29
# 2  5.63e-02  0.81
# 3  7.97e-01  0.37
# 4  1.31e-04  0.99
# 5  5.58e-02  0.81

# %%
run = get_run('/cellar/data/TCGA/Firehose__2013_04_21/', 'Run_all')

# %%
draw_survival_curves(to_quants(dff.ix['RAF1'], std=1), surv, show=True, show_legend=False, std=1)
# Out:
# <img src='data:image/png;base64,...'>

# %%
d = pd.Series({'ARRB1': 0.33001123176212449,
 'DNM1': -0.21174600988544495,
 'GNAS': 0.075103361396666318,
 'GNB1': -0.46643135170723998,
 'GNGT1': -0.38104500381584983,
 'MAP2K1': -0.12709077192810503,
 'MAP2K2': 0.21096202523483465,
 'MAPK3': 0.34791393954292976,
 'RAF1': 0.54420680701195878})

# %%
draw_survival_curves(to_quants(p53, std=1), surv, hpv, show=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-148-95b5a798ef01> in <module>()
# ----> 1 draw_survival_curves(to_quants(p53, std=1), surv, hpv, show=True)
#
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src/Figures/R_Wrappers.pyc in draw_survival_curves(feature, surv, assignment, filename, show, title, labels, colors, ann, show_legend, q, std)
#      21         num_panels = len(assignment.unique())
#      22         name = lambda v: str(assignment.name) + ' = ' + str(v)
# ---> 23     if (labels is None) and ((len(feature) / feature.nunique()) > 10):
#      24         labels = r.sort(r.c(*feature.unique()))  #R sorts bad
#      25         colors = ['blue','green','red','cyan','magenta','yellow','black']
#
# /cellar/users/agross/semillon/anaconda2/lib/python2.7/site-packages/pandas-0.12.0.dev_-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getattr__(self, name)
#    2083             return self[name]
#    2084         raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2085                              (type(self).__name__, name))
#    2086
#    2087     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'nunique'

# %%
from Figures.Boxplots import *

# %%
violin_plot_pandas(hpv.fillna('Unknown'), p53)

# %%
draw_survival_curves(to_quants(p53, q=.1), surv, hpv.fillna('Unknown'), show=True, show_legend=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
rr.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-02fc88d6b144> in <module>()
# ----> 1 rr.head(20)
#
# NameError: name 'rr' is not defined

# %%
screen_feature(hpv, kruskal_pandas, features).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-b383083a4dec> in <module>()
# ----> 1 screen_feature(hpv, kruskal_pandas, features).head()
#
# NameError: name 'features' is not defined

# %%
screen_feature(clinical.Differentation=='Poor', kruskal_pandas, features).head()
# Out:
#                                                            H         p  q
# REACTOME_APOPTOTIC_CLEAVAGE_OF_CELL_ADHESION_PROTEINS  19.44  1.04e-05  0
# KEGG_LINOLEIC_ACID_METABOLISM                          17.89  2.34e-05  0
# REACTOME_CHOLESTEROL_BIOSYNTHESIS                      17.11  3.52e-05  0
# KEGG_STEROID_BIOSYNTHESIS                              16.66  4.48e-05  0
# KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS                   15.76  7.18e-05  0

# %%
screen_feature(clinical.Differentation=='Poor', kruskal_pandas, features).head()
# Out:
#                                                            H         p  q
# REACTOME_APOPTOTIC_CLEAVAGE_OF_CELL_ADHESION_PROTEINS  19.44  1.04e-05  0
# KEGG_LINOLEIC_ACID_METABOLISM                          17.89  2.34e-05  0
# REACTOME_CHOLESTEROL_BIOSYNTHESIS                      17.11  3.52e-05  0
# KEGG_STEROID_BIOSYNTHESIS                              16.66  4.48e-05  0
# KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS                   15.76  7.18e-05  0

# %%
pc_genes['REACTOME_APOPTOTIC_CLEAVAGE_OF_CELL_ADHESION_PROTEINS'].order().plot(kind='bar')

# %%
violin_plot_pandas(clinical.Differentation, features.ix['REACTOME_APOPTOTIC_CLEAVAGE_OF_CELL_ADHESION_PROTEINS'])

# %%
hpv.name = 'hpv'
cov_df = pd.concat([clinical['Age'], hpv], axis=1)
test = SurvivalTest(surv, cov_df)

# %%
rna_res = run_feature_matrix(features, test, fp_cutoff=1)

# %%
rna_res.head()
# Out:
#                                                                 Full  Full                                               Full  Univariate
#                                                                   LR  LR_q                                               fmla     hazzard     p     q
# REACTOME_REMOVAL_OF_THE_FLAP_INTERMEDIATE_FROM_THE_C_STRAND  0.00269   0.3                      Surv(days, event) ~ feature\n        0.03  0.01  0.91
# SA_FAS_SIGNALING                                             0.00485   0.3  Surv(days, event) ~ feature + hpv + feature:hpv\n        0.03  0.01  0.90
# REACTOME_GLYCOLYSIS                                          0.00501   0.3  Surv(days, event) ~ feature + hpv + feature:hpv\n       24.93  0.01  0.90
# KEGG_ECM_RECEPTOR_INTERACTION                                 0.0102   0.3  Surv(days, event) ~ feature + hpv + feature:hpv\n        0.80  0.86  0.98
# REACTOME_REMOVAL_OF_THE_FLAP_INTERMEDIATE                     0.0125   0.3                      Surv(days, event) ~ feature\n        0.08  0.05  0.94

# %%
draw_survival_curves(to_quants(features.ix['SA_FAS_SIGNALING'], std=.5, labels=True), surv, hpv, show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
cn = pd.read_table('/cellar/users/agross/Data/HanesExp/GSE39367_smooth_cn_data.txt', index_col=[0,1]).T

# %%
import Data.Firehose as FH

# %%
path = '/cellar/users/hcarter/Desktop/Andy/'
gistic = pd.read_table(path + 'all_lesions.conf_90.txt', index_col=[0,1])
lesions = gistic.select(lambda s: 'HN' in s, axis=1) 
lesions = lesions.select(lambda s: 'values' not in s[0], axis=0) 
from_tuples = pd.MultiIndex.from_tuples
lesions.index = from_tuples([(s[0].split(' ')[0], s[1].strip(), 'Lesion') 
                             for s in lesions.index])
lesions.columns = [s.split('_')[1] for s in  lesions.columns]
lesions = lesions.groupby(level=[0,1,2]).first()

# %%
import Stats.Survival as S
reload(S)
# Out:
# <module 'Stats.Survival' from 'Stats/Survival.pyc'>

# %%
rr = S.cox_screen(lesions, surv)

# %%
rr.head(10)
# Out:
#                                 LR     p     q
# Amplification 3p11.1  Lesion  4.12  0.04  0.86
#               11q13.3 Lesion  3.82  0.05  0.86
# Deletion      2q24.1  Lesion  3.04  0.08  0.86
# Amplification 3q25.1  Lesion  2.86  0.09  0.86
# Deletion      17p13.2 Lesion  2.69  0.10  0.86
# Amplification 3q11.2  Lesion  2.56  0.11  0.86
#               9p23    Lesion  2.56  0.11  0.86
# Deletion      7q36.3  Lesion  2.39  0.12  0.86
#               2q34    Lesion  2.33  0.13  0.86
#               3p25.3  Lesion  2.15  0.14  0.86

# %%
f = lesions.ix['Amplification'].ix['3p11.1'].ix[0]

# %%
draw_survival_curves(f, surv, show=True, show_legend=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
path = '/cellar/users/hcarter/Desktop/Andy/combined/'
gistic = pd.read_table(path + 'all_lesions.conf_99.txt', index_col=[0,1])
gistic = gistic.ix[:,7:]
from_tuples = pd.MultiIndex.from_tuples
gistic.index = from_tuples([(s[0].split(' ')[0], s[1].strip()) 
                             for s in gistic.index])
gistic = gistic.groupby(level=[0,1]).first()
gistic.T['Deletion'] = (gistic.T['Deletion']*-1).replace(-0,0)

cna = gistic.ix[:,[i for i in gistic.columns if 'GSM' in i and '_HN' in i]]
cna.columns = map(lambda s: s.split('_')[1], cna.columns)

# %%
rr = S.lr_screen(cna.ix['Deletion'] < 0, surv)
rr.head()
# Out:
#          chi2     p     q
# 18q12.1  4.80  0.03  0.91
# 4q13.2   4.11  0.04  0.91
# 3p14.1   3.99  0.05  0.91
# 18q12.3  3.69  0.05  0.91
# 1p36.21  2.71  0.10  0.91

# %%
draw_survival_curves(cna.ix['Deletion'].ix['3p14.1'], surv, show=True, ann='p')
# Out:
# <img src='data:image/png;base64,...'>

# %%
path = '/cellar/users/hcarter/Desktop/Andy/combined/'
gistic = pd.read_table(path + 'all_thresholded.by_genes.txt', index_col=[0,1, 2])

cna = gistic.ix[:,[i for i in gistic.columns if 'GSM' in i and '_HN' in i]]
cna.columns = map(lambda s: s.split('_')[1], cna.columns)

# %%
path = '/cellar/users/hcarter/Desktop/Andy/combined/'
gistic = pd.read_table(path + 'broad_values_by_arm.txt', index_col=0)

cna = gistic.ix[:,[i for i in gistic.columns if 'GSM' in i and '_HN' in i]]
cna.columns = map(lambda s: s.split('_')[1], cna.columns)

# %%
from scipy.stats import chi2

# %%
cox_screen(cna, surv).head()
# Out:
#                    p  chi2     q
# Chromosome Arm
# 2p              0.02  5.31  0.49
# 14q             0.03  5.01  0.49
# 16q             0.15  2.10  1.00
# 21q             0.20  1.67  1.00
# 4p              0.24  1.40  1.00

# %%
log_rank(cna.ix['FHIT'].iloc[0]<0, surv)
# Out:
# chi2    1.73
# p       0.19
# dtype: float64

# %%
draw_survival_curves(cna.ix['FHIT'].iloc[0]<0, surv, show=True, ann='p')
# Out:
# <img src='data:image/png;base64,...'>

# %%
rr = S.lr_screen(cna.ix['Amplification'] > 0, surv)
rr.head()
# Out:
#          chi2     p     q
# 19q13.2  2.78  0.10  0.91
# 3q25.1   2.63  0.10  0.91
# 7q31.1   2.62  0.11  0.91
# 2q22.3   2.62  0.11  0.91
# 7q34     2.62  0.11  0.91

# %%
log_rank(1.*(cn[3].iloc[:,:400].median(1) < -.03), surv)
# Out:
# chi2    2.27
# p       0.13
# dtype: float64

# %%
draw_survival_curves(cn[3].iloc[:,:400].median(1) < -.02, surv, show=True, ann='p')
# Out:
# <img src='data:image/png;base64,...'>

# %%
fhit = cn[3].ix[:,59000000:62000000].median(1)

# %%
fhit.hist()

# %%
draw_survival_curves(fhit < -.05, surv, clinical.Differentation, show=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-270-63520860c9d1> in <module>()
# ----> 1 draw_survival_curves(fhit < -.05, surv, clinical.Differentation, show=True)
#
# /cellar/users/agross/semillon/anaconda2/lib/python2.7/site-packages/pandas-0.12.0.dev_-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getattr__(self, name)
#    2083             return self[name]
#    2084         raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2085                              (type(self).__name__, name))
#    2086
#    2087     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Differentation'

# %%
log_rank(1.*(fhit < -.05), surv)
# Out:
# chi2    5.11
# p       0.02
# dtype: float64

# %%
draw_survival_curves(to_quants(t.ix['FHIT'], std=.5), surv, hpv, show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
draw_survival_curves(t.ix['TP53'], surv, show=True, std=1, show_legend=False)
# Out:
# <img src='data:image/png;base64,...'>

# %%
clinical.head()
# Out:
#         Expression Subtype Tissue  Age              Race Gender  Smoking  PackYears             Alcohol Use Differentation         Site Stage Tumor Status Node Status                  Treatment HPV Status Vital Status Recurrence Status  Recurrence-Free Survival Time (Months)
# Anon_ID
# HN153                Basal  Tumor   78         Caucasian   Male        1         20  None or Light/Moderate       Moderate  Oral Cavity    II           T2          N0              Surgery Alone       HPV-        Alive     No Recurrence                                      36
# HN119            Classical  Tumor   48         Caucasian   Male        0          0  None or Light/Moderate           Well        Other   III           T3          N0      Surgery and Radiation        NaN        Alive     No Recurrence                                      36
# HN065                Basal  Tumor   58         Caucasian   Male        0          0                   Heavy           Well  Oral Cavity   IVa          T4a         N2c  Concurrent Chemoradiation        NaN         Dead        Recurrence                                       4
# HN074            Classical  Tumor   72  African American   Male        1         40  None or Light/Moderate           Poor  Hypopharynx   IVa          T4a          N0              Surgery Alone       HPV-         Dead        Recurrence                                      19
# HN143          Mesenchymal  Tumor   71  African American   Male        1        120                   Heavy       Moderate   Oropharynx   IVa          NaN         NaN  Concurrent Chemoradiation       HPV-         Dead     No Recurrence                                      26

# %%
t.ix['MEG3'].hist()

# %%
cn = pd.read_csv('/cellar/users/agross/Data/HNSC_50/cn_by_patient.csv', index_col=0)

# %%
draw_survival_curves(cn['3p14.2-DP6'], surv, show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
maf = pd.read_csv('/cellar/users/agross/Data/HNSC_50/maf.csv')
maf = maf.set_index(['Hugo_Symbol','Tumor_Sample_Barcode'])
maf = maf[maf.Variant_Classification != 'Silent']
mut = maf.groupby(level=[0,1]).size().unstack()
mut.columns = map(lambda s: int(s.split('-')[2]), mut.columns)
mut = mut.fillna(0.)

# %%
draw_survival_curves(clinical['Cell differentiation'].dropna(), surv, show=True, ann='p')
# Out:
# <img src='data:image/png;base64,...'>

# %%
combo = combine(mut.ix['TP53']>0, cn['3p.del'])

# %%
draw_survival_curves(combo == 'both', surv, show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
draw_survival_curves(combine(mut.ix['TP53']>0, cn['3p.del']), surv, show=True, show_legend=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
draw_survival_curves(mut.ix['TP53']>0, surv, clinical['Age'] > 60, show=True, ann='p')
# Out:
# <img src='data:image/png;base64,...'>

# %%
draw_survival_curves(mut.ix['TP53']>0, surv, clinical['Age'] > 60, show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
clinical['Age'].hist()

# %%
draw_survival_curves(clinical['Age'], surv, show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
chi2.sf(cox(surv, clinical['Age']),1)
# Out:
# 0.052712708618173044

# %%
tt = lambda a,b: kruskal_pandas(b,a)

# %%
screen_feature(clinical['Age'], tt, cn.T).head()
# Out:
#                 H     p     q
# 21q.del      4.25  0.04  0.86
# 2q34-DP4     3.48  0.06  0.86
# 13q22.1-AP9  3.34  0.07  0.86
# 6q23.3-DP16  2.85  0.09  0.86
# 5q35.3-DP13  2.83  0.09  0.86
