# %% [markdown]
# #RCC Multivariate Screen
#
# This is a screen for survival associated features.

# %%
cd ../src
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
from Processing.Imports import *
from Figures.Survival import survival_and_stats

# %% [markdown]
# ##Read in Data

# %%
run = get_run('/cellar/data/TCGA/Firehose__2013_05_23/', 'Run_all')

cancer = run.load_cancer('KIRC')
clinical = cancer.load_clinical()
global_vars = cancer.load_global_vars()

mut = cancer.load_data('Mutation')
mut.uncompress()
meth = cancer.load_data('Methylation')
cn = cancer.load_data('CN_broad')
cn.uncompress()
rna = cancer.load_data('mRNASeq')
rppa  = cancer.load_data('RPPA')
mirna = cancer.load_data('miRNASeq')
age = clinical.clinical.age.astype(float)

# %%
from Data.ProcessClinical import format_survival_from_data_portal
path  = '/cellar/users/agross/Data/TCGA/KIRC_Followup/'
survival, timeline = format_survival_from_data_portal(path, cancer.name)
clinical.survival = survival
clinical.artificially_censor(5)
age = timeline.age

# %% [markdown]
# ##Clinical Features

# %%
clinical.artificially_censor(8)

# %%
surv = clinical.survival.survival_8y
old = pd.Series(1.*(age>=75), name='old')

# %%
draw_survival_curves(age > 85, surv, show=True, ann='p')
# Out:
# <img src='data:image/png;base64,...'>

# %%
survival_and_stats(clinical.stage.pathologicstage, surv)

# %% [markdown]
# ####Form expression and methylation features without HPV
# * HPV has a big influence on expression, here I am creating a second set of features without HPV
# * I use this sparingly but it helps to tease out wheter an association is due to a underlying relationship with HPV

# %%
from Stats.Survival import cox

rev_kruskal = lambda a,b: kruskal_pandas(b,a)
def fc(hit_vec, response_vec):
    f = response_vec.groupby(hit_vec).median()
    return f[0] > f[1]

def mut_filter(df, rate, binary_cutoff=12):
    df = df[df.sum(1) >= binary_cutoff]
    cc = screen_feature(rate, rev_kruskal, df)
    
    fc_apply = lambda s: fc(s, rate)
    direction = df.apply(fc_apply, axis=1)
    direction.name = 'direction'
    
    cc = cc.join(direction)
    cc = cc[cc.direction==False]
    
    df = df.ix[true_index(cc.p > .01)]
    df = df.dropna(axis=1)
    return df


def get_patient_set(filters):
    f1 = [age >= 100] + list(filters)
    filter_df = pd.concat(f1, axis=1)
    clinical_filter = filter_df.dropna().sum(1) == 0
    keepers_o = true_index(clinical_filter)
    #keepers_o = keepers_o.intersection(mut.features.columns).intersection(cn.features.columns)
    
    f2 = [age >= 85] + list(filters)
    filter_df = pd.concat(f2, axis=1)
    clinical_filter = filter_df.sum(1) == 0
    keepers = true_index(clinical_filter)
    #keepers = keepers.intersection(mut.features.columns).intersection(cn.features.columns)
    return keepers, keepers_o

# %%
y = clinical.clinical.yearofinitialpathologicdiagnosis.astype(float) < 2004
stage = clinical.stage.pathologicstage
laterality = clinical.clinical.laterality
clinical_processed = pd.concat([y, stage, laterality], keys=['year','stage','laterality'],
                               axis=1)

# %%
cox_screen(clinical_processed, surv, axis=0)
# Out:
#                 hazard                                   LR                      concordance
#             exp(-coef)  exp(coef)  lower .95  upper .95  df     p    stat     q           se  stat
# stage             0.84       1.19       0.61       2.31   3  0.00  100.74  0.00         0.02  0.73
# year              0.58       1.73       1.24       2.42   1  0.00    9.80  0.00         0.02  0.55
# laterality        1.48       0.68       0.50       0.92   1  0.01    6.21  0.01         0.02  0.54

# %%
def get_data(keepers_o, binary_cutoff=12):
    rate = mut.df.sum()
    mut_df = mut_filter(mut.features.ix[:,keepers_o], rate, binary_cutoff).T
    
    del_df = (cn.features.ix['Deletion', keepers_o].dropna(1) < 0).astype(int)
    del_df = del_df[del_df.sum(1) >= binary_cutoff]
    del_df.index = del_df.index.droplevel(1)
    del_df = del_df.T
    amp_df = (cn.features.ix['Amplification', keepers_o].dropna(1) > 0).astype(int)
    amp_df = amp_df[amp_df.sum(1) >= binary_cutoff]
    amp_df.index = amp_df.index.droplevel(1)
    amp_df = amp_df.T
    
    global_df = pd.concat([global_vars['mutation'], global_vars['cna'], rna.global_vars, 
                           meth.global_vars, mirna.global_vars], 
                    keys=['mutation', 'cna', 'rna', 'methylation', 'mirna'], axis=1)
    global_df.columns = map(lambda s: '_'.join(s), global_df.columns)
    
    mirna_df = mirna.features.copy()
    mirna_df.index = map(lambda s: '_'.join(s), mirna_df.index)
    mirna_df = mirna_df.T
    
    rna_df = rna.features.copy()
    rna_df = rna_df.apply(lambda s: to_quants(s, std=1),  axis=1)
    rna_df.index = map(lambda s: '_'.join(s), rna_df.index)
    rna_df = rna_df.T
    
    clinical_df = clinical_processed.select(lambda s: 'age' not in s, 1)
    
    data_sets = {'clinical': clinical_df,
                 'global': global_df,
                 'mutation': mut_df,
                 'deletion': del_df,
                 'amplification': amp_df,
                 'rna': rna_df,
                 'mirna': mirna_df,
                 'methylation': meth.pathways.T}
    return data_sets

def test(s, surv, cov_df):
    s = s.dropna()
    try:
        return get_cox_ph_ms(surv, s, cov_df, return_val='LR', interactions='just_feature')
    except:
        return pd.Series(index=['LR','feature_p', 'fmla', 'hazzard'])
    
def get_interactions(df, cov_df):
    binary = df[df.T.describe().ix['unique'] == 2]
    n_tests = (len(binary) * (len(binary) - 1)) / 2
    s = pd.DataFrame({(a,b): interaction(v1,v2, surv) 
                          for a,v1 in binary.iterrows()
                          for b,v2 in binary.iterrows()
                          if (a < b)
                          and fisher_exact_test(v1,v2).ix['p'] < (.3 / n_tests)}).T
    int_pairs =  s.ix[s.p < 1].sort('p')
    
    int_associations = {}
    for p,vals in int_pairs.iterrows():
        combo = combine(binary.ix[p[0]], binary.ix[p[1]])
        vec = combo == vals['interaction']
        int_associations[p] = test(vec, surv, cov_df) 
    int_associations = pd.DataFrame(int_associations).T
    return s, int_associations

def run_screen(filters, cov):
    cov_df = pd.concat(cov, axis=1)
    keepers, keepers_o = get_patient_set(filters)
    cutoff = max(np.floor(len(keepers_o) / 10.), 8)
    cutoff = min(cutoff, 15)
    data_sets = get_data(keepers_o, binary_cutoff=cutoff)
    df = pd.concat(data_sets, 1).T
    df = df.ix[:,keepers_o].dropna(how='all')
    binary = df[df.T.describe().ix['unique'] == 2]
    
    univariate = cox_screen(binary, surv)
    vec = univariate.LR.p.sort_index()
    univariate['q_bonf'] = vec.groupby(level=0).apply(lambda s: s*len(s)).order()
    univariate['q_bh'] = vec.groupby(level=0).apply(bhCorrection).order()
    hits = univariate[univariate['q_bh'] < .5].index
    
    feature_age = df.ix[hits].apply(test, args=(surv, cov_df,), axis=1)
    vec = feature_age.LR.ix[univariate.index].sort_index()
    feature_age['q_bonf'] = vec.groupby(level=0).apply(lambda s: s*len(s)).order()
    feature_age['q_bh'] = vec.groupby(level=0).apply(bhCorrection).order()
    feature_age['q_all'] = feature_age['q_bh'] * 6
    hits = feature_age[feature_age.q_all < .3].index
    try:
        pairs, interactions = get_interactions(df.ix[hits], cov_df)
        res = pd.concat([feature_age, interactions]).sort('LR')
    except:
        res = feature_age
    return res, feature_age, univariate, keepers_o, df

# %%
res, feature_age, univariate, keepers_o, df = run_screen([], [age, old])

# %%
res.dropna().head(20)
# Out:
#                            LR feature_p                                               fmla hazzard     q_all      q_bh    q_bonf
# rna binary_CDHR4     5.53e-10  5.24e-10  Surv(days, event) ~ feature + age + feature:age\n    3.06  5.64e-06  9.40e-07  1.27e-06
#     binary_GCKR      1.64e-09  2.21e-09                Surv(days, event) ~ feature + age\n    2.63  5.64e-06  9.40e-07  3.77e-06
#     binary_GOLGA8DP  1.66e-09  5.17e-10                Surv(days, event) ~ feature + age\n    2.74  5.64e-06  9.40e-07  3.80e-06
#     binary_ZIC2      1.75e-09  7.53e-09                Surv(days, event) ~ feature + age\n    2.68  5.64e-06  9.40e-07  4.01e-06
#     binary_WFDC10B   2.05e-09  5.19e-09                Surv(days, event) ~ feature + age\n    2.62  5.64e-06  9.40e-07  4.70e-06
#     binary_DMRT3     3.34e-09  7.34e-09                Surv(days, event) ~ feature + age\n    2.61  7.40e-06  1.23e-06  7.66e-06
#     binary_PAEP      3.76e-09  1.22e-08                Surv(days, event) ~ feature + age\n     2.6  7.40e-06  1.23e-06  8.64e-06
#     binary_AKR1B15   5.91e-09  3.45e-11  Surv(days, event) ~ feature + age + feature:age\n    3.25  1.02e-05  1.70e-06  1.36e-05
#     binary_SAA4      1.13e-08  5.09e-08                Surv(days, event) ~ feature + age\n    2.58  1.73e-05  2.88e-06  2.59e-05
#     binary_OTX1      1.65e-08  2.26e-08                Surv(days, event) ~ feature + age\n    2.46  2.27e-05  3.79e-06  3.79e-05
#     binary_C21orf99  3.04e-08  5.59e-09                Surv(days, event) ~ feature + age\n    2.61  3.80e-05  6.34e-06  6.98e-05
#     binary_KRT79     5.17e-08  5.47e-09                Surv(days, event) ~ feature + age\n     2.7  5.50e-05  9.17e-06  1.19e-04
#     binary_SSX2       5.2e-08  1.97e-10                Surv(days, event) ~ feature + age\n    4.06  5.50e-05  9.17e-06  1.19e-04
#     binary_ZIC5       8.6e-08  4.64e-08  Surv(days, event) ~ feature + age + feature:age\n    2.53  8.46e-05  1.41e-05  1.97e-04
#     binary_TGM5      1.17e-07  2.59e-07                Surv(days, event) ~ feature + age\n    2.36  1.02e-04  1.70e-05  2.68e-04
#     binary_OTP       1.18e-07  7.46e-08                Surv(days, event) ~ feature + age\n    2.35  1.02e-04  1.70e-05  2.72e-04
#     binary_CXorf30   1.36e-07  4.16e-07                Surv(days, event) ~ feature + age\n     2.4  1.10e-04  1.83e-05  3.11e-04
#     binary_MRAP      1.57e-07  1.59e-09                Surv(days, event) ~ feature + age\n    3.62  1.16e-04  1.94e-05  3.61e-04
#     binary_PDIA2      1.6e-07  6.98e-07                Surv(days, event) ~ feature + age\n    2.44  1.16e-04  1.94e-05  3.68e-04
#     binary_TDRG1     2.27e-07   1.5e-08                Surv(days, event) ~ feature + age\n    2.82  1.56e-04  2.61e-05  5.22e-04

# %%
res.ix['mirna'].head()
# Out:
#                             LR feature_p                                               fmla hazzard  q_all      q_bh    q_bonf
# binary_hsa-mir-9-3    4.24e-06  2.59e-06                Surv(days, event) ~ feature + age\n    2.13   0.00  6.72e-04  8.05e-04
# binary_hsa-mir-1305   7.07e-06  1.22e-06                Surv(days, event) ~ feature + age\n    2.42   0.00  6.72e-04  1.34e-03
# binary_hsa-mir-3651   4.28e-05  6.17e-06  Surv(days, event) ~ feature + age + feature:age\n    2.15   0.02  2.71e-03  8.14e-03
# binary_hsa-mir-875    7.94e-05  0.000248                Surv(days, event) ~ feature + age\n    0.47   0.02  3.58e-03  1.51e-02
# binary_hsa-mir-138-1  0.000116  8.49e-05                Surv(days, event) ~ feature + age\n    1.87   0.02  3.58e-03  2.21e-02

# %%
cdhr4 = df.ix['rna'].ix['binary_CDHR4'].ix[keepers_o].dropna()
survival_and_stats(cdhr4, surv, figsize=(6,4), upper_lim=10)

# %%
pd.crosstab(rna.df.ix['CDHR4'].ix[:,'01'] > -2, mut.features.ix['BAP1'])
# Out:
# BAP1     0   1
# CDHR4
# False  117   5
# True   136  22

# %%
violin_plot_series(rna.df.ix['CDHR4'])

# %%
screen_feature(rna.df.ix['CDHR4'].ix[:,'01'], rev_kruskal, cn.features < 0).head()
# Out:
#                                  H         p         q
# (Deletion, 9p21.3, Lesion)   28.94  7.45e-08  2.31e-06
# (Deletion, 9p23, Lesion)     24.44  7.65e-07  1.19e-05
# (Deletion, 13q13.3, Lesion)  23.65  1.15e-06  1.19e-05
# (Deletion, 14q31.1, Lesion)  16.79  4.18e-05  3.24e-04
# (Deletion, 8p23.2, Lesion)   11.84  5.80e-04  3.60e-03

# %%
screen_feature(rna.df.ix['CDHR4'].ix[:,'01'], rev_kruskal, mut.features).head()
# Out:
#                                                                  H         p     q
# BAP1                                                         17.67  2.62e-05  0.02
# BIOCARTA_CALCINEURIN_PATHWAY                                  8.20  4.18e-03  0.97
# REACTOME_CYCLIN_A1_ASSOCIATED_EVENTS_DURING_G2_M_TRANSITION   7.65  5.66e-03  0.97
# KEGG_AMINOACYL_TRNA_BIOSYNTHESIS                              7.24  7.12e-03  0.97
# KEGG_ASCORBATE_AND_ALDARATE_METABOLISM                        6.38  1.15e-02  0.97

# %%
violin_plot_pandas(combine(cn.features.ix['Deletion'].ix['9p21.3'].ix[0]==-1, mut.features.ix['BAP1']), rna.df.ix['CDHR4'].ix[:,'01'])

# %%
violin_plot_pandas(mut.features.ix['BAP1'], rna.df.ix['CDHR4'].ix[:,'01'])

# %%
draw_survival_curves(rna.df.ix['CDHR4'].ix[:,'01'] > -2, surv, show=True, ann='p')
# Out:
# <img src='data:image/png;base64,...'>

# %%
screen_feature(rna.df.ix['CDHR4'].ix[:,'01'] < -1, chi2_cont_test, cn.features).head()
# Out:
#                                    chi2         p  dof         q
# (Deletion, 9p21.3, Lesion)        20.99  4.61e-06    1  1.43e-04
# (Deletion, 9p23, Lesion)          16.88  3.98e-05    1  5.87e-04
# (Deletion, 13q13.3, Lesion)       16.21  5.68e-05    1  5.87e-04
# (Deletion, 14q31.1, Lesion)       12.21  4.76e-04    1  3.69e-03
# (Amplification, 8q24.22, Lesion)  10.50  5.25e-03    2  3.26e-02

# %%
screen_feature(rna.df.ix['CDHR4'].ix[:,'01'] < -1, chi2_cont_test, mut.features).head()
# Out:
#                                    chi2         p  dof     q
# BAP1                              11.00  9.09e-04    1  0.60
# KEGG_AMINOACYL_TRNA_BIOSYNTHESIS   9.71  1.83e-03    1  0.61
# REACTOME_DNA_REPAIR                8.15  4.32e-03    1  0.96
# BIOCARTA_RARRXR_PATHWAY            6.28  1.22e-02    1  1.00
# REACTOME_CENTROSOME_MATURATION     6.16  1.31e-02    1  1.00

# %%
res, feature_age, univariate, keepers_o, df = run_screen([gckr==1], [age, old])

# %%
res.sort('q_all').head(4)
# Out:
#                                    LR  feature_p                                 fmla  hazzard  q_bonf  q_bh  q_all
# mirna    binary_hsa-mir-9-3  3.61e-04   2.29e-04  Surv(days, event) ~ feature + age\n     4.75    0.07  0.07   0.41
# rna      binary_LOC150568    4.39e-05   5.15e-04  Surv(days, event) ~ feature + age\n     6.84    0.10  0.10   0.60
# deletion 3p12.2              4.25e-02   5.28e-02  Surv(days, event) ~ feature + age\n     2.47    0.68  0.17   1.04
#          14q31.1             5.39e-02   5.68e-02  Surv(days, event) ~ feature + age\n     2.24    0.86  0.17   1.04

# %%
mir9 = df.ix['mirna'].ix['binary_hsa-mir-9-3'].ix[keepers_o].dropna()
survival_and_stats(mir9, surv, figsize=(6,4))

# %%
res, feature_age, univariate, keepers_o, df = run_screen([gckr==0], [age, old])

# %%
res.sort('q_all').head()
# Out:
#                                   LR  feature_p                                               fmla  hazzard  q_bonf  q_bh  q_all
# amplification 1q24.1        3.68e-02   3.61e-03  Surv(days, event) ~ feature + age + feature:age\n     3.14    0.29  0.29   1.77
# rna           binary_PDIA2  1.45e-04   6.86e-03  Surv(days, event) ~ feature + age + feature:age\n    10.37    0.33  0.33   1.97
#               binary_CAMP   3.74e-04   4.87e-04                Surv(days, event) ~ feature + age\n     0.36    0.86  0.33   1.97
#               binary_MMP20  4.73e-04   5.41e-03  Surv(days, event) ~ feature + age + feature:age\n     0.17    1.08  0.33   1.97
#               binary_MLNR   5.73e-04   8.32e-04                Surv(days, event) ~ feature + age\n     0.37    1.31  0.33   1.97

# %%
wnt = df.ix['rna'].ix['binary_CAMP'].ix[keepers_o].dropna()
survival_and_stats(wnt, surv, figsize=(6,4))

# %%
res, feature_age, univariate, keepers_o, df = run_screen([hpv_inferred==1, two_hit==1, ras==1, wnt==1], [age, old])

# %%
res.sort('LR').head()
# Out:
#                                       LR  feature_p                                 fmla   hazzard  q_bonf  q_bh  q_all
# rna           binary_C10orf131  4.30e-04   9.99e-01  Surv(days, event) ~ feature + age\n  7.16e-10    0.80  0.80   4.83
# amplification 12q15             1.32e-03   1.40e-03  Surv(days, event) ~ feature + age\n  9.36e+00    0.03  0.03   0.17
# rna           binary_LOC400794  1.73e-03   7.22e-04  Surv(days, event) ~ feature + old\n  1.04e+02    3.24  1.00   6.00
#               binary_TAS2R4     2.10e-03   6.30e-03  Surv(days, event) ~ feature + old\n  1.19e+01    3.93  1.00   6.00
#               binary_AQP2       2.16e-03   9.99e-01  Surv(days, event) ~ feature + age\n  9.59e-10    4.04  1.00   6.00

# %%
mdm2 = data_sets['amplification']['12q15'].ix[keepers_o].dropna()
survival_and_stats(mdm2, surv, figsize=(6,4))

# %%
st = (1*(ras==0)).copy()
st.ix[true_index(st==1).intersection(true_index(mdm2==1))] = 2
st.ix[true_index(st==1).intersection(true_index(wnt==1))] = 3

# %%
survival_and_stats(st, clinical.survival.survival_5y, upper_lim=10, figsize=(5,4), order=[3,2,1,0])
plt.savefig('/cellar/users/agross/Desktop/Figures/subtype1_subtypes.pdf', tranparent=True)

# %%
res, feature_age, univariate, keepers_o, df = run_screen([hpv_inferred==1, two_hit==0], [age, old])

# %%
res.head()
# Out:
#                                     LR  feature_p                                               fmla  hazzard  q_all  q_bh  q_bonf
# mutation MUC5B                1.11e-04   8.90e-06                Surv(days, event) ~ feature + old\n     4.08   0.10  0.02    0.02
# clinical pre_2000             6.85e-04        NaN  Surv(days, event) ~ feature + old + feature:old\n      NaN   0.04  0.01    0.01
# mirna    binary_hsa-mir-548k  2.38e-03   2.35e-03                Surv(days, event) ~ feature + old\n     1.91   1.66  0.28    0.46
#          binary_hsa-mir-3170  2.88e-03   3.93e-03                Surv(days, event) ~ feature + old\n     1.94   1.66  0.28    0.55
#          binary_hsa-mir-137   5.01e-03   4.89e-03                Surv(days, event) ~ feature + old\n     1.81   1.92  0.32    0.96

# %%
muc5b = df.ix['mutation'].ix['MUC5B'].ix[keepers_o].dropna()
survival_and_stats(muc5b, surv, figsize=(6,4))

# %%
res, feature_age, univariate, keepers_o, df = run_screen([hpv_inferred==1, two_hit==0, muc5b==1], [age, old])

# %%
res.sort('q_all').head()
# Out:
#                               LR  feature_p                                               fmla  hazzard  q_bonf  q_bh  q_all
# clinical pre_2000           0.00        NaN                      Surv(days, event) ~ feature\n      NaN    0.02  0.02   0.14
#          invasion_inferred  0.01       0.11  Surv(days, event) ~ feature + old + feature:old\n     1.45    0.12  0.06   0.36
#          spread             0.03        NaN                Surv(days, event) ~ feature + old\n      NaN    0.24  0.08   0.49
#          lymph_status       0.05       0.04                Surv(days, event) ~ feature + old\n     1.67    0.45  0.08   0.50
#          spread_inferred    0.04       0.04                Surv(days, event) ~ feature + old\n     1.64    0.36  0.08   0.50

# %%
pre_2k = data_sets['clinical']['pre_2000'].ix[keepers_o].dropna()
survival_and_stats(pre_2k, surv, figsize=(6,4))

# %%
res, feature_age, univariate, keepers_o, df = run_screen(filter_features=[hpv_inferred==1, two_hit==0, muc5b==1], 
                                                         covariates=[age, old, pre_2k])

# %%
res, _, _, keepers_o, df = run_screen(filter_features=[hpv_inferred==1, two_hit==0, muc5b==1], 
                                      covariates=[age, old, pre_2k])

# %%
res.head()
# Out:
#                                     LR  feature_p                                               fmla  hazzard  q_all  q_bh  q_bonf
# mirna    binary_hsa-mir-548k  3.17e-05   1.65e-05  Surv(days, event) ~ feature + pre_2000 + featu...     3.83   0.04  0.01    0.01
#          binary_hsa-mir-3170  2.36e-03   3.56e-03           Surv(days, event) ~ feature + pre_2000\n     2.10   1.36  0.23    0.45
# clinical smoker               2.65e-03   4.92e-03  Surv(days, event) ~ feature + pre_2000 + featu...     0.18   0.11  0.02    0.02
#          drinker_inferred     4.10e-03   2.67e-03  Surv(days, event) ~ feature + pre_2000 + featu...     2.65   0.11  0.02    0.04
#          invasion_inferred    6.35e-03   1.31e-01  Surv(days, event) ~ feature + old + pre_2000 +...     1.43   0.11  0.02    0.06

# %%
mir548 = df.ix['mirna'].ix['binary_hsa-mir-548k'].ix[keepers_o].dropna()
survival_and_stats(mir548, surv, figsize=(6,4))

# %%
survival_and_stats(mir548.ix[true_index(pre_2k=='post_2000')], surv, figsize=(6,4))

# %%
st = (two_hit*1.).copy()
st.ix[true_index(st==1).intersection(true_index(muc5b==1))] = 2
st.ix[true_index(st==1).intersection(true_index(mir137==1))] = 3

# %%
survival_and_stats(st.dropna(), surv)

# %%
draw_survival_curves(clinical_processed.pre_2000=='pre_2000', surv, st, show=True, ann='p', show_legend=False)
# Out:
# <img src='data:image/png;base64,...'>

# %%
y = clinical_processed.year.dropna()
y = 1.*(y < 2008) + 1.*(y < 2000)
draw_survival_curves(y, surv, st, show=True, ann='p', show_legend=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
screen_feature(clinical_processed.pre_2000, kruskal_pandas, rna.pathways).head()
# Out:
#                                                       H         p     q
# BIOCARTA_IL5_PATHWAY                              14.03  1.80e-04  0.08
# KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM  11.46  7.10e-04  0.15
# BIOCARTA_BARR_MAPK_PATHWAY                         9.97  1.59e-03  0.19
# BIOCARTA_BARRESTIN_SRC_PATHWAY                     9.73  1.81e-03  0.19
# BIOCARTA_CREB_PATHWAY                              9.09  2.57e-03  0.22

# %%
batch = pd.Series({i: i[5:7] for i in age.index})

# %%
res, feature_age, univariate, keepers_o, df = run_screen([hpv_inferred==1, two_hit==0, muc5b==1], [age, old, pre_2k])

# %%
univariate.ix['rna'].sort('q_bonf').head(10)
# Out:
#                      hazard                                   LR                     concordance        q_bonf  q_bh
#                  exp(-coef)  exp(coef)  lower .95  upper .95  df     p   stat     q           se  stat
# binary_HTR4            0.31   3.18e+00       1.70       5.95   1  0.00  10.13  0.74         0.02  0.56    2.89  0.78
# real_CRISP1     26873861.46   3.72e-08       0.00        inf   1  0.00  10.01  0.74         0.01  0.53    3.08  0.78
# binary_FNDC7           0.08   1.23e+01       3.49      43.65   1  0.00   8.99  0.77         0.01  0.53    5.39  0.78
# binary_TLX3            0.39   2.54e+00       1.44       4.49   1  0.00   8.50  0.77         0.02  0.55    7.05  0.78
# real_GUCY2GP    26335597.42   3.80e-08       0.00        inf   1  0.00   8.39  0.77         0.01  0.53    7.45  0.78
# binary_C7orf52         0.45   2.21e+00       1.34       3.67   1  0.00   8.37  0.77         0.02  0.57    7.55  0.78
# binary_EPS8L3          0.36   2.79e+00       1.48       5.23   1  0.00   8.16  0.77         0.02  0.56    8.47  0.78
# binary_TFF1            0.47   2.12e+00       1.30       3.46   1  0.00   8.08  0.77         0.02  0.57    8.86  0.78
# binary_ADRA1A          0.47   2.11e+00       1.28       3.48   1  0.01   7.48  0.77         0.02  0.56   12.36  0.78
# binary_GBA3            0.49   2.05e+00       1.26       3.36   1  0.01   7.41  0.77         0.02  0.56   12.86  0.78

# %%
meth.df.groupby(level=1, axis=1).size()
# Out:
# 01    265
# 11     44
# dtype: int64

# %%
res.sort('LR').head()
# Out:
#                                     LR  feature_p                                               fmla  hazzard  q_all  q_bh  q_bonf
# mirna    binary_hsa-mir-548k  3.17e-05   1.65e-05  Surv(days, event) ~ feature + pre_2000 + featu...     3.83   0.04  0.01    0.01
#          binary_hsa-mir-3170  2.36e-03   3.56e-03           Surv(days, event) ~ feature + pre_2000\n     2.10   1.36  0.23    0.45
# clinical smoker               2.65e-03   4.92e-03  Surv(days, event) ~ feature + pre_2000 + featu...     0.18   0.11  0.02    0.02
#          drinker_inferred     4.10e-03   2.67e-03  Surv(days, event) ~ feature + pre_2000 + featu...     2.65   0.11  0.02    0.04
#          invasion_inferred    6.35e-03   1.31e-01  Surv(days, event) ~ feature + old + pre_2000 +...     1.43   0.11  0.02    0.06

# %%
res.ix['amplification']
# Out:
#             LR  feature_p                                               fmla  hazzard  q_all  q_bh  q_bonf
# 12p13.33  0.02       0.02           Surv(days, event) ~ feature + pre_2000\n     0.59   2.35  0.39    0.55
# 7q22.1    0.03       0.04  Surv(days, event) ~ feature + pre_2000 + featu...     1.81   2.35  0.39    0.78
# 15q26.3   0.05       0.04           Surv(days, event) ~ feature + pre_2000\n     1.62   2.46  0.41    1.23
# 17q12     1.00        NaN                     Surv(days, event) ~ pre_2000\n      NaN   6.00  1.00   25.00
# 6q12      1.00        NaN                     Surv(days, event) ~ pre_2000\n      NaN   6.00  1.00   25.00

# %%
res.ix['amplification']
# Out:
#             LR  feature_p                                               fmla  hazzard  q_all  q_bh  q_bonf
# 12p13.33  0.02       0.02           Surv(days, event) ~ feature + pre_2000\n     0.59   2.35  0.39    0.55
# 7q22.1    0.03       0.04  Surv(days, event) ~ feature + pre_2000 + featu...     1.81   2.35  0.39    0.78
# 15q26.3   0.05       0.04           Surv(days, event) ~ feature + pre_2000\n     1.62   2.46  0.41    1.23
# 17q12     1.00        NaN                     Surv(days, event) ~ pre_2000\n      NaN   6.00  1.00   25.00
# 6q12      1.00        NaN                     Surv(days, event) ~ pre_2000\n      NaN   6.00  1.00   25.00
