# %%
cd ../src
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
import os as os
import pickle as pickle
from pandas import DataFrame, Series

# %%
data_path = '/cellar/data/TCGA/Firehose__2012_10_24/ucsd_analyses/'
cancers = os.listdir(data_path)
report_ext = ''

# %%
def retreive_paths_for_datatype(data_type, report_ext, folder='Clinical', archive='ClinicalObject.p'):
    clinical = {}
    for cancer in cancers:
        clinical_obj = data_path + '/'.join([cancer, folder, data_type + report_ext,
                                             archive])
        if os.path.isfile(clinical_obj):
            clinical[cancer] = clinical_obj
    return clinical

# %%
data_types = ['mutation','amplification','deletion','expression','methylation']

# %%
def mut_module_raster(cluster_num, mut, ax=None):
    assert hasattr(mut, 'clustered')
    if ax is None:
        fig, ax = plt.subplots(1,1, figsize=(10,8))
    else:
        fig = fig.gcf()
    p = mut.assignments[mut.assignments == cluster_num].index
    s = mut.meta_matrix.ix[p].sum()
    x_order = sort(-s[s > 0]).index
    y_order = sort(mut.meta_matrix.ix[p].sum(1)).index
    plt.imshow(mut.meta_matrix.ix[y_order, x_order], aspect=8, 
               interpolation='Nearest', cmap=plt.cm.bone_r) #@UndefinedVariable
    ax.set_yticks(range(len(p)))
    ax.set_yticklabels(p);
    ax.hlines(arange(len(p)) + .5, 0, len(x_order), colors='grey', alpha=.3, lw=4)
    ax.set_xlabel('Patients');
    ax.axvline(x=(mut.clustered.ix[cluster_num] == 1).sum(), ymin=0, 
               ymax=len(y_order), color='r', alpha=.7, lw=5)
    ax.set_xbound(0, len(x_order))
    fig.tight_layout()
    return fig

# %%
def fancy_raster(df):
    fig, ax = plt.subplots(1,1, figsize=(12,8))
    ax.imshow(df, interpolation='Nearest', cmap=plt.cm.coolwarm_r)
    ax.set_yticks(range(len(df.index)))
    ax.set_yticklabels(df.index)
    ax.set_xticks(arange(len(df.columns)))
    ax.set_xticklabels(df.columns, rotation=360-90, ha='center');
    ax.hlines(arange(len(df.index)-1)+.5, -.5, len(df.columns)-.5, 
              color='white', lw=6)
    ax.vlines(arange(len(df.columns)-1)+.5, -.5, len(df.index)-.5, 
              color='white', lw=6)

# %%
paths = DataFrame({dt: retreive_paths_for_datatype(dt, report_ext, 'Globals', 'RateObject.p') for dt in data_types})
fancy_raster(paths != nan)

# %%
def get_field(obj_file, field):
    cancer = pickle.load(open(obj_file, 'rb'))
    return getattr(cancer, field)

def characterize(r, stat):
    try:
        best_pathway = r.p_pathways[stat].idxmin()
        p_pathway = r.p_pathways.ix[best_pathway, stat]
        q_pathway = r.q_pathways.ix[best_pathway, stat]
        sub_fdr_pathway = (r.q_pathways[stat] < .25).sum()
        if hasattr(r, 'p_genes'):
            best_gene = r.p_genes[stat].idxmin()
            p_gene = r.p_genes.ix[best_gene, stat]
            q_gene = r.q_genes.ix[best_gene, stat]
            sub_fdr_gene = (r.q_genes[stat] < .25).sum()
        else:
            best_gene = p_gene = q_gene = sub_fdr_gene = Series()
        res = Series(locals(), name=r.cancer)
        res = res[['best_gene', 'p_gene', 'q_gene', 'sub_fdr_gene',
                   'best_pathway', 'p_pathway', 'q_pathway', 'sub_fdr_pathway']]
    except:
        return None
    return res

def get_stat_df(reports, stat):
    df = DataFrame()
    for cancer, report in reports.iteritems():
        if stat in report.q_pathways:
            res = characterize(report, stat)
            if res is not None:
                df = df.join(res, how='outer')
    df = df.T
    df = df.ix[df[['p_gene','p_pathway']].min(1).order().index]
    return df

# %%
s = paths.ix[0,0]
r = pickle.load(open(s, 'rb'))

# %%
results = DataFrame({dt: paths[dt].map(lambda s: pickle.load(open(s, 'rb')), na_action='ignore') for dt in data_types})

# %%
def get_stat_df(reports, stat):
    df = DataFrame()
    for dt, report in reports.iteritems():
        if stat in report.q_pathways:
            res = characterize(report, stat)
            if res is not None:
                df = df.join(Series(res, name=dt), how='outer')
    df = df.T
    return df
    df = df.ix[df[['p_gene','p_pathway']].min(1).order().index]
    return df

# %%
import scipy.cluster.hierarchy as sch
import scipy.spatial.distance as dist

# %%
def fancy_raster(df, cluster=False):
    if cluster:
        d = dist.pdist(df)
        D = dist.squareform(d)
        Y = sch.linkage(D)
        Z = sch.dendrogram(Y, no_plot=True)
        order = Z['leaves']
        df = df.ix[order, order]
        
    fig, ax = plt.subplots(1,1, figsize=(12,8))
    ax.imshow(df, interpolation='Nearest', cmap=plt.cm.coolwarm_r)
    ax.set_yticks(range(len(df.index)))
    ax.set_yticklabels(df.index)
    ax.set_xticks(arange(len(df.columns)))
    ax.set_xticklabels(df.columns, rotation=360-90, ha='center');
    ax.hlines(arange(len(df.index)-1)+.5, -.5, len(df.columns)-.5, 
              color='white', lw=6)
    ax.vlines(arange(len(df.columns)-1)+.5, -.5, len(df.index)-.5, 
              color='white', lw=6)
    
    if cluster:
        icoord = array(Z['icoord']) - array(Z['icoord']).min()
        icoord = icoord * ((len(Z['leaves']) - 1) / icoord.max())
    
        dcoord = -1*array(Z['dcoord']) - .7b   
        for i,z,c in zip(icoord, dcoord, Z['color_list']):
            ax.plot(i,z,color=c, lw=2, alpha=.8)
            
        ax.tick_params(axis='x', top='off')
        ax.set_frame_on(False)

# %%
r = results.ix['COAD','mutation']
fancy_raster(r.clinical.corr().dropna(axis=[0,1], how='all'), cluster=True)

# %%
from Reports.Figures import *

# %%
r.clinical.rate.order().dropna().plot()

# %%
r.clinical.rate_sil.order()
# Out:
# TCGA-A5-A0GD    0.000000e+00
# TCGA-B5-A1MU    3.260021e-08
# TCGA-B5-A0K0    6.520041e-08
# TCGA-AP-A05D    9.780062e-08
# TCGA-AP-A052    1.304008e-07
# TCGA-AP-A0LO    1.304008e-07
# TCGA-BS-A0U9    1.304008e-07
# TCGA-A5-A0GX    1.630010e-07
# TCGA-AP-A1DQ    1.630010e-07
# TCGA-B5-A0JS    1.630010e-07
# TCGA-B5-A11M    1.630010e-07
# TCGA-BS-A0V7    1.630010e-07
# TCGA-D1-A16Q    1.630010e-07
# TCGA-D1-A17N    1.630010e-07
# TCGA-FI-A2D2    1.630010e-07
# ...
# TCGA-FI-A2D6   NaN
# TCGA-FI-A2EU   NaN
# TCGA-FI-A2EY   NaN
# TCGA-FI-A2F4   NaN
# TCGA-FI-A2F9   NaN
# TCGA-FI-A3PV   NaN
# TCGA-FI-A3PX   NaN
# TCGA-H5-A2HR   NaN
# TCGA-K6-A3WQ   NaN
# TCGA-KJ-A3U4   NaN
# TCGA-KP-A3VZ   NaN
# TCGA-KP-A3W0   NaN
# TCGA-KP-A3W1   NaN
# TCGA-KP-A3W3   NaN
# TCGA-KP-A3W4   NaN
# Name: rate_sil, Length: 500

# %%
r = results.ix['UCEC','mutation']
violin_plot_pandas(r.hit_matrix.ix['KRAS'], r.clinical['rate']);

# %%
r = results.ix['UCEC','mutation']
vec = r.hit_matrix.ix[r.gene_sets['REACTOME_E2F_ENABLED_INHIBITION_OF_PRE_REPLICATION_COMPLEX_FORMATION']].sum()
violin_plot_pandas(vec > 0, r.clinical['rate']);

# %%
def filter_bad_pathways(self, gene_lookup):
    for clin_type, p_vals in self.p_genes.iteritems():
        for gene in set(p_vals.index).intersection(set(gene_lookup)):
            for pathway in gene_lookup[gene]:
                if ((pathway in self.q_pathways[clin_type]) and 
                   (p_vals[gene] < self.p_pathways[clin_type][pathway]) and
                    (self.hit_matrix.ix[gene].sum() > 
                     self.meta_matrix.ix[pathway].sum()*.5)):
                    self.p_pathways[clin_type][pathway] = nan
        self.q_pathways[clin_type] = bhCorrection(self.p_pathways[clin_type])

# %%
from Data.Pathways import read_in_pathways
from Processing.Clinical import ClinicalObject

PATHWAY_FILE = '/cellar/users/agross/Data/GeneSets/c2.cp.v3.0.symbols_edit.csv'
gene_sets, gene_lookup = read_in_pathways(PATHWAY_FILE)
from Processing.Helpers import *

# %%
for a,l in results.iteritems():
    for b,r in l.iteritems():
        if type(r) == 'float':
            filter_bad_pathways(r, gene_lookup)

# %%
r = results.ix['OV','mutation']

# %%
[i for i in r.q_pathways.index if 'TGF' in i]
# Out:
# ['BIOCARTA_TGFB_PATHWAY',
#  'KEGG_TGF_BETA_SIGNALING_PATHWAY',
#  'REACTOME_SIGNALING_BY_TGF_BETA']

# %%
r.clinical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 567 entries, TCGA-04-1331 to TCGA-61-2614
# Data columns:
# AMAR                 0  non-null values
# exp_pc1              263  non-null values
# exp_pc2              263  non-null values
# methylation_age      0  non-null values
# methylation_pc1      0  non-null values
# methylation_pc2      0  non-null values
# chrom_instability    562  non-null values
# gene_amp             562  non-null values
# gene_amp_high        562  non-null values
# gene_del             562  non-null values
# gene_del_homo        562  non-null values
# lesion_amp           562  non-null values
# lesion_amp_high      562  non-null values
# lesion_del           562  non-null values
# lesion_del_homo      562  non-null values
# rate_dbsnp           316  non-null values
# rate_sil             316  non-null values
# rate_non             316  non-null values
# *CpG->T              316  non-null values
# *Cp(A_C_T)->T        316  non-null values
# C->(G_A)             316  non-null values
# A->mut               316  non-null values
# indel+null           316  non-null values
# double_null          316  non-null values
# rate                 316  non-null values
# dtypes: float64(25)

# %%
get_stat_df(results.ix['KIRC'].dropna(), 'chrom_instability').sort(columns='q_pathway')
# Out:
#                best_gene        p_gene        q_gene sub_fdr_gene  \
# expression            []            []            []           []
# methylation           []            []            []           []
# mutation            MUC4   0.003008129     0.1456454            3
# amplification    7q36.3   5.392409e-20  1.078482e-19            2
# deletion       LOC285326  0.0005616603   0.004767876          500
#
#                                             best_pathway     p_pathway  \
# expression                         BIOCARTA_EIF2_PATHWAY  1.844049e-27
# methylation    REACTOME_CALCITONIN_LIKE_LIGAND_RECEPTORS   1.53326e-14
# mutation                         BIOCARTA_HIVNEF_PATHWAY  5.874255e-06
# amplification                   BIOCARTA_ASBCELL_PATHWAY  7.865495e-06
# deletion                   REACTOME_MEMBRANE_TRAFFICKING  0.0002182143
#
#                   q_pathway sub_fdr_pathway
# expression     5.882518e-25             294
# methylation    3.495833e-12              87
# mutation        0.004834512               7
# amplification   0.006402513             376
# deletion         0.01417539             526

# %%
get_stat_df(results.mutation.dropna(), 'rate_sil').sort(columns='q_pathway')
# Out:
#      best_gene        p_gene        q_gene sub_fdr_gene  \
# UCEC      ROS1  3.303408e-61  1.651704e-58          499
# LAML      IDH2  0.0008389738    0.01090666            1
# COAD    CEP290   1.61513e-29  7.994895e-27          489
# BRCA       TTN  2.517628e-15  3.147035e-13           93
# STAD     AGAP1  4.177424e-24  2.088712e-21          492
# GBM       EVPL  2.636099e-10  7.676441e-09          101
# OV         TTN  2.942704e-08  1.177081e-06           26
# READ     CSMD3  0.0007018094   0.004931933           10
# LUSC   FAM123C  2.930059e-11   1.46503e-08          319
# LUAD     FCRL5  3.271096e-09  1.635548e-06          389
# KIRC      MUC4  2.249009e-08  1.709247e-06           26
# THCA      HRAS     0.2461796     0.9705352            0
# BLCA       TTN    0.05304361     0.1060872            2
# CESC    PIK3CA    0.01653341    0.03306681            2
# PRAD     MUC16     0.1215335     0.3646006            0
#
#                                            best_pathway     p_pathway  \
# UCEC  REACTOME_E2F_ENABLED_INHIBITION_OF_PRE_REPLICA...   1.12979e-55
# LAML                        REACTOME_GLUCOSE_METABOLISM  2.177513e-43
# COAD                  REACTOME_PURINE_SALVAGE_REACTIONS   1.42667e-24
# BRCA                  KEGG_STEROID_HORMONE_BIOSYNTHESIS  1.717426e-21
# STAD                               BIOCARTA_P27_PATHWAY  4.113265e-20
# GBM                                BIOCARTA_ETC_PATHWAY  1.121547e-19
# OV                         REACTOME_PLATELET_ACTIVATION  1.252372e-14
# READ                             BIOCARTA_TALL1_PATHWAY  1.365157e-08
# LUSC                       BIOCARTA_TCAPOPTOSIS_PATHWAY  6.480168e-10
# LUAD                               BIOCARTA_RAB_PATHWAY  2.154295e-09
# KIRC        KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION  2.115365e-08
# THCA          REACTOME_DUAL_INCISION_REACTION_IN_TC_NER  5.895071e-08
# BLCA         REACTOME_RECYCLING_OF_BILE_ACIDS_AND_SALTS  4.048931e-07
# CESC                              BIOCARTA_ARAP_PATHWAY  5.457878e-07
# PRAD  REACTOME_ELONGATION_AND_PROCESSING_OF_CAPPED_T...  3.559336e-05
#
#          q_pathway sub_fdr_pathway
# UCEC  9.399855e-53             828
# LAML  1.099644e-40             442
# COAD   1.18699e-21             821
# BRCA  1.423746e-18             685
# STAD  3.422237e-17             832
# GBM   8.681268e-17             804
# OV    1.023188e-11             561
# READ  4.832375e-07             644
# LUSC  5.372059e-07             746
# LUAD  1.744244e-06             828
# KIRC  1.113979e-05             550
# THCA  3.424006e-05             245
# BLCA  0.0001552841             449
# CESC  0.0002990221             534
# PRAD   0.009414443             124

# %%
r = results.ix['OV']

# %%
def characterize(q_vec):
    name = q_vec.name
    best = q_vec.idxmin

# %%
stat = 'event_free_survival'

# %%
r.ix['mutation'].q_pathways.dropna(axis=1, how='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, BIOCARTA_41BB_PATHWAY to WNT_SIGNALING
# Data columns:
# tumor_t1t2               817  non-null values
# new_tumor                817  non-null values
# event_free_survival      817  non-null values
# gender                   817  non-null values
# age                      817  non-null values
# rate                     817  non-null values
# metastatic_recurrence    817  non-null values
# histo_g1g2               817  non-null values
# karnofsky_performance    776  non-null values
# survival                 817  non-null values
# neo_status               817  non-null values
# dtypes: float64(11)

# %%
df = DataFrame()
for cancer, report in reports.iteritems():
    if 'event_free_survival' in report.q_pathways:
        stat = 'event_free_survival'
    else:
        stat = 'survival'
    df = df.join(characterize(report, stat), how='outer')
df = df.T
df = df.ix[df[['p_gene','p_pathway']].min(1).order().index]
df
# Out:
#          best_gene        p_gene       q_gene sub_fdr_gene                                       best_pathway     p_pathway    q_pathway sub_fdr_pathway
# UCEC          FAT3  2.238134e-05   0.01119067            4                         SA_MMP_CYTOKINE_CONNECTION             0            0               5
# LUAD           APC  2.174838e-06  0.001087419            1               REACTOME_G_ALPHA_S_SIGNALLING_EVENTS   0.001322901     0.368582               0
# LUSC        NCKAP5  0.0004360212   0.07708433            4                   REACTOME_GLUTATHIONE_CONJUGATION  1.445905e-05   0.01198655               2
# LAML        DNMT3A   0.002775481   0.03608126            2                         KEGG_WNT_SIGNALING_PATHWAY  2.286132e-05  0.008303663              32
# STAD         RNF43  0.0007667581    0.3392525            0                            BIOCARTA_STRESS_PATHWAY  4.499237e-05   0.03743365               1
# COADREAD    PDGFRA  7.412243e-05   0.03706121            6                           REACTOME_GLUCURONIDATION  0.0001579322     0.119974               2
# GBM       TMEM132D  0.0005166609   0.05889934            1                 REACTOME_DEATH_RECEPTOR_SIGNALLING  7.727443e-05   0.03930162              15
# OV            TP53    0.03718328    0.6895539            0  REACTOME_NA_CL_DEPENDENT_NEUROTRANSMITTER_TRAN...  0.0001029727   0.05135286              27
# BRCA          MUC2   0.006186986    0.6415332            0  REACTOME_ACTIVATION_OF_KAINATE_RECEPTORS_UPON_...  0.0007044624    0.5839993               0
# KIRC          BAP1   0.004317765    0.3281502            0                      ST_T_CELL_SIGNAL_TRANSDUCTION   0.005235335    0.9998964               0
# PRAD         MUC16          1.23            1            0                              BIOCARTA_ACE2_PATHWAY          1.23            1               0
# THCA          BRAF          1.23            1            0                              BIOCARTA_ACE2_PATHWAY          1.23            1               0

# %%
get_stat_df(results.mutation.dropna(), 'neo_status')
# Out:
#     best_gene      p_gene     q_gene sub_fdr_gene                     best_pathway     p_pathway  q_pathway sub_fdr_pathway
# OV      HUWE1  0.07059237  0.9240645            0   REACTOME_CENTROSOME_MATURATION  0.0007870428  0.5521016               0
# GBM     ABCC9   0.1058659          1            0  REACTOME_TOLL_RECEPTOR_CASCADES   0.008672318          1               0

# %%
get_stat_df(results.mutation.dropna(), 'tumor_t1t2')
# Out:
#      best_gene        p_gene        q_gene sub_fdr_gene                                       best_pathway     p_pathway     q_pathway sub_fdr_pathway
# UCEC      TP53  6.391702e-21  3.195851e-18           26                                BIOCARTA_RB_PATHWAY  8.487612e-18  4.288374e-15             227
# BRCA      CDH1    0.02244412     0.9353829            0                               BIOCARTA_EIF_PATHWAY  9.971052e-05    0.08266002               1
# KIRC      MLL2   0.005354113     0.4069126            0                    KEGG_JAK_STAT_SIGNALING_PATHWAY  0.0001059635    0.08720796               2
# LUAD     SYNE1   0.004109563     0.6904606            0  REACTOME_CDC6_ASSOCIATION_WITH_THE_ORC:ORIGIN_...  0.0002356184    0.09801724               3
# STAD     DIP2C  0.0009624041      0.481202            0                          BIOCARTA_CYTOKINE_PATHWAY   0.005653429             1               0
# LUSC    GRIN2A   0.001098355     0.3866124            0  REACTOME_REGULATION_OF_INSULIN_LIKE_GROWTH_FAC...   0.003140553     0.8820477               0
# THCA      BRAF    0.01115319    0.06691914            1            KEGG_VASCULAR_SMOOTH_MUSCLE_CONTRACTION   0.004335252     0.8390701               0
# OV       AHNAK             1             1            0                              BIOCARTA_41BB_PATHWAY             1             1               0

# %%
get_stat_df(reports, 'age')
# Out:
#          best_gene        p_gene        q_gene sub_fdr_gene                                       best_pathway     p_pathway     q_pathway sub_fdr_pathway
# GBM           IDH1  1.327294e-09  1.513115e-07            1              REACTOME_PEROXISOMAL_LIPID_METABOLISM  1.965245e-06  0.0009488089              20
# KIRC         AKAP9   0.002343982     0.1524999            5                KEGG_NEUROTROPHIN_SIGNALING_PATHWAY  8.593001e-08   7.07204e-05             194
# STAD        ANAPC1   9.21281e-05    0.04050352          195                               BIOCARTA_NKT_PATHWAY  1.638637e-05   0.004313956             695
# UCEC          TP53  2.016264e-05    0.01008132            7                        ST_WNT_BETA_CATENIN_PATHWAY  3.579186e-05    0.01846404              35
# COADREAD     TRPA1   0.002092594      0.744172            0                               BIOCARTA_TCR_PATHWAY  0.0001087458    0.07947668              98
# OV            GLI2   0.008989382     0.3595753            0  REACTOME_CYCLIN_E_ASSOCIATED_EVENTS_DURING_G1_...  0.0001152638    0.03010933              38
# THCA            TG     0.4193636      0.936251            0        REACTOME_CLASS_B2_SECRETIN_FAMILY_RECEPTORS  0.0001178675    0.06352954              37
# BRCA        MAP3K1  0.0007536852    0.09421065            4       REACTOME_SEMA3A_PAK_DEPENDENT_AXON_REPULSION  0.0001206802    0.03926586              65
# LUAD         POTEH  0.0007016507     0.3508253            0  REACTOME_REMOVAL_OF_DNA_PATCH_CONTAINING_ABASI...  0.0003910529      0.325356               0
# LAML          IDH2   0.005901353    0.03706869            6                                    KEGG_CELL_CYCLE  0.0004122541     0.1244432              42
# LUSC         ITPR2   0.002318841     0.5459445            0  REACTOME_PROTEOLYTIC_CLEAVAGE_OF_SNARE_COMPLEX...   0.002324489     0.8280104               0
# PRAD           TTN    0.03868743     0.1160623            1                      REACTOME_INFLUENZA_LIFE_CYCLE   0.004802276     0.7265076               0

# %%
get_stat_df(reports, 'rate')
# Out:
#          best_gene        p_gene        q_gene sub_fdr_gene                                  best_pathway     p_pathway q_pathway sub_fdr_pathway
# COADREAD       NEB  1.927143e-25  9.635713e-23          497      REACTOME_INTRINSIC_PATHWAY_FOR_APOPTOSIS  2.561553e-50         0             184
# UCEC          PCLO  4.776682e-39  2.388341e-36          499                  REACTOME_EGFR_DOWNREGULATION  2.907942e-42    0.0008             113
# BRCA          TP53  2.031248e-16   2.53906e-14          102          REACTOME_OLFACTORY_SIGNALING_PATHWAY  1.556302e-29         0             136
# STAD         HERC2  1.026256e-20  5.131278e-18          497  REACTOME_AUTODEGRADATION_OF_CDH1_BY_CDH1_APC   5.77336e-26         0             147
# LUAD         ZFHX4  1.158819e-17  5.794093e-15          493                         KEGG_ABC_TRANSPORTERS  1.698336e-20     0.004              88
# GBM           EVPL  7.495071e-13  8.544381e-11          103  REACTOME_APOPTOSIS_INDUCED_DNA_FRAGMENTATION  1.754473e-19     0.012             194
# LUSC         USH2A  1.823997e-06   0.000419565          426                      REACTOME_GENE_EXPRESSION  9.678499e-17      0.06              99
# OV             TTN  1.256336e-07  5.025343e-06           24                KEGG_CALCIUM_SIGNALING_PATHWAY  2.135454e-16     0.012             142
# KIRC           TTN  3.880073e-09  2.782066e-07           41                           REACTOME_HEMOSTASIS  2.929797e-14     0.012             233
# LAML          IDH2    0.00110271    0.01433523            4                      REACTOME_GENE_EXPRESSION  2.600578e-11     0.012             105
# PRAD           TTN    0.07148941     0.1894832            2                           KEGG_TIGHT_JUNCTION  1.078004e-07         0             140
# THCA           TTN     0.2212007     0.5612662            0           REACTOME_SIGNALING_IN_IMMUNE_SYSTEM  6.570269e-07      0.06             191

# %%
best, p, q, sub_fdr
# Out:
# ('REACTOME_NA_CL_DEPENDENT_NEUROTRANSMITTER_TRANSPORTERS',
#  0.0001029727138479597,
#  0.051352860224893528,
#  27)

# %%
np.sort(r.q_pathways.event_free_survival)
# Out:
# BIOCARTA_TGFB_PATHWAY                                           0.051353
# REACTOME_NA_CL_DEPENDENT_NEUROTRANSMITTER_TRANSPORTERS          0.051353
# REACTOME_P130CAS_LINKAGE_TO_MAPK_SIGNALING_FOR_INTEGRINS        0.051353
# REACTOME_AMINE_DERIVED_HORMONES                                 0.070819
# REACTOME_TIGHT_JUNCTION_INTERACTIONS                            0.070819
# BIOCARTA_SODD_PATHWAY                                           0.088431
# REACTOME_ASSOCIATION_OF_TRIC_CCT_WITH_TARGET_PROTEINS_DURING_BIOSYNTHESIS    0.088431
# REACTOME_NOTCH_HLH_TRANSCRIPTION_PATHWAY                        0.088431
# REACTOME_P53_INDEPENDENT_DNA_DAMAGE_RESPONSE                    0.088431
# REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3G                   0.088431
# ST_ERK1_ERK2_MAPK_PATHWAY                                       0.088431
# REACTOME_AMINE_COMPOUND_SLC_TRANSPORTERS                        0.109249
# REACTOME_DEATH_RECEPTOR_SIGNALLING                              0.109249
# REACTOME_GRB2_SOS_PROVIDES_LINKAGE_TO_MAPK_SIGNALING_FOR_INTERGRINS_    0.109249
# REACTOME_NRIF_SIGNALS_CELL_DEATH_FROM_THE_NUCLEUS               0.109249
# ...
# REACTOME_E2F_ENABLED_INHIBITION_OF_PRE_REPLICATION_COMPLEX_FORMATION    0.998479
# REACTOME_FANCONI_ANEMIA_PATHWAY                                 0.998479
# REACTOME_GLYCOGEN_BREAKDOWN_GLYCOGENOLYSIS                      0.998479
# REACTOME_GLYCOLYSIS                                             0.998479
# REACTOME_OLFACTORY_SIGNALING_PATHWAY                            0.998479
# REACTOME_OTHER_SEMAPHORIN_INTERACTIONS                          0.998479
# REACTOME_REGULATION_OF_PYRUVATE_DEHYDROGENASE_COMPLEX           0.998479
# REACTOME_TIE2_SIGNALING                                         0.998479
# REACTOME_UNWINDING_OF_DNA                                       0.998479
# SA_G2_AND_M_PHASES                                              0.998479
# SA_PTEN_PATHWAY                                                 0.998479
# ST_IL_13_PATHWAY                                                0.998479
# ST_INTERLEUKIN_13_PATHWAY                                       0.998479
# KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY                          0.998843
# REACTOME_ETHANOL_OXIDATION                                      0.999604
# Name: event_free_survival, Length: 817

# %%
reports
# Out:
# {'BRCA': <Processing.Clinical.ClinicalObject at 0x19449d50>,
#  'COADREAD': <Processing.Clinical.ClinicalObject at 0x8893b50>,
#  'GBM': <Processing.Clinical.ClinicalObject at 0x6ed06d0>,
#  'KIRC': <Processing.Clinical.ClinicalObject at 0x17816550>,
#  'LAML': <Processing.Clinical.ClinicalObject at 0xa2f10d0>,
#  'LUAD': <Processing.Clinical.ClinicalObject at 0x12a12ad0>,
#  'LUSC': <Processing.Clinical.ClinicalObject at 0x4dc5910>,
#  'OV': <Processing.Clinical.ClinicalObject at 0x1c97b410>,
#  'PRAD': <Processing.Clinical.ClinicalObject at 0x14e9f4d0>,
#  'STAD': <Processing.Clinical.ClinicalObject at 0xe9ff450>,
#  'THCA': <Processing.Clinical.ClinicalObject at 0x51fe050>,
#  'UCEC': <Processing.Clinical.ClinicalObject at 0xea17b10>}
