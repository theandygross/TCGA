# %% [markdown]
# #HNSC Copy Number Event Screen
# * This is a screen for survival associated copy-number event features.
# * I am using the results of the [GISTIC2](http://www.broadinstitute.org/cgi-bin/cancer/publications/pub_paper.cgi?mode=view&paper_id=216&p=t) analysis for the event calls.
# * Briefly their encoding for CN events is as follows:
#     * -2 homozygous loss
#     * -1 heterozygous loss
#     * 0 diploid
#     * 1 amplification
#     * 2 high grade amplification
# * There are two types of features:
#     * Lesions are events that occur on a broad level
#     * Gene level events are localized to a gene
# * Since gene level events on a shared copy-number band are usually highly correlated I combine them for the sake of limiting the number of tests preformed.

# %%
cd ../src
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
from Processing.Imports import *

# %% [markdown]
# ##Load Firehose Data

# %%
run = get_run('/cellar/data/TCGA/Firehose__2013_04_21/', 'Run_all')

cancer = run.load_cancer('HNSC')
clinical = cancer.load_clinical()
global_vars = cancer.load_global_vars()

mut = cancer.load_data('Mutation')
mut.uncompress()
meth = cancer.load_data('Methylation')
cn = cancer.load_data('CN_broad')
cn.uncompress()
rna = cancer.load_data('mRNASeq')
rppa  = cancer.load_data('RPPA')
mirna = cancer.load_data('miRNASeq')
age = clinical.clinical.age.astype(float)

hpv_all = pd.read_csv('/cellar/users/agross/hpv_summary_3_20_13_distribute.csv', index_col=0)
hpv = hpv_all.Molecular_HPV.map({0:'HPV-', 1:'HPV+'})
hpv.name = 'HPV'

# %%
from Data.ProcessClinical import format_survival_from_data_portal
path  = '/cellar/users/agross/Data/TCGA/HNSC_Followup/'
survival, timeline = format_survival_from_data_portal(path, cancer.name)
clinical.survival = survival
clinical.artificially_censor(5)
age = timeline.age

# %%
filters = pd.concat([age>85], axis=1)
clinical_filter = filters.sum(1) == 0
keepers = true_index(clinical_filter)

# %%
surv = clinical.survival.survival_5y

# %% [markdown]
# ####Form expression and methylation features without HPV
# * HPV has a big influence on expression, here I am creating a second set of features without HPV
# * I use this sparingly but it helps to tease out wheter an association is due to a underlying relationship with HPV

# %%
from Initialization.InitializeReal import RealDataset

filters = pd.concat([age>=85, hpv!='HPV+'], axis=1)
clinical_filter2 = filters.sum(1) > 0
patients = true_index(clinical_filter2)
rna_no_hpv = RealDataset(run, cancer, 'mRNASeq', patients)
meth_no_hpv = RealDataset(run, cancer, 'Methylation', patients)

# %% [markdown]
# #Exploration of Chromosomal Instability
# * We know chromosomal instability has a large role in cancer, lets see if we can find any good correlates
# * For chromosomal instability I'm using the total number of amplified or deleted lesions

# %%
cin = (global_vars.cna.lesion_del + global_vars.cna.lesion_amp)
cin.name = 'Chromosomal Instability'

# %%
draw_survival_curves(to_quants(cin, std=1, labels=True), surv, hpv, show=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-2f5556a2c716> in <module>()
# ----> 1 draw_survival_curves(to_quants(cin, std=1, labels=True), surv, hpv, show=True)
#
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src/Figures/R_Wrappers.pyc in draw_survival_curves(feature, surv, assignment, filename, show, title, labels, colors, ann, show_legend, q, std)
#      65         f = feature.ix[assignment[assignment==value].index]
#      66         if len(f.unique()) > 1:
# ---> 67             plot_me(f, name(value))
#      68
#      69     if show_legend == True:
#
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src/Figures/R_Wrappers.pyc in plot_me(sub_f, label)
#      47             sub_f = to_quants(sub_f, q=q, std=std)
#      48         m = get_cox_ph_ms(surv, sub_f, return_val='model', formula=fmla)
# ---> 49         r_data = m.rx2('call')[2]
#      50         s = survival.survdiff(fmla, r_data)
#      51         p = str(s).split('\n\n')[-1].strip().split(', ')[-1]
#
# /cellar/users/agross/semillon/anaconda2/lib/python2.7/site-packages/pandas-0.12.0.dev_-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getattr__(self, name)
#    2083             return self[name]
#    2084         raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2085                              (type(self).__name__, name))
#    2086
#    2087     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rx2'

# %%
violin_plot_pandas(hpv, cin)

# %%
screen_feature(cin, spearman_pandas, global_vars.T)
# Out:
#                             rho          p   q
# (cna, lesion_amp)          1.00   0.00e+00 NaN
# (cna, gene_amp)            0.91  1.28e-138 NaN
# (cna, chrom_instability)   0.68   5.96e-50 NaN
# (cna, lesion_amp_high)     0.62   2.27e-38 NaN
# (cna, gene_del)            0.46   5.63e-20 NaN
# (cna, gene_del_homo)       0.37   8.62e-13 NaN
# (cna, gene_amp_high)       0.26   8.19e-07 NaN
# (mutation, A->mut)         0.21   1.70e-04 NaN
# (methylation, pc2)        -0.20   6.00e-04 NaN
# (mutation, *Cp(A_C_T)->T) -0.19   8.45e-04 NaN
# (methylation, pc1)         0.15   1.08e-02 NaN
# (mutation, rate_non)       0.09   1.10e-01 NaN
# (mutation, indel+null)     0.08   1.53e-01 NaN
# (mutation, double_null)   -0.08   1.53e-01 NaN
# (mutation, rate_sil)       0.07   2.15e-01 NaN
# (mRNASeq, pc2)             0.07   2.37e-01 NaN
# (mutation, rate_dbsnp)     0.06   2.94e-01 NaN
# (mutation, *CpG->T)       -0.04   5.06e-01 NaN
# (mutation, C->(G_A))       0.02   7.50e-01 NaN
# (mRNASeq, pc1)             0.02   7.61e-01 NaN
# (cna, lesion_del_homo)      NaN        NaN NaN
# (cna, lesion_del)           NaN        NaN NaN

# %%
s = screen_feature(cin, spearman_pandas, rppa.features)
s.head()
# Out:
#                                                                                  rho  p     q
# REACTOME_DEADENYLATION_OF_MRNA                                                 -0.22  0  0.15
# REACTOME_METABOLISM_OF_MRNA                                                    -0.22  0  0.15
# REACTOME_TRANSPORT_OF_THE_SLBP_INDEPENDENT_MATURE_MRNA                         -0.22  0  0.15
# REACTOME_TRANSPORT_OF_MATURE_MRNA_DERIVED_FROM_AN_INTRON_CONTAINING_TRANSCRIPT -0.22  0  0.15
# REACTOME_METABOLISM_OF_RNA                                                     -0.22  0  0.15

# %%
s = screen_feature(cin, spearman_pandas, rna_no_hpv.features)
s.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a324f2b8042b> in <module>()
# ----> 1 s = screen_feature(cin, spearman_pandas, rna_no_hpv.features)
#       2 s.head()
#
# NameError: name 'rna_no_hpv' is not defined

# %%
fig, axs = subplots(1,2,figsize=(12,4))
series_scatter(cin, rna_no_hpv.features.ix['BIOCARTA_CASPASE_PATHWAY'], ax=axs[0])
rna_no_hpv.pc_genes['BIOCARTA_CASPASE_PATHWAY'].order().plot(kind='bar')

# %%
s = screen_feature(cin, spearman_pandas, meth_no_hpv.features)
s.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-22967b8e288b> in <module>()
# ----> 1 s = screen_feature(cin, spearman_pandas, meth_no_hpv.features)
#       2 s.head()
#
# NameError: name 'meth_no_hpv' is not defined

# %% [markdown]
# * We know that TP53 hits the cell cycle and messes with replication
# * PDRM9 regulations recombination in mitotic cell division
# * HRAS and CASP8 are highly overlapping, HRAS has fewer patients but bigger effect

# %%
df = mut.df.ix[(mut.df.sum(1).order() > 5)]
s = screen_feature(cin, spearman_pandas, df)
s.head(10)
# Out:
#          rho         p         q
# TP53    0.30  6.67e-08  1.14e-04
# CASP8  -0.22  1.19e-04  1.02e-01
# PIK3CA -0.19  9.55e-04  4.79e-01
# PLCB1   0.19  1.12e-03  4.79e-01
# USP29  -0.18  1.78e-03  6.11e-01
# FAM83G -0.18  2.24e-03  6.27e-01
# CDKL5   0.17  2.88e-03  6.27e-01
# HRAS   -0.17  2.93e-03  6.27e-01
# OR5D18 -0.17  3.86e-03  6.40e-01
# PRDM9   0.17  3.90e-03  6.40e-01

# %% [markdown]
# ####Screening for copy-number correlates of chromosomal instability
# * These are all fragile sites usually around large genes ( http://www.sciencedirect.com/science/article/pii/S0304383505008232, http://www.sciencedirect.com/science/article/pii/S0168952512000303 )

# %%
tt = lambda a,b: kruskal_pandas(b,a)
screen_feature(cin, tt, cn.features.ix['Deletion'] < 0).head()
# Out:
#                       H         p         q
# (5q11.2, Lesion)  67.27  2.37e-16  1.04e-14
# (3p12.2, Lesion)  65.11  7.08e-16  1.56e-14
# (3p14.2, Lesion)  63.36  1.72e-15  2.53e-14
# (3p25.3, Lesion)  58.11  2.48e-14  2.73e-13
# (5q35.3, Lesion)  53.47  2.63e-13  2.31e-12

# %%
tt = lambda a,b: kruskal_pandas(b,a)
df = cn.features.ix['Amplification']
df.index = df.index.get_level_values(0)
screen_feature(cin, tt, df > 0).head()
# Out:
#                H         p         q
# 8q24.21   111.21  5.33e-26  1.33e-24
# 7p11.2    109.05  1.58e-25  1.98e-24
# 12p13.33  100.12  1.44e-23  1.20e-22
# 2q11.2     98.13  3.91e-23  2.45e-22
# 5p15.33    96.80  7.66e-23  3.83e-22

# %%
fig, axs = subplots(1,2, figsize=(12,4))
violin_plot_pandas(cn.features.ix[('Deletion','5q11.2','Lesion')], cin, ax=axs[0])
violin_plot_pandas(cn.features.ix[('Deletion','3p14.2','Lesion')], cin, ax=axs[1])

# %% [markdown]
# #Run Copy Number Data

# %% [markdown]
# ##Screen for survival associated features
# * First pass is a log-rank test on all features
# * Next we run the full model with covariates
# * We use a combination of the two tests to filter down the candidate associations and pull out the top biomarkers
# * Here the log-rank test is really underpowered.
# * The deletion-rate covariate helps a lot to explain away many of the patients who have very high mutation rates and good prognosis.
# * The age covariate often explains patients who are in a good-prognosis group but have bad outcomes.
# * The results of the full model are kind of hard to interperet and non-necessarily relavant as we get a lot of features that help to explain rate effect, ect. and thus improve the model but we don't exactly know what to do with these things for now.

# %%
survival_test = 'survival_5y'
covariates = ['age']
cov_df = global_vars.join(clinical.clinical, how='outer')
cov_df = cov_df[covariates]
cin = global_vars[('cna', 'chrom_instability')]
cov_df[('CIN')] = cin
surv = clinical.survival[survival_test]
test = SurvivalTest(surv, cov_df)
test.name = survival_test
test.check_featues = lambda s: s.sum() > 10

# %%
df = (cn.features.ix['Deletion',keepers].dropna(1) < 0).astype(int)
df = df[df.sum(1) > 10]

lr = df.apply(log_rank, args=(surv,), axis=1)
lr = lr.sort('p')
lr_del = lr

# %%
df = (cn.features.ix['Amplification',keepers].dropna(1) > 0).astype(str)
df = df[df.sum(1) > 10]

lr = df.apply(log_rank, args=(surv,), axis=1)
lr = lr.sort('p')
lr_amp = lr

# %%
lr = pd.concat([lr_del, lr_amp], keys=['Deletion','Amplification'])
lr['q'] = bhCorrection(lr.p)

# %%
lr.sort('p').head()
# Out:
#                                chi2         p         q
# Deletion      3p25.3  Lesion  19.80  8.59e-06  4.16e-04
#               3p14.2  Lesion  19.15  1.21e-05  4.16e-04
#               3p12.2  Lesion  17.65  2.65e-05  6.10e-04
# Amplification 15q26.3 Lesion   9.85  1.70e-03  2.93e-02
#               7p11.2  Lesion   8.21  4.16e-03  5.15e-02

# %% [markdown]
# ###Now for the full test

# %%
rate = cn.df.ix['Deletion', keepers].sum()
rate.name = 'rate'
cov_df = pd.concat([age, rate], axis=1).dropna()
test = SurvivalTest(surv, cov_df)

# %%
df = (cn.features.ix['Deletion', keepers].dropna(1) < 0).astype(int)
df = df[df.sum(1) > 10]
cn_del_full = df.apply(test.full_test, 1)

# %%
rate = global_vars[('cna', 'lesion_amp')]
rate.name = 'rate'
cov_df = pd.concat([age, rate], axis=1).dropna()
test = SurvivalTest(surv, cov_df)

df = (cn.features.ix['Amplification',keepers].dropna(1) > 0).astype(int)
df = df[df.sum(1) > 10]
cn_amp_full = df.apply(test.full_test, 1)

# %%
cn_full = pd.concat([cn_del_full, cn_amp_full], keys=['Deletion','Amplification'])
cn_full['LR_q'] = bhCorrection(cn_full.LR)

# %% [markdown]
# * p16 seems to get bumped up there seems to be some differential effect depending on the deletion rate.  This is likely due in part to its interaction with TP53.
# * 3p seems to preform much better than p16 in the simple model, I think p16 may be able to explain some of the p53 effect while 3p is too heavily redundant with p53?

# %%
cn_full.sort('LR').head()
# Out:
#                                     LR  feature_p                                               fmla  hazzard  LR_q
# Deletion      3p14.2  Lesion  5.62e-05   9.71e-05  Surv(days, event) ~ feature + age + feature:age\n     5.00  0.00
#               3p25.3  Lesion  2.82e-04   2.57e-05                      Surv(days, event) ~ feature\n     3.22  0.01
#               3p12.2  Lesion  1.21e-03   6.12e-05  Surv(days, event) ~ feature + age + feature:age\n     3.04  0.03
#               13q14.2 Lesion  3.65e-03   4.11e-03               Surv(days, event) ~ feature + rate\n     0.55  0.06
# Amplification 13q22.1 Lesion  6.89e-03   3.03e-02  Surv(days, event) ~ feature + age + rate + fea...     1.70  0.08

# %%
cn_full.sort('LR').head()
# Out:
#                                     LR  feature_p                                               fmla  hazzard  LR_q
# Deletion      3p14.2  Lesion  5.62e-05   9.71e-05  Surv(days, event) ~ feature + age + feature:age\n     5.00  0.00
#               3p25.3  Lesion  2.82e-04   2.57e-05                      Surv(days, event) ~ feature\n     3.22  0.01
#               3p12.2  Lesion  1.21e-03   6.12e-05  Surv(days, event) ~ feature + age + feature:age\n     3.04  0.03
#               13q14.2 Lesion  3.65e-03   4.11e-03               Surv(days, event) ~ feature + rate\n     0.55  0.06
# Amplification 13q22.1 Lesion  6.89e-03   3.03e-02  Surv(days, event) ~ feature + age + rate + fea...     1.70  0.08

# %% [markdown]
# ####Now merge the two together and filter down

# %%
cn_res = pd.concat([cn_full[cn_full.LR_q < .3], lr[lr.p < .05]], keys=['Full','Univariate'], axis=1).sort([('Full', 'LR')])
cn_res = cn_res.dropna()
cn_res.head()
# Out:
#                                   Full                                                          Full     Full        Univariate
#                                     LR  feature_p                                               fmla  hazzard  LR_q        chi2         p         q
# Deletion      3p14.2  Lesion  5.62e-05   9.71e-05  Surv(days, event) ~ feature + age + feature:age\n     5.00  0.00       19.15  1.21e-05  4.16e-04
#               3p25.3  Lesion  2.82e-04   2.57e-05                      Surv(days, event) ~ feature\n     3.22  0.01       19.80  8.59e-06  4.16e-04
#               3p12.2  Lesion  1.21e-03   6.12e-05  Surv(days, event) ~ feature + age + feature:age\n     3.04  0.03       17.65  2.65e-05  6.10e-04
#               19p13.3 Lesion  1.26e-02   1.21e-02  Surv(days, event) ~ feature + rate + feature:r...     1.67  0.11        7.44  6.37e-03  5.46e-02
# Amplification 7p11.2  Lesion  1.68e-02   3.30e-03  Surv(days, event) ~ feature + age + feature:age\n     1.77  0.13        8.21  4.16e-03  5.15e-02

# %% [markdown]
# ####Find overlapping copy number regions and filter them out
# * We will go back and characterize the top biomarkers later including their linked regions but for prioritizing the list it helps to look at non-redundant regions.

# %%
cn_hits = cn_res.index
df = pd.DataFrame({f: cn.features.ix[f].map(np.abs).clip_upper(1.) for f in cn_res.index}).T
df.index = pd.MultiIndex.from_tuples(df.index)

interactions = pd.Series({(a,b): fisher_exact_test(df.ix[a], df.ix[b])['p'] 
                          for i,a in enumerate(cn_hits) for j,b in enumerate(cn_hits) if i<j})
interactions.index = pd.MultiIndex.from_tuples(interactions.index)

# %%
ii = interactions.copy()
ii.index = pd.MultiIndex.from_tuples([(i[0][:2], i[1][:2]) for i  in ii.index])
ii.order().head(20)
# Out:
# (Deletion, 3p14.2)        (Deletion, 3p12.2)          1.41e-55
#                           (Deletion, 3p25.3)          3.52e-54
# (Deletion, 3p25.3)        (Deletion, 3p12.2)          2.37e-45
# (Deletion, 3p14.2)        (Amplification, 3q26.33)    5.42e-22
# (Deletion, 3p12.2)        (Amplification, 3q26.33)    4.01e-19
# (Amplification, 7p11.2)   (Amplification, 7q22.1)     1.65e-18
# (Deletion, 3p25.3)        (Amplification, 3q26.33)    2.45e-16
# (Deletion, 3p14.2)        (Amplification, 11q13.3)    2.57e-11
# (Deletion, 3p25.3)        (Amplification, 11q13.3)    3.08e-11
# (Deletion, 11p15.4)       (Deletion, 11q14.1)         1.10e-10
# (Amplification, 11q13.3)  (Deletion, 11q14.1)         1.66e-10
# (Amplification, 7q22.1)   (Amplification, 17q12)      3.07e-10
# (Deletion, 3p12.2)        (Amplification, 11q13.3)    5.88e-10
#                           (Deletion, 19p13.3)         1.27e-09
# (Deletion, 3p25.3)        (Deletion, 9p21.3)          1.99e-09
#                           (Deletion, 8p23.2)          2.24e-08
# (Deletion, 3p14.2)        (Deletion, 19p13.3)         2.25e-08
#                           (Deletion, 9p21.3)          2.89e-08
# (Deletion, 3p12.2)        (Deletion, 9p21.3)          3.12e-08
# (Amplification, 3q26.33)  (Amplification, 17q12)      7.93e-08
# dtype: float64

# %% [markdown]
# ####Top copy number hits
# * 3p14.2: FHIT coexpressed with TP53 to stabilize it, FRA3B breakpoint
# * 11q13: CCND1- cell cycle regulator, associated with lymphnode stage as well as functional state of TP53 mutation
# * 15q26.3: IGF1R- Insulin-like growth factor receptor, SMAD on 15q ( http://www.ncbi.nlm.nih.gov/pubmed/9892110 , http://en.wikipedia.org/wiki/Insulin-like_growth_factor_1_receptor)
# * 8p23.2: CSMD1, FRA8B breakpoint

# %%
cc1 = combine(cn.df.ix['Amplification'].ix['11q13.3'].ix[0]>0, mut.features.ix['TP53'])

# %%
cc = combine(cn.df.ix['Deletion'].ix['3p14.2'].ix[0]<0, mut.features.ix['TP53']>0)

# %%
draw_survival_curves(cc1.ix[true_index(hpv=='HPV-')], surv, show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
draw_survival_curves(cc, surv, hpv=='HPV+', show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
cn_hits1 = cn_hits.diff(pd.Index([i[1] for i in interactions[interactions < 10**-10].index]).unique())
cn_res.ix[cn_hits1].sort([('Univariate', 'p')]).head(10)
# Out:
#                                    Full                                                          Full     Full        Univariate
#                                      LR  feature_p                                               fmla  hazzard  LR_q        chi2         p         q
# Deletion      3p14.2   Lesion  5.62e-05   9.71e-05  Surv(days, event) ~ feature + age + feature:age\n     5.00  0.00       19.15  1.21e-05  4.16e-04
# Amplification 15q26.3  Lesion  6.41e-02   2.02e-03                      Surv(days, event) ~ feature\n     1.89  0.18        9.85  1.70e-03  2.93e-02
#               7p11.2   Lesion  1.68e-02   3.30e-03  Surv(days, event) ~ feature + age + feature:age\n     1.77  0.13        8.21  4.16e-03  5.15e-02
# Deletion      11p15.4  Lesion  1.08e-01   2.93e-02  Surv(days, event) ~ feature + age + rate + fea...     1.71  0.21        8.02  4.62e-03  5.15e-02
#               Xp11.3   Lesion  1.12e-01   4.06e-02  Surv(days, event) ~ feature + rate + feature:r...     1.58  0.21        7.80  5.22e-03  5.15e-02
#               19p13.3  Lesion  1.26e-02   1.21e-02  Surv(days, event) ~ feature + rate + feature:r...     1.67  0.11        7.44  6.37e-03  5.46e-02
#               11q14.1  Lesion  1.15e-01   1.11e-01               Surv(days, event) ~ feature + rate\n     1.38  0.21        6.50  1.08e-02  6.31e-02
# Amplification 18p11.31 Lesion  9.63e-02   9.35e-02               Surv(days, event) ~ feature + rate\n     1.43  0.21        6.33  1.19e-02  6.31e-02
# Deletion      9p21.3   Lesion  2.41e-02   5.29e-01  Surv(days, event) ~ feature + rate + feature:r...     1.14  0.15        6.07  1.37e-02  6.31e-02
#               8p23.2   Lesion  8.05e-02   8.50e-02  Surv(days, event) ~ feature + rate + feature:r...     1.41  0.21        5.15  2.32e-02  1.00e-01

# %%
del_3p = cn.df.ix['Deletion', keepers].ix['3p14.2'].ix[0].ix[keepers]
del_3p.name = 'del_3p'

# %% [markdown]
# ####Is this just an artifact of chromosomal instablity?
# * We screen the number of lesions deleted and amplified to see if thats what we are seeing
# * It seems like the 3p14 effect is stronger than an optimal threshold on chromosomal instability

# %%
import Figures.Survival as S
reload(S)
from Figures.Survival import *

# %%
cin
# Out:
# TCGA-BA-4074     5
# TCGA-BA-4075    21
# TCGA-BA-4076    10
# TCGA-BA-4077     6
# TCGA-BA-4078     5
# TCGA-BA-5149     6
# TCGA-BA-5151     5
# TCGA-BA-5152     2
# TCGA-BA-5153     1
# TCGA-BA-5555    13
# TCGA-BA-5556     7
# TCGA-BA-5557     6
# TCGA-BA-5558     8
# TCGA-BA-5559    13
# TCGA-BA-6868    11
# ...
# TCGA-HD-7229     7
# TCGA-HD-7753    15
# TCGA-HD-7754     3
# TCGA-HD-7831    13
# TCGA-HD-7832     5
# TCGA-HD-7917    17
# TCGA-HD-8224    10
# TCGA-HD-8314     7
# TCGA-HD-8634     6
# TCGA-HD-8635     5
# TCGA-HD-A4C1     0
# TCGA-HL-7533     6
# TCGA-IQ-7630     9
# TCGA-IQ-7631     3
# TCGA-IQ-7632     3
# Name: Chromosomal Instability, Length: 356, dtype: float64

# %%
cin = (global_vars.cna.lesion_del + global_vars.cna.lesion_amp)
cin.name = 'Chromosomal Instability'

fig, axs = subplots(1,3, figsize=(12,4))
aa = pd.DataFrame({x: log_rank(cin >= x, surv) for x in arange(0, 50)}).T
aa.dropna().chi2.plot(ax=axs[0])
axs[0].set_ylabel('Hazzard Ratio')
axs[0].set_xlabel('# of Lesions Deleted')
draw_survival_curve(((cin<6)*1.).map({True: '# Events < 6', False: '# LOH >= 6'}), surv, ax=axs[1])
draw_survival_curve(((del_3p==0)*1.).map({False: '3p14.2 +/-', True: ' 3p14.2 +/+'}), surv, ax=axs[2])
#fig.savefig('/cellar/users/agross/Desktop/Figures/3p_chrom_deletion_rate.pdf', transparent=True)

# %%
cin = (cn.df.ix['Deletion'] < 0).sum()
cin.name = '# Deletions'

fig, axs = subplots(1,3, figsize=(12,4))
aa = pd.DataFrame({x: log_rank(cin < x, surv) for x in arange(0, 50)}).T
aa.dropna().chi2.plot(ax=axs[0])
axs[0].set_ylabel('Hazzard Ratio')
axs[0].set_xlabel('# of Lesions Deleted')
draw_survival_curve(((cin<11)*1.).map({True: '# Events < 11', False: '# LOH >= 11'}), surv, ax=axs[1])
draw_survival_curve(((del_3p==0)*1.).map({False: '3p14.2 +/-', True: ' 3p14.2 +/+'}), surv, ax=axs[2])
#fig.savefig('/cellar/users/agross/Desktop/Figures/3p_chrom_deletion_rate.pdf', transparent=True)

# %% [markdown]
# ###3p Characterization
# * 3p14.2 is more significant than the other deletions by a relatively large margin.
# * Lets characterize this event and see whats going on.
# * 8q23 is FRA8C, annother fragile site with CSMD3 on it
# * We seem to have an accumulation of large genes with fragile sites

# %%
s = screen_feature(del_3p, fisher_exact_test, cn.features.ix['Deletion'] < 0)
s.head(5)
# Out:
#                    odds_ratio         p         q
# (3p14.2, Lesion)         0.00  7.28e-77  3.20e-75
# (3p25.3, Lesion)         0.00  2.41e-50  5.29e-49
# (3p12.2, Lesion)         0.00  4.88e-50  7.16e-49
# (18q23, Lesion)          0.09  4.50e-17  4.95e-16
# (18q21.2, Lesion)        0.12  8.44e-13  7.43e-12

# %%
fig, axs = subplots(1,2, figsize=(8,3))
aa = pd.Series(del_3p==-1, name='3p14.2 +/-')
bb = pd.Series(cn.features.ix[('Deletion','18q23','Lesion')] < 0, name='18q23 +/-')
venn_pandas(aa, bb)
draw_survival_curve(combine(aa, bb), surv, ax=axs[0],
                      colors=array(rcParams['axes.color_cycle'])[[2,0,3,1]])
axs[0].legend(loc='lower left', frameon=False)
#fig.savefig('/cellar/users/agross/Desktop/Figures/3p_p16.pdf', transparent=True);

# %%
s = screen_feature(del_3p, fisher_exact_test, cn.features.ix['Amplification'] > 0)
s.head(5)
# Out:
#                    odds_ratio         p         q
# (3q26.33, Lesion)        0.08  2.94e-17  7.34e-16
# (11q13.3, Lesion)        0.16  9.03e-10  1.13e-08
# (2q11.2, Lesion)         0.11  2.31e-06  1.92e-05
# (8q24.21, Lesion)        0.31  2.17e-05  1.35e-04
# (7p11.2, Lesion)         0.32  6.78e-05  3.39e-04

# %%
fig, axs = subplots(1,2, figsize=(8,3))
aa = pd.Series(del_3p==-1, name='3p14.2 +/-')
bb = pd.Series(cn.features.ix[('Amplification','3q26.33','Lesion')] > 0, name='3q26 +/-')
venn_pandas(aa, bb)
draw_survival_curve(combine(aa, bb), surv, ax=axs[0],
                      colors=array(rcParams['axes.color_cycle'])[[2,0,3,1]])
axs[0].legend(loc='lower left', frameon=False)
#fig.savefig('/cellar/users/agross/Desktop/Figures/3p_p16.pdf', transparent=True);

# %% [markdown]
# * The overlap of 3p and HPV+ is under-represented.
# * We already know that 3p and TP53 overlap from the mutation screen, in our TP53wt patients there is no significant overlap of 3p and HPV+.
# * Those patients in HPV+ that do have 3p deletion do worse than those with two copies.

# %%
fisher_exact_test(del_3p==-1, hpv=='HPV+')
# Out:
# odds_ratio    2.02e-01
# p             3.46e-05
# dtype: float64

# %%
fisher_exact_test(del_3p.ix[true_index(mut.features.ix['TP53']==0)]==-1, hpv=='HPV+')
# Out:
# odds_ratio    0.85
# p             0.82
# dtype: float64

# %%
fig, axs = subplots(1,2, figsize=(6,3))
plt.sca(axs[0])
a,b = del_3p==-1, hpv=='HPV+'
a.name = '3p14.2 Deletion'
b.name = 'HPV'
venn_pandas(a,b)

draw_survival_curve(del_3p.ix[true_index(hpv=='HPV+')].map({-1: 'LOH', 0: 'Diploid'}), surv, ax=axs[1], 
                    colors=array(rcParams['axes.color_cycle'])[[0,4]])
plt.tight_layout()
fig.savefig('/cellar/users/agross/Desktop/Figures/fig1b2.pdf', transparent=True)

# %% [markdown]
# ###Characterizing the 3p Deletions's Molecular Phenotype
# * Now that we have identified that 3p deletion has an adverse clinical outcome we would like to find what molecular phenotypes follow from this event.
# * We already know that this interacts with TP53 and thus HPV so we need to work that out.

# %%
screen_feature(del_3p, kruskal_pandas, global_vars.T)
# Out:
#                                H         p   q
# (cna, gene_del)            88.67  4.68e-21 NaN
# (cna, chrom_instability)   53.98  2.03e-13 NaN
# (cna, lesion_amp)          50.89  9.76e-13 NaN
# (cna, lesion_amp_high)     41.96  9.33e-11 NaN
# (cna, gene_amp)            40.70  1.78e-10 NaN
# (cna, gene_amp_high)       28.51  9.30e-08 NaN
# (methylation, pc2)         25.72  3.95e-07 NaN
# (mutation, A->mut)         17.24  3.29e-05 NaN
# (mutation, *CpG->T)        11.45  7.13e-04 NaN
# (mutation, *Cp(A_C_T)->T)  10.65  1.10e-03 NaN
# (mutation, rate_non)       10.33  1.31e-03 NaN
# (mutation, rate_sil)        9.04  2.65e-03 NaN
# (mutation, C->(G_A))        6.26  1.24e-02 NaN
# (methylation, pc1)          3.21  7.34e-02 NaN
# (mutation, rate_dbsnp)      2.79  9.49e-02 NaN
# (mRNASeq, pc2)              2.74  9.76e-02 NaN
# (mRNASeq, pc1)              0.71  3.99e-01 NaN
# (mutation, double_null)     0.66  4.15e-01 NaN
# (mutation, indel+null)      0.65  4.21e-01 NaN
# (cna, gene_del_homo)        0.45  5.02e-01 NaN
# (cna, lesion_del_homo)       NaN       NaN NaN
# (cna, lesion_del)            NaN       NaN NaN

# %% [markdown]
# ####Screening for conserved pathways
# * This is a little tricky due to linkage of copy number events.
# * The basic strategy is as follows:
#     * first find associated features with a copy number event
#     * next screen candidate feature for association with all copy number events
#     * if our feature comes up at the top it is more likely causative rather than artifactual of the linkage

# %% [markdown]
# ####Protein Expression
# * KDR the VEGFR2 receptor is coming up in both directions
# * BAX is a pro-apoptotic gene, is upregulated by TP53

# %%
s = screen_feature(del_3p, kruskal_pandas, rppa.features)
s.head()
# Out:
#                                                                                     H         p     q
# REACTOME_SIGNALING_BY_VEGF                                                      21.23  4.08e-06  0.00
# REACTOME_TRANSPORT_OF_MATURE_MRNA_DERIVED_FROM_AN_INTRON_CONTAINING_TRANSCRIPT  14.22  1.63e-04  0.01
# REACTOME_METABOLISM_OF_MRNA                                                     14.22  1.63e-04  0.01
# REACTOME_TRANSPORT_OF_THE_SLBP_INDEPENDENT_MATURE_MRNA                          14.22  1.63e-04  0.01
# REACTOME_DEADENYLATION_OF_MRNA                                                  14.22  1.63e-04  0.01

# %%
s = screen_feature(del_3p, kruskal_pandas, rppa.df.xs('01',level=1, axis=1))
s.head()
# Out:
#                                         H         p         q
# (KDR, VEGFR2-R-V)                   21.23  4.08e-06  7.10e-04
# (EIF4E, eIF4E-R-V)                  14.22  1.63e-04  1.42e-02
# (BAX, Bax-R-V)                      12.70  3.66e-04  2.12e-02
# (CASP7, Caspase-7_cleavedD198-R-C)  10.51  1.19e-03  4.39e-02
# (ANXA1, Annexin_I-R-V)              10.40  1.26e-03  4.39e-02

# %%
violin_plot_pandas(del_3p, rppa.df.ix[s.index[0]].ix[:,'01']);
test = lambda a,b: kruskal_pandas(b,a)
screen_feature(rppa.df.ix[s.index[0]].ix[:,'01'], test, cn.features).head()
# Out:
#                                       H         p         q
# (Deletion, 3p14.2, Lesion)        24.32  8.18e-07  5.64e-05
# (Deletion, 3p25.3, Lesion)        20.41  6.26e-06  2.16e-04
# (Deletion, 3p12.2, Lesion)        19.22  1.16e-05  2.67e-04
# (Amplification, 3q26.33, Lesion)  20.83  3.00e-05  5.18e-04
# (Deletion, 2q21.2, Lesion)        16.46  4.97e-05  6.86e-04

# %% [markdown]
# ####RNA Expression

# %% [markdown]
# * Broad expression changes seem to be due to linkage of 3p14 other fragile sites

# %%
s = screen_feature(del_3p, kruskal_pandas, rna.features)
s.head()
# Out:
#                                                        H         p         q
# BIOCARTA_RAS_PATHWAY                               88.69  4.62e-21  3.84e-18
# REACTOME_TRKA_SIGNALLING_FROM_THE_PLASMA_MEMBRANE  86.84  1.17e-20  4.89e-18
# BIOCARTA_EDG1_PATHWAY                              82.55  1.03e-19  2.85e-17
# KEGG_RNA_DEGRADATION                               81.63  1.64e-19  3.41e-17
# ST_WNT_BETA_CATENIN_PATHWAY                        78.92  6.46e-19  9.50e-17

# %%
screen_feature(del_3p, kruskal_pandas, rna.df.ix[run.gene_sets['BIOCARTA_RAS_PATHWAY']].xs('01', axis=1, level=1)).head()
# Out:
#             H         p         q
# RHOA    80.30  3.22e-19  7.40e-18
# RAF1    71.63  2.59e-17  2.98e-16
# PIK3CG  24.02  9.54e-07  7.32e-06
# AKT1    19.93  8.04e-06  4.62e-05
# PIK3R1  16.29  5.45e-05  2.51e-04

# %%
survival_and_stats(to_quants(rna.df.ix['RAF1'].ix[:,'01'], labels=True, std=1), surv)

# %%
violin_plot_pandas(del_3p, rna.features.ix[s.index[0]]);
test = lambda a,b: kruskal_pandas(b,a)
screen_feature(rna.features.ix[s.index[0]], test, cn.features).head()
# Out:
#                                        H         p         q
# (Deletion, 3p25.3, Lesion)        108.55  2.03e-25  1.40e-23
# (Deletion, 3p14.2, Lesion)         95.11  1.80e-22  6.22e-21
# (Deletion, 3p12.2, Lesion)         90.86  1.54e-21  3.54e-20
# (Amplification, 3q26.33, Lesion)   55.06  1.11e-12  1.91e-11
# (Deletion, 9p23, Lesion)           39.54  3.21e-10  4.43e-09

# %% [markdown]
# ####microRNA expression
# * http://www.ncbi.nlm.nih.gov/pubmed/21868754

# %%
s = screen_feature(del_3p, kruskal_pandas, mirna.features)
s.head()
# Out:
#                           H         p         q
# (real, hsa-mir-152)   33.62  6.71e-09  4.41e-06
# (real, hsa-mir-150)   32.31  1.31e-08  4.41e-06
# (real, hsa-mir-183)   28.68  8.55e-08  1.92e-05
# (real, hsa-mir-155)   27.49  1.58e-07  2.66e-05
# (real, hsa-mir-1910)  23.30  1.39e-06  1.87e-04

# %%
violin_plot_pandas(del_3p, mirna.features.ix[s.index[0]]);
test = lambda a,b: kruskal_pandas(b,a)
screen_feature(mirna.features.ix[s.index[0]], test, cn.features).head()
# Out:
#                                       H         p         q
# (Deletion, 3p14.2, Lesion)        35.45  2.62e-09  1.81e-07
# (Amplification, 3q26.33, Lesion)  35.75  1.72e-08  5.95e-07
# (Deletion, 5q11.2, Lesion)        29.95  4.44e-08  1.02e-06
# (Deletion, Xq21.33, Lesion)       28.24  1.07e-07  1.85e-06
# (Deletion, 3p25.3, Lesion)        27.50  1.57e-07  2.16e-06

# %% [markdown]
# ####Screen for associated mutations
# * We know about TP53 from our mutation screen
# * The rest our our HRAS/MAPK stuff and CASP8 which we know cause much lower deletion rates

# %%
screen_feature(del_3p, fisher_exact_test, mut.features).head()
# Out:
#                                   odds_ratio         p         q
# TP53                                    0.12  6.21e-13  6.14e-10
# REACTOME_SOS_MEDIATED_SIGNALLING        9.44  1.05e-07  5.21e-05
# REACTOME_SHC_MEDIATED_SIGNALLING        8.76  3.88e-07  1.28e-04
# REACTOME_SHC_RELATED_EVENTS             7.10  1.95e-06  4.82e-04
# CASP8                                   8.94  3.06e-06  6.06e-04

# %%
fig, axs = subplots(1,2, figsize=(6,3))
a,b = del_3p==-1, mut.features.ix['CASP8']>0
a.name = '3p14.2 Deletion'
plt.sca(axs[0])
venn_pandas(a,b)
b = mut.features.ix['TP53']>0
plt.sca(axs[1])
venn_pandas(a,b)

# %%
from Figures.MemoPlot import pathway_plot

# %%
fig, axs = subplots(1,2, figsize=(6,3))
plt.sca(axs[0])
a,b = del_3p==-1, mut.features.ix['REACTOME_SOS_MEDIATED_SIGNALLING']==1
a.name = '3p14.2 Deletion'
venn_pandas(a,b)
pathway_plot(mut.df.ix[run.gene_sets['REACTOME_SOS_MEDIATED_SIGNALLING'], keepers], ax=axs[1])

# %% [markdown]
# * We're getting a bunch of action around 5q35 so lets take a look at that

# %%
fig, axs = subplots(1,2, figsize=(6,3))
a,b =cn.features.ix[('Deletion','5q35.3','Lesion')]==-1, mut.features.ix['CASP8']==1
a.name = '5q35.3 Deletion'
plt.sca(axs[0])
venn_pandas(a.ix[keepers],b)
b = mut.features.ix['TP53']>0
plt.sca(axs[1])
venn_pandas(a,b)

# %%
screen_feature(cn.features.ix[('Deletion','5q35.3','Lesion'), keepers], 
               fisher_exact_test, mut.features).head()
# Out:
#                                    odds_ratio         p     q
# TP53                                     0.28  8.23e-06  0.01
# REACTOME_SOS_MEDIATED_SIGNALLING         6.26  8.52e-04  0.28
# REACTOME_FRS2_MEDIATED_ACTIVATION        6.26  8.52e-04  0.28
# PRDM9                                    0.20  1.47e-03  0.33
# KEGG_CELL_CYCLE                          0.28  1.65e-03  0.33

# %% [markdown]
# ###Breaking down the locus
# * Let's take a look at 3p14.2 and its related loci and see if we can figure out whats going on

# %% [markdown]
# * So far we have been using the thresholded copy number results.
# * Now we want to look at the continuous copy number levels and see if this is a good treshold.
# * The default GISTIC cutoff is -.1, which actually looks pretty good.

# %%
args = [run.data_path] + [cancer.name]
f = '{}/analyses/{}/CopyNumber_Gistic2/all_lesions.conf_99.txt'.format(*args)
lesions = pd.read_table(f, index_col=0)
#lesions = lesions.set_index('Descriptor').select(lambda s: s.startswith('TCGA'), 1)

# %%
lesions
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140 entries, Amplification Peak  1 to Deletion Peak 45 - CN values
# Columns: 361 entries, Descriptor to Unnamed: 361
# dtypes: float64(356), object(5)

# %%
args = [run.data_path] + [cancer.name]
f = '{}/analyses/{}/CopyNumber_Gistic2/all_lesions.conf_99.txt'.format(*args)
lesions = pd.read_table(f, index_col=0)
lesions = lesions.set_index('Descriptor').select(lambda s: s.startswith('TCGA'), 1)
lesions = lesions.groupby(lambda s: s[:12],1).first()
lesions.index = map(str.strip, lesions.index)

levels = lesions.ix['3p14.2'].ix[2]
calls = lesions.ix['3p14.2'].ix[0]

# %%
args = [run.data_path] + [cancer.name]
f = '{}/analyses/{}/CopyNumber_Gistic2/broad_values_by_arm.txt'.format(*args)
arm = pd.read_table(f, index_col=0)
arm = arm.groupby(lambda s: s[:12],1).first()

# %%
survival_test = 'survival_5y'
surv = clinical.survival[survival_test]
test = SurvivalTest(surv, pd.DataFrame(index=lesions.columns))
test.name = survival_test

# %%
fig, axs = subplots(1, 2, figsize=(12,4))
levels.hist(bins=50, ax=axs[0])
s = pd.DataFrame({c: log_rank(levels < c, surv) for c in levels.order()[2:-2]})
s.ix['p'].plot(ax=axs[1])
axs[0].set_xlabel('Copy Number')
axs[1].set_xlabel('Copy Number')
axs[1].set_ylabel('p-value')
axs[1].set_yscale('log')

# %%
s.T.sort('p').head()
# Out:
#         chi2         p
# -0.19  17.42  2.99e-05
# -0.18  16.94  3.86e-05
# -0.17  16.53  4.78e-05
# -0.17  16.36  5.24e-05
# -0.19  16.33  5.31e-05

# %%
df = cn.features.ix['Deletion']
df = df.ix[:,df.columns.diff(true_index(hpv == 'HPV+'))]

# %%
s = lr_screen(df < 0, surv).head()

# %%
df.ix[s.index].apply(test.full_test, 1).sort('LR')
# Out:
#                       LR  feature_p                                               fmla  hazzard
# 3p14.2  Lesion  1.25e-04   1.43e-03  Surv(days, event) ~ feature + age + feature:age\n     0.14
# 3p25.3  Lesion  1.83e-03   5.32e-04                      Surv(days, event) ~ feature\n     0.33
# 3p12.2  Lesion  7.74e-03   1.08e-03  Surv(days, event) ~ feature + age + feature:age\n     0.35
# 11p15.4 Lesion  3.32e-02   5.36e-03  Surv(days, event) ~ feature + rate + feature:r...     0.49
# 11q14.1 Lesion  6.94e-02   6.67e-02               Surv(days, event) ~ feature + rate\n     0.67

# %%
from Figures.R_Wrappers import *

# %%
draw_survival_curves(combine(calls, mut.features.ix['TP53']), surv, hpv, show=True)
# Out:
# <img src='data:image/png;base64,...'>

# %%
survival_and_stats(combine(calls, mut.features.ix['TP53']).ix[true_index(hpv=='HPV-')].dropna(), surv)

# %%
survival_and_stats(combine(calls, mut.features.ix['TP53']).ix[true_index(hpv.ix[del_3p.index] != 'HPV+')].dropna(), surv)

# %% [markdown]
# ####Now lets try and narrow down to a single gene
# * We have a bunch of genes of 3p that are deleted, it seems like this event is selected for, so lets try and figure out why.
# * The plan is to look at a bunch of complementary features and see if we can get support for any genes.
#     * Copy number loss should correlate with expression decrease
#     * Expression in the tumor should be lower than matched normal tissue
#     * Expression should correlate with survival

# %% [markdown]
# ####Here we build up a matrix of descriptive statistics for the genes in our copy number arm
# * exp_cn: change in expression across diploid and deleted patients (Kruskal-Wallis test)
# * exp_tumor: change in expression across normal and matched tumor tissue
#     * Kruskal-Wallis test
#     * Note uneven sample sizes due to unavailibility of matched expression samples for all patients
#     * Using only matched samples with a paired test, yeild similar results but we are just using all the data and treating them as poplulations for now
# * exp_p53: Spearman correlation of expression with TP53 expression
#     * might be cheating a little because it has been published that FHIT is coexpressed with TP53 ( http://www.ncbi.nlm.nih.gov/pubmed/15313915 )
# * exp_survp: Univariate Cox test for association of experession with survival
#     * The idea here is that the expression change driven by the copy number loss should influence survival

# %%
run.data_path
# Out:
# '/cellar/data/TCGA/Firehose__2013_04_21/'

# %%
args = ['/scratch/TCGA/Firehose__2012_01_16/'] + [cancer.name]
f = '{0}analyses/{1}/CopyNumber_GeneBySample/{1}-TP.RS.tsv'.format(*args)
cn_by_gene = pd.read_table(f, skiprows=[1], index_col=0)
cn_by_gene = cn_by_gene.groupby(lambda s: s[:12],1).first()


coords = cn_by_gene[['chrom','start']]

args = [run.data_path] + [cancer.name]
f = '{}/analyses/{}/CopyNumber_Gistic2/all_data_by_genes.txt'.format(*args)
cn_by_gene = pd.read_table(f, index_col=[0])
cn_by_gene = cn_by_gene.groupby(lambda s: s[:12],1).first()
cn_by_gene = cn_by_gene

cn_by_gene = cn_by_gene.join(coords).set_index(['chrom','start','Cytoband','Locus ID'], append=True)
cn_by_gene = cn_by_gene.ix[:,keepers].dropna(axis=1)

ch_3 = cn_by_gene.xs(3, level='chrom')
p_arm = pd.Series(ch_3.index.get_level_values('Cytoband').map(lambda s: 'p' in s), ch_3.index)
p_arm = ch_3[p_arm].sortlevel('start')
p_arm = p_arm.ix[:-1]

# %%
lr = (1.*(p_arm  < -.1)).apply(log_rank, args=(surv,), axis=1)

# %%
colors = rcParams['axes.color_cycle']

# %%
import Data.Firehose as FH
df = FH.read_rnaSeq(run.data_path, cancer.name, average_on_genes=True, tissue_code='All')

# %%
tt = lambda s: cox(s, surv)
exp_change = lambda s: anova(pd.Series(s.index.get_level_values(1), s.index), s)

# %%
meth
# Out:
# Methylation dataset

# %%
fc = lambda s: kruskal_pandas(pd.Series(s.index.get_level_values(1), s.index), s)

# %%
exp_fc = pd.Series({f: -fc(df.ix[f[0]].ix[true_index(del_3p==-1)]) for f in p_arm.index
                               if f[0] in df.index}).order()

# %%
def fc(s):
    l = s.groupby(level=1).median()
    return (l['01']-l['11'])
exp_fc = pd.Series({f: -fc(rna.df.ix[f[0]].ix[true_index(del_3p==-1)]) for f in p_arm.index
                               if f[0] in df.index}).order()
#exp_fc.index = pd.MultiIndex.from_tuples(exp_fc.index, names=p_arm.index.names)

# %%
import Stats.Survival as S
reload(S)
from Stats.Survival import *

def stratified_cox(feature, surv, strata):
    fmla = 'Surv(days, event) ~ feature + strata({})'.format(strata.name)
    model = get_cox_ph(surv, feature, covariates=strata, formula=fmla)
    lr = model[3][0]
    p = stats.chi2.sf(lr, 1)
    return pd.Series({'LR': lr, 'p': p})

# %%
del_3p = del_3p.dropna()
calls.name = 'del_3p'

# %%
exp = df.apply(stratified_cox, args=(surv, calls), axis=1)

# %%
exp = exp.sort_index()
exp.index = lr.sort_index().ix[exp.index].index

# %%
tn = lambda s: kruskal_pandas(pd.Series(s.index.get_level_values(1), s.index), s)
fc = lambda s: kruskal_pandas(del_3p, s)

# %%
tumor_change = rna.df.ix[df.index].apply(tn, axis=1)
fold_change = df.apply(fc, axis=1)

# %%
tumor_change.sort('p').head(20)
# Out:
#              H         p
# GPD1L    92.57  6.50e-22
# FAM3D    89.79  2.64e-21
# SUCLG2   88.76  4.47e-21
# QARS     85.55  2.26e-20
# IL17RC   83.79  5.51e-20
# SLC26A6  82.24  1.21e-19
# MAGI1    78.58  7.67e-19
# PDHB     78.49  8.04e-19
# CLEC3B   78.21  9.28e-19
# COL7A1   75.91  2.98e-18
# GORASP1  75.84  3.07e-18
# GOLGA4   75.63  3.43e-18
# ZCWPW2   75.30  4.03e-18
# CIDEC    74.22  6.99e-18
# RPL14    73.52  9.98e-18
# EIF4E3   72.55  1.63e-17
# TMEM111  71.88  2.28e-17
# SLC38A3  71.77  2.42e-17
# ACAA1    71.29  3.09e-17
# FHIT     71.14  3.33e-17

# %%
fold_change.ix[true_index(tumor_change.p < .000001)].sort('p').head(20)
# Out:
#               H         p
# QRICH1    89.77  2.67e-21
# ACTR8     86.08  1.73e-20
# AZI2      85.50  2.31e-20
# SUCLG2    85.29  2.58e-20
# RNF123    84.41  4.02e-20
# MKRN2     84.02  4.90e-20
# PDHB      83.84  5.36e-20
# ATXN7     83.84  5.36e-20
# WDR48     81.51  1.74e-19
# RHOA      80.30  3.22e-19
# RPP14     76.03  2.79e-18
# CYB561D2  75.29  4.06e-18
# USP19     74.86  5.04e-18
# GORASP1   74.67  5.58e-18
# C3orf23   72.19  1.96e-17
# RAF1      71.63  2.59e-17
# TMF1      71.24  3.16e-17
# SLMAP     71.16  3.29e-17
# OXNAD1    69.84  6.44e-17
# ZFYVE20   68.66  1.17e-16

# %%
violin_plot_pandas(calls, df.ix['WNT7A'].ix[:,'01'])

# %%
violin_plot_series(rna.df.ix['WNT7A'])

# %%
draw_survival_curves(

# %%
exp2 = exp.ix[true_index(tumor_change.p < .05)]
exp2 = exp2.ix[true_index(fold_change.p < .01)].dropna()
exp2 = -exp2.p.map(log10)

# %%
fig = plt.figure(figsize=(8,4))
ax1 = plt.subplot2grid((7,1), (0,0), rowspan=3, colspan=1)
ax2 = plt.subplot2grid((7,1), (3,0), rowspan=3, colspan=1)
ax3 = plt.subplot2grid((7,1), (6,0), rowspan=1, colspan=1)

bands = lr.reset_index().groupby('Cytoband').first().start.order()
for i,(idx,v) in enumerate(bands.iteritems()):
    try:
        r = plt.Rectangle((v,0), bands.iloc[i+1]-v, 1, lw=2, alpha=.5, fc=colors[i%2])
    except:
        r = plt.Rectangle((v,0), lr.index.get_level_values('start')[-1]-v, 1, lw=2, alpha=.5, fc=colors[i%2])
    ax3.add_artist(r)
ax3.set_xticks(bands)
b = [{0:s,1:''}[(i%2)] for i,s in enumerate(bands.index)]
ax3.set_xticklabels(b, rotation=270+45, ha='left')

ax1.scatter(p_arm.index.get_level_values('start'), (p_arm < -.1).sum(1), s=40, c=colors[2], edgecolor='grey', alpha=1)
ax2.scatter(exp2.index.get_level_values('start'), exp2, s=40, c=colors[4], edgecolor='grey', alpha=1)

ax1.set_ybound(215,255)
ax1.set_ylabel('# of Patients\nwith Deletion\n\n', ha='center', va='center')
ax2.set_ybound(0,4)
ax2.set_ylabel('mRNA Survival\nAssociation\n(Log10 p)\n\n\n', ha='center', va='center')
ax3.set_yticks([])
fig.tight_layout()
for ax in [ax1, ax2, ax3]:
    ax.set_xbound(lr.index.get_level_values('start')[0], lr.index.get_level_values('start')[-1])
    ax.set_xticks(bands)
ax1.set_xticklabels('')
ax2.set_xticklabels('')
fig.tight_layout()
fig.savefig('/cellar/users/agross/Desktop/Figures/fig2b.pdf', transparent=True)

# %%
from matplotlib import gridspec

# %%
len(exp2)
# Out:
# 213

# %%
exp2 = -log10(bhCorrection(10**(-exp2)).order())

# %%
fig, axs = subplots(3,1, figsize=(8,5), sharex=True)
bands = lr.reset_index().groupby('Cytoband').first().start.order()
for i,(idx,v) in enumerate(bands.iteritems()):
    try:
        r = plt.Rectangle((v,0), bands.iloc[i+1]-v, 1, lw=2, alpha=.5, fc=colors[i%2])
    except:
        r = plt.Rectangle((v,0), lr.index.get_level_values('start')[-1]-v, 1, lw=2, alpha=.5, fc=colors[i%2])
    axs[-1].add_artist(r)
axs[-1].set_xticks(bands)
b = [{0:s,1:''}[(i%2)] for i,s in enumerate(bands.index)]
axs[-1].set_xticklabels(b, rotation=270+45, ha='left')

axs[0].scatter(p_arm.index.get_level_values('start'), (p_arm < -.1).sum(1), s=40, c=colors[2], edgecolor='grey', alpha=1)
axs[1].scatter(exp2.index.get_level_values('start'), exp2, s=40, c=colors[4], edgecolor='grey', alpha=1)

axs[0].set_ybound(215,255)
axs[0].set_ylabel('# of Patients\nwith Deletion\n\n', ha='center', va='center')
axs[-1].set_xbound(lr.index.get_level_values('start')[0], lr.index.get_level_values('start')[-1])
#axs[1].hlines(-log10(.1), lr.index.get_level_values('start')[0], lr.index.get_level_values('start')[-1], linestyles='--')
axs[1].set_ybound(0,4)
axs[1].set_ylabel('mRNA Survival\nAssociation\n(Log10 p)\n\n\n', ha='center', va='center')
axs[2].set_yticks([])

fig.tight_layout()
for n, ss in exp2.order().tail(4).iteritems():
    axs[1].annotate(n[0], (n[1], ss), 
                     xytext=(15, -5), textcoords='offset points', arrowprops=dict(arrowstyle="->"))
fig.savefig('/cellar/users/agross/Desktop/Figures/fig2b.pdf', transparent=True)

# %%
lm = robjects.r.lm

# %%
def sanitize_for_r(f):
    s = f.name
    s = s.replace(':','_').replace('(','_').replace(')','_').replace('-','_')
    return pd.Series(f, name=s)

def process_factors(cov):
    '''
    Coerce covariates and feature into format suitable for R's
    survival functions. 
    '''
    if type(cov) == pd.Series:
        cov = pd.concat([cov], axis=1)
    elif type(cov) == list:
        assert map(type, cov) == ([pd.Series] * len(cov))
        cov = pd.concat(cov, axis=1)
        
    
    c_real = cov.ix[:,cov.dtypes.isin([np.dtype(float), np.dtype(int)])]
    c_real = (c_real - c_real.mean()) / c_real.std()
    cov[c_real.columns] = c_real
    df = cov
    df = df.groupby(level=0).first()
    df = df.dropna()
    df = convert_to_r_dataframe(df)
    return df

# %%
def stratified_regression(target, feature, strata):
    target, feature, strata = map(sanitize_for_r, [target, feature, strata])
    fmla = '{} ~ {} + strata({})'.format(target.name, feature.name, strata.name)
    fmla = robjects.Formula(fmla)
    df_r = process_factors([strata, target, feature])
    fit = lm(fmla, df_r)
    
    fmla = '{} ~ strata({})'.format(target.name, strata.name)
    fmla = robjects.Formula(fmla)
    fit_null = lm(fmla, df_r)
    
    f_stat = robjects.r.anova(fit_null, fit)[4][1]
    p = robjects.r.anova(fit_null, fit)[5][1]
    
    return pd.Series({'F': f_stat, 'p': p})

# %%
strata = calls.astype(str)
feature = df.ix['CELSR3'].ix[:,'01']
rr = rna.features.apply(stratified_regression, args=(feature, strata), axis=1)

# %%
rr['q'] = bhCorrection(rr.p)
rr.sort('p').head()
# Out:
#                                                            F         p         q
# REACTOME_A_THIRD_PROTEOLYTIC_CLEAVAGE_RELEASES_NICD    31.33  4.96e-08  4.13e-05
# BIOCARTA_ARF_PATHWAY                                   27.29  3.31e-07  1.38e-04
# REACTOME_CDC6_ASSOCIATION_WITH_THE_ORC_ORIGIN_COMPLEX  26.27  5.36e-07  1.49e-04
# BIOCARTA_SKP2E2F_PATHWAY                               25.41  8.08e-07  1.68e-04
# ST_INTERLEUKIN_13_PATHWAY                              24.11  1.51e-06  2.09e-04

# %%
target = rna.features.ix['REACTOME_A_THIRD_PROTEOLYTIC_CLEAVAGE_RELEASES_NICD']

# %%
target = rppa.features.ix['BIOCARTA_VEGF_PATHWAY']

# %%
rna.loadings.ix['REACTOME_A_THIRD_PROTEOLYTIC_CLEAVAGE_RELEASES_NICD'].order()
# Out:
# PSEN1    -0.24
# NCSTN    -0.20
# NOTCH3   -0.17
# NOTCH4   -0.13
# NOTCH2    0.18
# PSENEN    0.25
# PSEN2     0.87
# Name: 0, dtype: float64

# %%
fig, ax = subplots(1,1)
series_scatter(feature, target.ix[true_index(strata == strata.unique()[0])], ax=ax)
series_scatter(feature, target.ix[true_index(strata == strata.unique()[1])], ax=ax, color='r', ann=None)

# %%
fig, axs = subplots(1,2, figsize=(8,3), sharex=True, sharey=True)
series_scatter(feature, target.ix[true_index(strata == strata.unique()[0])], ax=axs[0])
series_scatter(feature, target.ix[true_index(strata == strata.unique()[1])], ax=axs[1])
fig.tight_layout()

# %%
strata = calls.astype(str)
feature = df.ix['CELSR3'].ix[:,'01']
rr = rppa.features.apply(stratified_regression, args=(feature, strata), axis=1)

# %%
rr['q'] = bhCorrection(rr.p)
rr.sort('p').head()
# Out:
#                                                                                   F         p     q
# BIOCARTA_VEGF_PATHWAY                                                         13.45  3.15e-04  0.15
# REACTOME_JNK_PHOSPHORYLATION_AND_ACTIVATION_MEDIATED_BY_ACTIVATED_HUMAN_TAK1  10.83  1.18e-03  0.19
# BIOCARTA_PPARA_PATHWAY                                                        10.35  1.51e-03  0.19
# ST_DIFFERENTIATION_PATHWAY_IN_PC12_CELLS                                       9.59  2.23e-03  0.19
# REACTOME_BASE_EXCISION_REPAIR                                                  9.39  2.48e-03  0.19

# %% [markdown]
# ####Co-expression of TP53 and FHIT
# * http://www.ncbi.nlm.nih.gov/pubmed/15313915

# %%
series_scatter(rna.df.ix['TP53'], rna.df.ix['FHIT'])
