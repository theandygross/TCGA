# %%
cd ../src
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
import os
import pickle

# %%
firehose_path = '/cellar/users/agross/Data/TCGA/'
date = '20120913'
date_ = '_'.join([date[:4], date[4:6], date[6:8]])
cancers = os.listdir(firehose_path + 'analyses__' + date_)

# %%
data_type = 'mutation'
report_ext = 'cov_age_rate_4'

clinical = {}
for cancer in cancers:
    data_path = firehose_path + 'analyses__' + date_ + '/' + cancer + '/' + date + '/'
    clinical_obj = data_path + data_type + '_' + report_ext + '/ClinicalObject.p'
    if os.path.isfile(clinical_obj):
        clinical[cancer] = clinical_obj

# %%
from Processing.Clinical import *
covariates = ['age','rate']
time_var = 'event_free_survival'
event_var = 'event'

# %%
cancer = pickle.load(open(clinical['OV'], 'rb'))

# %%
p = cancer.q_pathways.event_free_survival.idxmin()

# %%
p
# Out:
# 'BIOCARTA_TGFB_PATHWAY'

# %%
get_cox_ph(clinical, cancer.meta_matrix.ix[p].clip_upper(1),  
           covariates, time_var, event_var, return_val='all')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-4f3fb08580ad> in <module>()
#       1 get_cox_ph(clinical, cancer.meta_matrix.ix[p].clip_upper(1),
# ----> 2            covariates, time_var, event_var, return_val='all')
#
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src/Processing/Clinical.pyc in get_cox_ph(clinical, hit_vec, covariates, time_var, event_var, return_val)
#      86     hit_vec.name = 'pathway'
#      87     factors = ['pathway'] + covariates
# ---> 88     df = clinical.join(hit_vec)
#      89     df = df[factors + [time_var, event_var]]
#      90     #df = df.ix[patients]
#
# AttributeError: 'dict' object has no attribute 'join'
# age, rate not in clinical data... running anyway.

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-2ca2cafc5772> in <module>()
# ----> 1 cancer = pickle.load(open(clinical['OV'], 'rb'))
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getitem__(self, key)
#    1782                 raise ValueError('Cannot index using non-boolean DataFrame')
#    1783         else:
# -> 1784             return self._get_item_cache(key)
#    1785
#    1786     def _getitem_array(self, key):
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/generic.pyc in _get_item_cache(self, item)
#     529             return cache[item]
#     530         except Exception:
# --> 531             values = self._data.get(item)
#     532             res = self._box_item_values(item, values)
#     533             cache[item] = res
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/internals.pyc in get(self, item)
#     818
#     819     def get(self, item):
# --> 820         _, block = self._find_block(item)
#     821         return block.get(item)
#     822
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/internals.pyc in _find_block(self, item)
#     932
#     933     def _find_block(self, item):
# --> 934         self._check_have(item)
#     935         for i, block in enumerate(self.blocks):
#     936             if item in block:
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/internals.pyc in _check_have(self, item)
#     939     def _check_have(self, item):
#     940         if item not in self.items:
# --> 941             raise KeyError('no item named %s' % com.pprint_thing(item))
#     942
#     943     def reindex_axis(self, new_axis, method=None, axis=0, copy=True):
#
# KeyError: u'no item named OV'

# %%
cancer.clinical.deceased

# %%
def get_age_rate(cancer_obj):
    cancer = pickle.load(open(cancer_obj, 'rb'))
    covariates = ['age','rate']
    try:
        time_var = 'event_free_survival'
        event_var = 'event'
        clinical = cancer.clinical[[time_var, event_var] + covariates].dropna()
        
        rate = get_cox_ph(clinical, clinical.rate, [], time_var=time_var, event_var=event_var, 
                          return_val='all')
        age = get_cox_ph(clinical, clinical.age, [], time_var=time_var, event_var=event_var, 
                          return_val='all')
    except:
        time_var = 'days'
        event_var = 'deceased'
        clinical = cancer.clinical[[time_var, event_var] + covariates].dropna()
        
        rate = get_cox_ph(clinical, clinical.rate, [], time_var=time_var, event_var=event_var, 
                          return_val='all')
        age = get_cox_ph(clinical, clinical.age, [], time_var=time_var, event_var=event_var, 
                          return_val='all')
    return DataFrame({'age': age.ix[0], 'rate' : rate.ix[0]})

# %%
age_rate = dict((cancer, get_age_rate(cancer_obj)) for cancer, cancer_obj in clinical.iteritems())
# Out:
#     test       df   pvalue
# 1.460365 1.000000 0.226872
#
#      test        df    pvalue
# 1.4981850 1.0000000 0.2209508
#
#      test        df    pvalue
# 1.2012618 1.0000000 0.2730696
#         test           df       pvalue
# 1.367463e+01 1.000000e+00 2.173716e-04
#       test         df     pvalue
# 3.04547314 1.00000000 0.08096252
#         test           df       pvalue
# 2.659825e+01 1.000000e+00 2.504708e-07
#
#      test        df    pvalue
# 0.7162109 1.0000000 0.3973896
#       test         df     pvalue
# 5.07214804 1.00000000 0.02431324
#
#      test        df    pvalue
# 1.2319105 1.0000000 0.2670358
#        test          df      pvalue
# 0.008860884 1.000000000 0.925004087
#
#       test         df     pvalue
# 3.27256449 1.00000000 0.07044742
#      test        df    pvalue
# 1.2252771 1.0000000 0.2683275
#
#        test          df      pvalue
# 8.345727826 1.000000000 0.003865953
#         test           df       pvalue
# 2.093734e+01 1.000000e+00 4.745545e-06
#
#      test        df    pvalue
# 1.7118591 1.0000000 0.1907443
#      test        df    pvalue
# 1.9015310 1.0000000 0.1679071
#
#       test         df     pvalue
# 5.94740996 1.00000000 0.01473893
#      test        df    pvalue
# 2.6511279 1.0000000 0.1034765

# %%
from pandas import Panel

# %%
ar = Panel(age_rate)
z = ar.major_xs('z').T
z = z.rename_axis({'age':'age', 'rate':'mutation rate'})

fig, ax = subplots()
ax.hlines([1.96,-1.96], 0,10, linestyles='--', color='black')
r = z.sort(columns='mutation rate').plot(kind='bar', ax=ax)
ax.set_ylabel('Cox Regression: z score')
fig.savefig('age_rate_survival.svg')

# %%
cancer = pickle.load(open(clinical['OV'], 'rb'))

# %%
plt.hist?

# %%
fig, ax = subplots(2,4, figsize=)

# %%
def get_densities(cancer_obj):
    cancer = pickle.load(open(cancer_obj, 'rb'))
    vec = cancer.hit_matrix.sum(1).astype(float)
    vec = vec / cancer.hit_matrix.shape[1]
    return vec

# %%
densities = dict((cancer, get_densities(cancer_obj)) for cancer, cancer_obj in clinical.iteritems())

# %%
DataFrame(densities).ix['TP53'].plot(kind='bar')

# %%
fig, axs = subplots(3,3, sharex=True, sharey=True, figsize=(7,4))
for i,(cancer,vec) in enumerate(densities.iteritems()):
    #vec = vec[vec > 0]
    (vec.value_counts() / float(len(vec))).sort_index().plot(ax=axs[i/3, i%3], lw=5)
    axs[i/3, i%3].set_xscale('log')
    axs[i/3, i%3].annotate(cancer, (.95,.75), xycoords='axes fraction', fontsize=18, ha='right')
    #if (i%3) == 0:
    #    axs[i/3, i%3].set_ylabel('# genes')
    #if (i/3) == 2:
    #    axs[i/3, i%3].set_xlabel('fraction of cohort')
vec = densities['BRCA']
axs[0,0].set_xbound(vec[vec > 0].min(), 1)
axs[0,0].set_ybound(0,.3)
for i in range(3):
    plt.setp(axs[2,i].get_xticklabels(), fontsize=14)
    plt.setp(axs[i,0].get_yticklabels(), fontsize=14)
fig.tight_layout()
fig.savefig('densities.svg', transparent=True)

# %%
cancer = pickle.load(open(clinical['LAML'], 'rb'))

from Processing.Clinical import *
covariates = ['age','rate']
time_var = 'days'
event_var = 'deceased'

clinical = cancer.clinical[[time_var, event_var] + covariates].dropna()

# %%
from Reports.Figures import *
from IPython.display import Image

# %%
p = cancer.q_pathways.survival.idxmin()

# %%
clinical['p53'] = cancer.hit_matrix.ix['TP53'].clip_upper(1.)

# %%
p = 'KEGG_UBIQUITIN_MEDIATED_PROTEOLYSIS'
hit_vec = cancer.meta_matrix.ix[p].clip_upper(1)

res = get_cox_ph(clinical, cancer.meta_matrix.ix[p].clip_upper(1),  
           covariates, time_var, event_var, return_val='all')

draw_survival_curves_KM(clinical, hit_vec, show=True, title=False,
                        time_var=time_var, event_var=event_var, filename='LAML_Ubiqutitn.pdf')

print res
Image(filename='tmp1.png')
# Out:
#         test           df       pvalue
# 3.675089e+01 5.000000e+00 6.719142e-07
#
#                   coef  exp(coef)  se(coef)         z  Pr(>|z|)
# pathway       1.122362   3.072103  0.364461  3.079510  0.002073
# age           0.034452   1.035053  0.007335  4.697142  0.000003
# rate          0.055385   1.056948  0.148434  0.373130  0.709052
# pathway:age   0.015279   1.015397  0.021963  0.695684  0.486627
# pathway:rate -0.508538   0.601374  0.275554 -1.845509  0.064964

# %%
draw_pathway_count_bar(p, cancer, file_name='LAML_Ubiquitin_bar.svg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-4003f33b6bee> in <module>()
# ----> 1 draw_pathway_count_bar(p, cancer, file_name='LAML_Ubiquitin_bar.svg')
#
# <ipython-input-19-02128b59d7b3> in draw_pathway_count_bar(p, cancer, file_name)
#      30 def draw_pathway_count_bar(p, cancer, file_name='tmp.svg'):
#      31     fig, ax = plt.subplots(1,1, figsize=(3+len(cancer.gene_sets[p])/30.,2))
# ---> 32     m = cancer.hit_matrix.ix[list(cancer.gene_sets[p]), cancer.patients] > 0
#      33     m = np.sort(m[m.sum(1) > 0].sum(1))
#      34     colors = ['orange']*(len(m))
#
# AttributeError: 'ClinicalObject' object has no attribute 'patients'

# %%
hit_vec = cancer.hit_matrix.ix[list(cancer.gene_sets[p] - set(['TP53']))].sum().clip_upper(1)

# %%
get_cox_ph(clinical, hit_vec, covariates + ['p53'], time_var, event_var, return_val='all')
# Out:
#         test           df       pvalue
# 4.218993e+01 7.000000e+00 4.779900e-07
#                   coef  exp(coef)  se(coef)         z  Pr(>|z|)
# pathway       1.106269   3.023058  0.375864  2.943268  0.003248
# age           0.033808   1.034386  0.007456  4.534471  0.000006
# rate          0.001166   1.001167  0.149083  0.007821  0.993760
# p53           1.078072   2.939009  0.403782  2.669936  0.007587
# pathway:age   0.014457   1.014562  0.025008  0.578084  0.563207
# pathway:rate -0.444655   0.641045  0.284611 -1.562328  0.118211
# pathway:p53  -1.066737   0.344130  0.812907 -1.312249  0.189436

# %%
def draw_survival_curves_KM(clinical, hit_vec, time_var='days', event_var='deceased',
                            filename='tmp.png', show=False, ax=None, title=True, 
                            labels=['No Mutation', 'Mutation'], ann=None):
    if not hasattr(hit_vec, 'name'):
        hit_vec.name = 'pathway'
    df = clinical[[time_var, event_var]].join(hit_vec)
    df = df.dropna()
    df_r = com.convert_to_r_dataframe(df) #@UndefinedVariable
    fmla = robjects.Formula('Surv(' + time_var + ', ' + event_var + ') ~ ' + hit_vec.name)
    fit = survival.survfit(fmla, df_r)
    ls = r('2:' + str(len(set(hit_vec))+1)) #R line styles
    if filename.endswith('.png'):
        r.png(filename=filename, width=300, height=250, res=100, pointsize=8)
    else:
        r.pdf(filename, width=4.5, height=3.75)
    s = survival.survdiff(fmla, df_r)
    p = str(s).split('\n\n')[-1].strip().split(', ')[-1]
    ls = r.c('blue','red','red')
    r.plot(survival.survfit(fmla, df_r), lty=1, col=ls, lwd=3, cex=1.5, 
                            xlab='Days to Event', ylab= 'Survival');
    if title:
        r('title')(hit_vec.name)
    r('legend')(nanmax(df[time_var]) * .5,.9, labels, lty=1, col=ls, lwd=3)
    if ann=='p':
        r.text(0, labels='logrank ' + p, pos=4)
    elif ann != None:
        r.text(0, labels=ann, pos=4)
    r('dev.off()')
    
def draw_pathway_count_bar(p, cancer, file_name='tmp.svg'):
    fig, ax = plt.subplots(1,1, figsize=(3+len(cancer.gene_sets[p])/30.,2))
    m = cancer.hit_matrix.ix[list(cancer.gene_sets[p]), cancer.patients] > 0
    m = np.sort(m[m.sum(1) > 0].sum(1))
    colors = ['orange']*(len(m))
    m.plot(kind='bar', ax=ax, alpha=.7, color=colors);
    ax.set_yticks(range(m.max()+1))
    ax.set_xticklabels(m.index, ha='center', va='bottom', position=(0,.1), size=20)
    ax.set_ylabel('# Patients', size=16)
    
    fig.tight_layout()
    fig.savefig(file_name)

# %%
def draw_survival_curves_COX(clinical, hit_vec, covariates=[], time_var='days',
                         event_var='censored', filename='tmp.png',
                         labels=['No Mutation', 'Mutation']):
    if not all([cov in clinical for cov in covariates]):
        missing = [cov for cov in covariates if cov not in clinical]
        covariates = [cov for cov in covariates if cov in clinical]
    
    hit_vec.name = 'pathway'
    factors = ['pathway'] + covariates
    df = clinical.join(hit_vec)
    df[event_var]  = df[event_var].fillna(0)
    df = df[factors + [time_var, event_var]]
    df = df.dropna()
    df[covariates] = (df[covariates] - df[covariates].mean())
    df_r = com.convert_to_r_dataframe(df) #@UndefinedVariable
    #fmla = 'Surv(' + time_var + ', ' + event_var + ') ~ '+ '*'.join(factors)
    interactions = '+'.join(['pathway*' + c for c in covariates])
    if len(covariates) == 0:
        interactions = 'pathway'
    fmla = 'Surv(' + time_var + ', ' + event_var + ') ~ ' + interactions
    fmla = robjects.Formula(fmla)
    
    s = survival.coxph(fmla, df_r)
    results = com.convert_robj(dict(base.summary(s).iteritems())['coefficients'])
    print results
    
    df_2 = DataFrame({'pathway' : [0,1,0], 'p53' : [0,0,1]})
    #print df_2
    #return df_2,df
    for cov in ['age','rate']:
        df_2[cov] = [df[cov].median()]*3
    df_2 = com.convert_to_r_dataframe(df_2) #@UndefinedVariable
    
    f = survival.survfit(s, newdata=df_2)
    ls = r('2:' + str(len(set(hit_vec))+2)) #R line styles
    if filename.endswith('.png'):
        r.png(filename=filename, width=300, height=300, res=100, pointsize=8)
    else:
        r.pdf(filename, width=4, height=4)
        
    r.plot(f, lty=1, col=ls, lwd=3, cex=1.5, xlab='Days to Event', 
           ylab= 'Adj. Survival');
    r.text(0, labels='p = ' + '%2.2e'%results.ix['pathway'].ix[-1], pos=4)
    r.title('Cox PH Model')
    
    r.legend(nanmax(df[time_var]) * .5, .95, labels, lty=1, col=ls)
    r('dev.off()');

# %%
vec = hit_vec - clinical.p53
vec.name = 'Effect'
draw_survival_curves_KM(clinical, vec, show=True, labels=['p53','none','other_wnt'],
                        time_var=time_var, event_var=event_var, filename='tmp1.png')

Image(filename='tmp1.png')

# %%
rate_norm = (clinical.age - clinical.age.mean()) / clinical.age.std()
rate_split = (rate_norm < -1)*-1 + (rate_norm.abs() < 1.5) * 0 + (rate_norm > 1)*1
low = clinical.rate.ix[(rate_norm - 1).idxmin()]
high = clinical.rate.ix[abs(rate_norm + 1).idxmin()]
rate_split.name = 'age'
draw_survival_curves_KM(clinical, rate_split, show=True, labels=['low','normal','high'],
                        time_var=time_var, event_var=event_var, filename='tmp1.png',
                        ann='p')

Image(filename='tmp1.png')

# %%
cancer = pickle.load(open(clinical['OV'], 'rb'))


from Processing.Clinical import *
covariates = ['age','rate']
time_var = 'event_free_survival'
event_var = 'event'

clinical = cancer.clinical[[time_var, event_var] + covariates].dropna()
cancer.patients = clinical.index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-4b88e9348d0d> in <module>()
# ----> 1 cancer = pickle.load(open(clinical['OV'], 'rb'))
#       2
#       3
#       4 from Processing.Clinical import *
#       5 covariates = ['age','rate']
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getitem__(self, key)
#    1782                 raise ValueError('Cannot index using non-boolean DataFrame')
#    1783         else:
# -> 1784             return self._get_item_cache(key)
#    1785
#    1786     def _getitem_array(self, key):
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/generic.pyc in _get_item_cache(self, item)
#     529             return cache[item]
#     530         except Exception:
# --> 531             values = self._data.get(item)
#     532             res = self._box_item_values(item, values)
#     533             cache[item] = res
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/internals.pyc in get(self, item)
#     818
#     819     def get(self, item):
# --> 820         _, block = self._find_block(item)
#     821         return block.get(item)
#     822
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/internals.pyc in _find_block(self, item)
#     932
#     933     def _find_block(self, item):
# --> 934         self._check_have(item)
#     935         for i, block in enumerate(self.blocks):
#     936             if item in block:
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/internals.pyc in _check_have(self, item)
#     939     def _check_have(self, item):
#     940         if item not in self.items:
# --> 941             raise KeyError('no item named %s' % com.pprint_thing(item))
#     942
#     943     def reindex_axis(self, new_axis, method=None, axis=0, copy=True):
#
# KeyError: u'no item named OV'

# %%
p = 'REACTOME_P53_INDEPENDENT_DNA_DAMAGE_RESPONSE'
hit_vec = cancer.meta_matrix.ix[p].clip_upper(1)

res = get_cox_ph(clinical, cancer.meta_matrix.ix[p].clip_upper(1),  
           covariates, time_var, event_var, return_val='all')

draw_survival_curves_KM(clinical, hit_vec, show=True, title=False,
                        time_var=time_var, event_var=event_var, filename='OV_P53_independent.pdf')

print res
Image(filename='tmp1.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-3666c499e751> in <module>()
#       1 p = 'REACTOME_P53_INDEPENDENT_DNA_DAMAGE_RESPONSE'
# ----> 2 hit_vec = cancer.meta_matrix.ix[p].clip_upper(1)
#       3
#       4 res = get_cox_ph(clinical, cancer.meta_matrix.ix[p].clip_upper(1),
#       5            covariates, time_var, event_var, return_val='all')
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/indexing.pyc in __getitem__(self, key)
#      32             return self._getitem_tuple(key)
#      33         else:
# ---> 34             return self._getitem_axis(key, axis=0)
#      35
#      36     def _get_label(self, label, axis=0):
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#     343                     return self._get_loc(key, axis=0)
#     344
# --> 345             return self._get_label(idx, axis=0)
#     346         else:
#     347             labels = self.obj._get_axis(axis)
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/indexing.pyc in _get_label(self, label, axis)
#      44             return self.obj.xs(label, axis=axis, copy=False)
#      45         except Exception:
# ---> 46             return self.obj.xs(label, axis=axis, copy=True)
#      47
#      48     def _get_loc(self, key, axis=0):
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in xs(self, key, axis, level, copy)
#    2086             loc, new_index = self.index.get_loc_level(key)
#    2087         else:
# -> 2088             loc = self.index.get_loc(key)
#    2089
#    2090             if isinstance(loc, np.ndarray):
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/core/index.pyc in get_loc(self, key)
#     668         loc : int
#     669         """
# --> 670         return self._engine.get_loc(key)
#     671
#     672     def get_value(self, series, key):
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/lib.so in pandas.lib.IndexEngine.get_loc (pandas/src/tseries.c:124477)()
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/lib.so in pandas.lib.IndexEngine.get_loc (pandas/src/tseries.c:124357)()
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/lib.so in pandas.lib.PyObjectHashTable.get_item (pandas/src/tseries.c:23615)()
#
# /cellar/users/agross/semillon/epd/lib/python2.7/site-packages/pandas-0.9.1rc1-py2.7-linux-x86_64.egg/pandas/lib.so in pandas.lib.PyObjectHashTable.get_item (pandas/src/tseries.c:23569)()
#
# KeyError: 'REACTOME_P53_INDEPENDENT_DNA_DAMAGE_RESPONSE'

# %%
draw_pathway_count_bar(p, cancer, file_name='OV_P53_independent_bars.svg')

# %%
p = 'REACTOME_NA_CL_DEPENDENT_NEUROTRANSMITTER_TRANSPORTERS'
hit_vec = cancer.meta_matrix.ix[p].clip_upper(1)

res = get_cox_ph(clinical, cancer.meta_matrix.ix[p].clip_upper(1),  
           covariates, time_var, event_var, return_val='all')

draw_survival_curves_KM(clinical, hit_vec, show=True, title=False,
                        time_var=time_var, event_var=event_var, filename='OV_nacl.pdf')

print res
Image(filename='tmp1.png')
# Out:
#         test           df       pvalue
# 2.101329e+01 5.000000e+00 8.053888e-04
#
#                   coef  exp(coef)  se(coef)         z  Pr(>|z|)
# pathway       1.088179   2.968864  0.277008  3.928329  0.000086
# age           0.013748   1.013843  0.006918  1.987342  0.046885
# rate         -0.414127   0.660917  0.134998 -3.067653  0.002157
# pathway:age   0.040809   1.041653  0.026964  1.513457  0.130164
# pathway:rate -0.555720   0.573659  0.501351 -1.108444  0.267670

# %%
draw_pathway_count_bar(p, cancer, file_name='OV_nacl_bar.svg')

# %%
p = 'BIOCARTA_TGFB_PATHWAY'
hit_vec = cancer.meta_matrix.ix[p].clip_upper(1)

res = get_cox_ph(clinical, cancer.meta_matrix.ix[p].clip_upper(1),  
           covariates, time_var, event_var, return_val='all')

draw_survival_curves_KM(clinical, hit_vec, show=True, title=False,
                        time_var=time_var, event_var=event_var, filename='OV_TGFB.pdf')

print res
Image(filename='tmp1.png')
# Out:
#         test           df       pvalue
# 20.382144041  5.000000000  0.001059277
#
#                   coef  exp(coef)  se(coef)         z  Pr(>|z|)
# pathway       1.131104   3.099077  0.304958  3.709054  0.000208
# age           0.012183   1.012257  0.006819  1.786469  0.074023
# rate         -0.402501   0.668646  0.137033 -2.937244  0.003311
# pathway:age  -0.007912   0.992119  0.021055 -0.375800  0.707066
# pathway:rate -0.347056   0.706766  0.676085 -0.513331  0.607720

# %%
draw_pathway_count_bar(p, cancer, file_name='OV_TGFB_bars.svg')

# %%
data_type = 'amplification'
report_ext = 'cov_age_rate_4'

clinical = {}
for cancer in cancers:
    data_path = firehose_path + 'analyses__' + date_ + '/' + cancer + '/' + date + '/'
    clinical_obj = data_path + data_type + '_' + report_ext + '/ClinicalObject.p'
    if os.path.isfile(clinical_obj):
        clinical[cancer] = clinical_obj

# %%
cancer = pickle.load(open(clinical['LUAD'], 'rb'))


from Processing.Clinical import *
covariates = ['age','rate']
time_var = 'event_free_survival'
event_var = 'event'

clinical = cancer.clinical[[time_var, event_var] + covariates].dropna()
cancer.patients = clinical.index

# %%
p = 'REACTOME_GLYCOGEN_BREAKDOWN_GLYCOGENOLYSIS'
hit_vec = cancer.meta_matrix.ix[p].clip_upper(1)

res = get_cox_ph(clinical, cancer.meta_matrix.ix[p].clip_upper(1),  
           covariates, time_var, event_var, return_val='all')

draw_survival_curves_KM(clinical, hit_vec, show=True, title=False,
                        time_var=time_var, event_var=event_var, filename='OV_glycogenolysis.pdf',
                        labels=['Not Amplified', 'Amplified'])

print res
Image(filename='tmp1.png')
# Out:
#        test          df      pvalue
# 13.10651128  5.00000000  0.02240083
#
#                   coef  exp(coef)  se(coef)         z  Pr(>|z|)
# pathway       1.236650   3.444058  0.367350  3.366405  0.000762
# age           0.022519   1.022775  0.013842  1.626865  0.103766
# rate         -0.076123   0.926702  0.097205 -0.783117  0.433559
# pathway:age   0.031030   1.031517  0.032435  0.956699  0.338719
# pathway:rate -0.578091   0.560968  0.271433 -2.129776  0.033190

# %%
def draw_pathway_count_bar(p, cancer, file_name='tmp.svg'):
    fig, ax = plt.subplots(1,1, figsize=(3+len(cancer.gene_sets[p])/8.,2))
    m = cancer.hit_matrix.ix[list(cancer.gene_sets[p]), cancer.patients] > 0
    m = np.sort(m[m.sum(1) > 0].sum(1))
    colors = ['red']*(len(m))
    m.plot(kind='bar', ax=ax, alpha=.7, color=colors);
    ax.set_yticks(range(m.max()+1))
    ax.set_xticklabels(m.index, ha='center', va='bottom', position=(0,.1), size=20)
    ax.set_ylabel('# Patients', size=16)
    
    fig.tight_layout()
    fig.savefig(file_name)
draw_pathway_count_bar(p, cancer, file_name='OV_glycogenolysis_bar.svg')

# %%
crosstab(cancer.meta_matrix.ix['REACTOME_GAP_JUNCTION_ASSEMBLY'], cancer.clinical.smoking_status).T.plot(kind='bar')

# %%
fig, ax = subplots()
violin_plot_pandas(cancer.meta_matrix.ix['REACTOME_MYD88_CASCADE'], cancer.clinical.pack_years, ax=ax);
ax.set_ylabel('Pack Years');

# %%
fig, ax = subplots()
violin_plot_pandas(cancer.meta_matrix.ix['REACTOME_MYD88_CASCADE'], cancer.clinical.pack_years, ax=ax);
ax.set_ylabel('Pack Years');

# %%
data_type = 'deletion'
report_ext = 'cov_age_rate_4'

clinical = {}
for cancer in cancers:
    data_path = firehose_path + 'analyses__' + date_ + '/' + cancer + '/' + date + '/'
    clinical_obj = data_path + data_type + '_' + report_ext + '/ClinicalObject.p'
    if os.path.isfile(clinical_obj):
        clinical[cancer] = clinical_obj

# %%
cancer = pickle.load(open(clinical['LUAD'], 'rb'))


from Processing.Clinical import *
covariates = ['age','rate']
time_var = 'event_free_survival'
event_var = 'event'

clinical = cancer.clinical[[time_var, event_var] + covariates].dropna()
cancer.patients = clinical.index

# %%
cancer.

# %%
p = 'REACTOME_ERK_MAPK_TARGETS'
hit_vec = cancer.meta_matrix.ix[p].clip_upper(1)

res = get_cox_ph(clinical, cancer.meta_matrix.ix[p].clip_upper(1),  
           covariates, time_var, event_var, return_val='all')

draw_survival_curves_KM(clinical, hit_vec, show=True, title=False,
                        time_var=time_var, event_var=event_var, filename='tmp1.png',
                        labels=['Not Amplified', 'Amplified'])

print res
Image(filename='tmp1.png')
# Out:
#         test           df       pvalue
# 19.102539520  5.000000000  0.001839406
#
#                   coef  exp(coef)  se(coef)         z  Pr(>|z|)
# pathway       3.906559  49.727547  0.829513  4.709461  0.000002
# age           0.007155   1.007181  0.013306  0.537728  0.590765
# rate         -0.379751   0.684032  0.104350 -3.639214  0.000273
# pathway:age  -0.004749   0.995262  0.033632 -0.141200  0.887712
# pathway:rate -1.842453   0.158428  0.405081 -4.548362  0.000005

# %%
violin_plot_pandas(hit_vec, clinical.rate);

# %%
(hit_vec * (clinical.rate < 5.8)).sum()
# Out:
# 17.0

# %%
get_cox_ph(clinical, (hit_vec * (clinical.rate > 5.8)), [], time_var, event_var, return_val='all')
# Out:
#      test        df    pvalue
# 1.8864500 1.0000000 0.1696029
#                            coef  exp(coef)  se(coef)         z  Pr(>|z|)
# pathway0.872222222222 -0.528444   0.589522  0.409565 -1.290256  0.196962

# %%
age_rate = dict((cancer, get_age_rate(cancer_obj)) for cancer, cancepr_obj in clinical.iteritems())
# Out:
#        test          df      pvalue
# 0.005503097 1.000000000 0.940864883
#
#        test          df      pvalue
# 6.719275499 1.000000000 0.009537636
#
#      test        df    pvalue
# 0.0923222 1.0000000 0.7612455
#         test           df       pvalue
# 2.220217e+01 1.000000e+00 2.453961e-06
#
#      test        df    pvalue
# 0.8789878 1.0000000 0.3484791
#        test          df      pvalue
# 9.972563703 1.000000000 0.001588901
#
#      test        df    pvalue
# 2.6914598 1.0000000 0.1008873
#       test         df     pvalue
# 5.39859683 1.00000000 0.02015295
#
#      test        df    pvalue
# 0.8491551 1.0000000 0.3567915
#      test        df    pvalue
# 0.6892479 1.0000000 0.4064203
#
#         test           df       pvalue
# 3.347961e-05 1.000000e+00 9.953833e-01
#      test        df    pvalue
# 1.0275649 1.0000000 0.3107313
#
#        test          df      pvalue
# 0.007030031 1.000000000 0.933179447
#        test          df      pvalue
# 7.121423449 1.000000000 0.007616821
#
#      test        df    pvalue
# 1.4448036 1.0000000 0.2293636
#        test          df      pvalue
# 7.942088608 1.000000000 0.004829806
#
#      test        df    pvalue
# 0.1073489 1.0000000 0.7431828
#      test        df    pvalue
# 1.0292970 1.0000000 0.3103238

# %%
ar = Panel(age_rate)
z = ar.major_xs('z').T
z = z.rename_axis({'age':'age', 'rate':'deletion rate'})

fig, ax = subplots()
ax.hlines([1.96,-1.96], 0,10, linestyles='--', color='black')
r = z.sort(columns='deletion rate').plot(kind='bar', ax=ax)
ax.set_ylabel('Cox Regression: z score')
#fig.savefig('age_rate_survival.svg')

# %%
data_type = 'methylation'
report_ext = 'cov_age_4'

clinical = {}
for cancer in cancers:
    data_path = firehose_path + 'analyses__' + date_ + '/' + cancer + '/' + date + '/'
    clinical_obj = data_path + data_type + '_' + report_ext + '/ClinicalObject.p'
    if os.path.isfile(clinical_obj):
        clinical[cancer] = clinical_obj

# %%
clinical
# Out:
# {}
