# %%
cd ../src/
# Out:
# /cellar/users/agross/TCGA_Code/TCGA/Pathway_Merge/src

# %%
import pandas as pandas
from Data.Pathways import read_in_pathways
from Processing.Clinical import ClinicalObject
import pickle as pickle
import os as os

pandas.set_printoptions(max_columns=300)

# %%
firehose_path = '/cellar/users/agross/Data/TCGA/'
date = '20120913'
date_ = '_'.join([date[:4], date[4:6], date[6:8]])
pathway_file = '/cellar/users/agross/Data/GeneSets/c2.cp.v3.0.symbols_edit.csv'
gene_sets, gene_lookup = read_in_pathways(pathway_file)
cancers = os.listdir(firehose_path + 'analyses__' + date_)

# %%
cancer = 'BRCA'
data_path = firehose_path + 'analyses__' + date_ + '/' + cancer + '/' + date + '/'
cancer = ClinicalObject(cancer, data_path, gene_sets, data_type='deletion')

# %%
cancer.filter_bad_pathways(gene_lookup)

# %%
from Reports.Figures import *
from Processing.Clinical import *

# %%
p53 = cancer.hit_matrix.ix['BIOCARTA_NEUROTRANSMITTERS_PATHWAY']>0
p53_vec = (cancer.clinical.triple_neg[p53[p53].index]).astype(float)
get_cox_ph(cancer.clinical, p53_vec, event_var='deceased', covariates=['age','rate'])

# %%
cancer.lesion_matrix.ix['17q12   '].value_counts()
# Out:
# 0    723
# 1    124

# %%
cancer.clinical.her2_pos = cancer.clinical.her2_pos == 'True'

# %%
p53 = cancer.meta_matrix.ix['SIG_CHEMOTAXIS']>0
p53_vec = (cancer.clinical.triple_neg[p53[p53].index]).astype(float)
get_cox_ph(cancer.clinical, p53_vec, event_var='deceased', covariates=['age','rate'])
# Out:
# 0.036848648989781463

# %%
def draw_survival_curves(clinical, hit_vec, ime_var='days', event_var='censored',
                         filename='tmp.png', show=False, 
                         ax=None, title=True, labels=['No Mutation', 'Mutation']):
    hit_vec.name = 'pathway'
    df = clinical.join(hit_vec)
    df = com.convert_to_r_dataframe(df) #@UndefinedVariable
    fmla = robjects.Formula('Surv(days, censored) ~ ' + hit_vec.name)
    fit = survival.survfit(fmla, df)
    r('png')(filename=filename)
    ls = r('2:' + str(len(set(hit_vec))+1)) #R line styles
    r('plot')(fit, lty=ls, col=ls, xlab='Days to Death', ylab= 'Survival')
    if title:
        r('title')(hit_vec.name)
    r('legend')(nanmax(clinical.days) * .7,.9, labels, lty=ls, col=ls)
    r('dev.off()')
    if ax or show:
        img = plt.imread(filename)
        if ax is None:
            fig,ax = plt.subplots(1,1, figsize=(7,7), frameon=False)
        ax.imshow(img)
        ax.set_axis_off()
        ax.get_figure().tight_layout()

# %%
fischer_bar_chart(cancer.meta_matrix.ix['SIG_CHEMOTAXIS']>0, cancer.clinical.triple_neg);

# %%
gene_sets['REACTOME_ETHANOL_OXIDATION']
# Out:
# set(['ADH7',
#      'ADH6',
#      'ADH4',
#      'ACSS2',
#      'ACSS1',
#      'ALDH2',
#      'ADH1C',
#      'ADH1B',
#      'ADH1A',
#      'ALDH1A1'])

# %%
np.sort(cancer.q_pathways.event_free_survival)
# Out:
# BIOCARTA_AKAP13_PATHWAY                         0.488668
# BIOCARTA_ATM_PATHWAY                            0.488668
# BIOCARTA_BCELLSURVIVAL_PATHWAY                  0.488668
# BIOCARTA_CERAMIDE_PATHWAY                       0.488668
# BIOCARTA_G2_PATHWAY                             0.488668
# BIOCARTA_GABA_PATHWAY                           0.488668
# BIOCARTA_INSULIN_PATHWAY                        0.488668
# BIOCARTA_RELA_PATHWAY                           0.488668
# BIOCARTA_TPO_PATHWAY                            0.488668
# BIOCARTA_VDR_PATHWAY                            0.488668
# KEGG_ARGININE_AND_PROLINE_METABOLISM            0.488668
# KEGG_ASCORBATE_AND_ALDARATE_METABOLISM          0.488668
# KEGG_ENDOCYTOSIS                                0.488668
# KEGG_FC_GAMMA_R_MEDIATED_PHAGOCYTOSIS           0.488668
# KEGG_GLYCINE_SERINE_AND_THREONINE_METABOLISM    0.488668
# ...
# REACTOME_TRAF6_MEDIATED_INDUCTION_OF_THE_ANTIVIRAL_CYTOKINE_IFN_ALPHA_BETA_CASCADE    0.99996
# REACTOME_TRANSFORMATION_OF_LANOSTEROL_TO_CHOLESTEROL            0.99996
# REACTOME_TRNA_AMINOACYLATION                                    0.99996
# REACTOME_VIRAL_DSRNA_TLR3_TRIF_COMPLEX_ACTIVATES_RIP1           0.99996
# REACTOME_XENOBIOTICS                                            0.99996
# REACTOME_ZINC_INFLUX_INTO_CELLS_BY_THE_SLC39_GENES_FAMILY       0.99996
# SA_FAS_SIGNALING                                                0.99996
# SA_MMP_CYTOKINE_CONNECTION                                      0.99996
# SA_TRKA_RECEPTOR                                                0.99996
# ST_DIFFERENTIATION_PATHWAY_IN_PC12_CELLS                        0.99996
# ST_IL_13_PATHWAY                                                0.99996
# ST_INTERFERON_GAMMA_PATHWAY                                     0.99996
# ST_INTERLEUKIN_13_PATHWAY                                       0.99996
# ST_JAK_STAT_PATHWAY                                             0.99996
# ST_TYPE_I_INTERFERON_PATHWAY                                    0.99996
# Name: event_free_survival, Length: 831

# %%
cancer.q_genes.describe()
# Out:
#        tumor_t1t2  lymphnode_n0n1  event_free_survival  triple_neg  gender         age      PR_pos      ER_pos  triple_pos        rate  post_menopause        AMAR      survival    her2_pos
# count  500.000000      500.000000         4.940000e+02  500.000000     500  500.000000  500.000000  500.000000         500  500.000000             500  500.000000  5.000000e+02  500.000000
# mean     0.982744        0.822509         9.999727e-01    0.406191       1    0.997535    0.342237    0.281904           1    0.003121               1    0.249408  9.979008e-01    0.848850
# std      0.021512        0.174779         9.483397e-08    0.332939       0    0.000000    0.357094    0.309166           0    0.017800               0    0.225598  4.471692e-02    0.232471
# min      0.955980        0.378419         9.999727e-01    0.011714       1    0.997535    0.006899    0.000833           1    0.000022               1    0.001656  4.096723e-11    0.191283
# 25%      0.955980        0.739924         9.999727e-01    0.106087       1    0.997535    0.017815    0.013692           1    0.000029               1    0.044540  9.999006e-01    0.713819
# 50%      1.000000        0.739924         9.999727e-01    0.254382       1    0.997535    0.139222    0.106687           1    0.000159               1    0.240380  9.999006e-01    1.000000
# 75%      1.000000        1.000000         9.999727e-01    0.748806       1    0.997535    0.656761    0.603229           1    0.001044               1    0.382014  9.999006e-01    1.000000
# max      1.000000        1.000000         9.999727e-01    1.000000       1    0.997535    1.000000    1.000000           1    0.150384               1    0.858409  9.999006e-01    1.000000

# %%
cancer.q_pathways.describe()
# Out:
#        tumor_t1t2  lymphnode_n0n1  event_free_survival  triple_neg  gender         age      PR_pos        ER_pos  triple_pos           rate  post_menopause        AMAR    survival    her2_pos
# count         831      831.000000           831.000000  831.000000     831  831.000000  831.000000  8.310000e+02         831   8.310000e+02             831  831.000000  831.000000  831.000000
# mean            1        0.515004             0.746891    0.123953       1    0.971179    0.065686  4.112102e-02           1   9.257448e-06               1    0.129355    0.990984    0.521124
# std             0        0.254502             0.183791    0.215350       0    0.008961    0.174699  1.269362e-01           0   1.280379e-04               0    0.214715    0.073130    0.281932
# min             1        0.115587             0.488668    0.000000       1    0.965893    0.000002  1.096355e-08           1  1.548883e-100               1    0.001574    0.001676    0.058781
# 25%             1        0.306334             0.561113    0.001998       1    0.965893    0.000465  4.276878e-05           1   3.041922e-40               1    0.012766    0.999889    0.283035
# 50%             1        0.440125             0.747804    0.022299       1    0.965893    0.003691  7.784319e-04           1   2.490055e-23               1    0.038462    0.999889    0.446763
# 75%             1        0.727153             0.911228    0.138011       1    0.974926    0.033156  1.165591e-02           1   5.977136e-15               1    0.127041    0.999889    0.789768
# max             1        1.000000             0.999960    1.000000       1    0.998583    1.000000  1.000000e+00           1   2.545773e-03               1    0.986977    0.999889    1.000000

# %%
np.sort(cancer.q_pathways.triple_neg)
# Out:
# SIG_CHEMOTAXIS                                       0.000000
# KEGG_PHOSPHATIDYLINOSITOL_SIGNALING_SYSTEM           0.000000
# KEGG_CELL_CYCLE                                      0.000000
# KEGG_TIGHT_JUNCTION                                  0.000000
# REACTOME_SIGNALLING_BY_NGF                           0.000000
# ST_PHOSPHOINOSITIDE_3_KINASE_PATHWAY                 0.000001
# SIG_PIP3_SIGNALING_IN_CARDIAC_MYOCTES                0.000001
# KEGG_JAK_STAT_SIGNALING_PATHWAY                      0.000001
# KEGG_FOCAL_ADHESION                                  0.000001
# REACTOME_REGULATION_OF_INSULIN_SECRETION             0.000006
# KEGG_RIG_I_LIKE_RECEPTOR_SIGNALING_PATHWAY           0.000006
# REACTOME_PI3K_AKT_SIGNALLING                         0.000006
# REACTOME_TRKA_SIGNALLING_FROM_THE_PLASMA_MEMBRANE    0.000008
# BIOCARTA_IGF1MTOR_PATHWAY                            0.000008
# ST_INTEGRIN_SIGNALING_PATHWAY                        0.000011
# ...
# BIOCARTA_AKAP13_PATHWAY                                     1
# BIOCARTA_FEEDER_PATHWAY                                     1
# BIOCARTA_IL22BP_PATHWAY                                     1
# BIOCARTA_MONOCYTE_PATHWAY                                   1
# BIOCARTA_P53HYPOXIA_PATHWAY                                 1
# BIOCARTA_SODD_PATHWAY                                       1
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS                    1
# REACTOME_CALCITONIN_LIKE_LIGAND_RECEPTORS                   1
# REACTOME_CTLA4_INHIBITORY_SIGNALING                         1
# REACTOME_DARPP32_EVENTS                                     1
# REACTOME_IONOTROPIC_ACTIVITY_OF_KAINATE_RECEPTORS           1
# REACTOME_REGULATION_OF_PYRUVATE_DEHYDROGENASE_COMPLEX       1
# REACTOME_SEMA3A_PAK_DEPENDENT_AXON_REPULSION                1
# REACTOME_TRANSLOCATION_OF_ZAP70_TO_IMMUNOLOGICAL_SYNAPSE    1
# ST_TUMOR_NECROSIS_FACTOR_PATHWAY                            1
# Name: triple_neg, Length: 831

# %%
from Processing.Clinical import *

# %%
REAL_VARIABLES = ['AMAR','rate','age']
BINARY_VARIABLES = ['gender', 'therapy', 'radiation', 'triple_neg', 'triple_pos',
                    'ER_pos','PR_pos','her2_pos', 'lymphnode_n0n1', 'tumor_t1t2',
                    'post_menopause']
SURVIVAL_TESTS = {'survival' : {'event_var' : 'deceased', 'time_var' : 'days', 
                                'covariates' : ['age', 'rate']},
                  'event_free_survival' : {'event_var' : 'event', 
                                           'time_var' : 'event_free_survival', 
                                           'covariates' : ['age', 'rate']}
                  }

# %%
def run_clinical_bool(cancer, data_path, gene_sets, data_type='mutation'):
    '''
    Runs clinical tests for boolean type data (mutation, amplification, 
    or deletion).
    '''
    stddata_path = data_path.replace('analyses', 'stddata')
    clinical = read_csv(stddata_path + 'Clinical/compiled.csv', index_col=0)
    try:
        meth_age, amar = get_age_signal(stddata_path, clinical)
        clinical['meth_age'] = meth_age
        clinical['AMAR'] = amar
    except:
        pass  #Probably because there is not a 450k chip for the cancer
    patients = clinical[['days','deceased']].dropna().index
    if data_type == 'mutation':
        hit_matrix, _ = get_mutation_matrix(cancer, data_path)
    elif data_type in ['amplification', 'deletion']:
        hit_matrix, lesion_matrix = get_cna_matrix(data_path, data_type)
    
    single_matrix = lesion_matrix if data_type == 'amplification' else hit_matrix
    single_matrix = single_matrix.clip_upper(1.)
    clinical['rate'] = log(single_matrix.sum(0))
    tests = get_tests_bool(clinical, SURVIVAL_TESTS, REAL_VARIABLES, BINARY_VARIABLES)
    gene_counts = sort(single_matrix.sum(1))
    good_genes = gene_counts[gene_counts > MIN_NUM_HITS].index[:500]
    p_genes, q_genes = run_tests(tests, single_matrix.ix[good_genes])
    
    clinical['rate'] = log(hit_matrix.sum(0))
    meta_matrix = build_meta_matrix(gene_sets, hit_matrix, 
                                    setFilter=lambda s: s.clip_upper(1))
    tests = get_tests_bool(clinical, SURVIVAL_TESTS, REAL_VARIABLES, BINARY_VARIABLES)
    p_pathways, q_pathways = run_tests(tests, meta_matrix.clip_upper(1.)) 
    return locals()

# %%
d = run_clinical_bool('BRCA', data_path, gene_sets, data_type='mutation')

# %%
from pandas import read_csv, read_table

# %%
clinical = read_csv(stddata_path + 'Clinical/compiled.csv', index_col=0)
try:
    meth_age, amar = get_age_signal(stddata_path, clinical)
    clinical['meth_age'] = meth_age
    clinical['AMAR'] = amar
except:
    pass  #Probably because there is not a 450k chip for the cancer

# %%
#patients = array(clinical[['days','deceased']].dropna().index)
stddata_path = data_path.replace('analyses', 'stddata')

# %%
hit_matrix, _ = get_mutation_matrix('BRCA', data_path)
clinical['rate'] = log(hit_matrix.sum(0))
tests = get_tests_bool(clinical, SURVIVAL_TESTS, REAL_VARIABLES, BINARY_VARIABLES)

# %%
gene_counts = sort(hit_matrix.sum(1))
good_genes = gene_counts[gene_counts > MIN_NUM_HITS].index[:500]
p_genes, q_genes = run_tests(tests, hit_matrix.ix[good_genes].clip_upper(1.))

# %%
q_genes.sort(columns='event_free_survival').head(10)
# Out:
#         tumor_t1t2  lymphnode_n0n1  event_free_survival  triple_neg  gender       age    PR_pos    ER_pos  triple_pos      rate  post_menopause      AMAR  survival  her2_pos
# SSPO      1.000000         1.00000             0.028754    0.881131       1  0.893222  0.593597  0.936219           1  0.221272        0.699517  0.845592         1  1.000000
# CBLB      0.987764         0.97464             0.465696    1.000000       1  0.893222  0.932423  1.000000           1  0.045361        0.903270  0.862644         1  0.833496
# DNAH11    1.000000         1.00000             0.465696    0.417500       1  0.999324  0.320597  0.557213           1  0.000003        0.997290  0.845592         1  0.507130
# ERBB3     1.000000         1.00000             0.465696    1.000000       1  0.893222  0.320597  0.557213           1  0.000160        0.903270  0.845592         1  0.507130
# OBSCN     1.000000         1.00000             0.465696    0.305170       1  0.906221  0.320597  0.557213           1  0.073357        0.997290  0.845592         1  1.000000
# ABCA13    0.987764         1.00000             0.772281    1.000000       1  0.893222  1.000000  0.636936           1  0.128019        1.000000  0.845592         1  1.000000
# UTRN      1.000000         1.00000             0.911188    1.000000       1  0.893222  0.407094  0.557213           1  0.000872        0.903270  0.845592         1  0.833496
# FLNC      1.000000         1.00000             0.911188    1.000000       1  0.775515  0.654769  0.557213           1  0.000483        0.903270  0.845592         1  0.874642
# F5        1.000000         1.00000             0.911188    0.111523       1  0.997897  0.320597  0.249492           1  0.002609        0.997290  0.845592         1  1.000000
# PCDH19    1.000000         1.00000             0.999998    1.000000       1  0.997897  0.932423  0.928132           1  0.122322        0.903270  0.845592         1  1.000000

# %%
clinical['rate'] = log(hit_matrix.sum(0))
meta_matrix = build_meta_matrix(gene_sets, hit_matrix, 
                                   setFilter=lambda s: s.clip_upper(1))
tests = get_tests_bool(clinical, SURVIVAL_TESTS, REAL_VARIABLES, BINARY_VARIABLES)
p_pathways, q_pathways = run_tests(tests, meta_matrix)

# %%
no_p53 = [n for n,s in gene_sets.iteritems() if 'TP53' not in s]

# %%
q_pathways.ix[no_p53].sort(columns='rate').head(10)
# Out:
#                                                      tumor_t1t2  lymphnode_n0n1  event_free_survival  triple_neg  gender       age    PR_pos    ER_pos  triple_pos          rate  post_menopause      AMAR  survival  her2_pos
# REACTOME_OLFACTORY_SIGNALING_PATHWAY                          1        0.774564             0.999996    0.005486       1  0.534304  0.000215  0.000613           1  1.285506e-26        0.590001  0.935562         1  0.914188
# KEGG_OLFACTORY_TRANSDUCTION                                   1        0.849140             0.999996    0.006943       1  0.639402  0.000013  0.000161           1  7.651117e-26        0.590001  0.975295         1  0.954980
# REACTOME_CELL_CYCLE_MITOTIC                                   1        0.752561             0.999996    0.246576       1  0.623896  0.001834  0.030884           1  8.425170e-26        0.890558  0.975295         1  0.954980
# REACTOME_MUSCLE_CONTRACTION                                   1        0.752561             0.999996    0.008729       1  0.608655  0.007925  0.035260           1  2.139467e-22        0.708579  0.857320         1  1.000000
# REACTOME_PLATELET_DEGRANULATION                               1        0.752561             0.999996    0.029274       1  0.800652  0.134397  0.069648           1  1.358266e-21        0.934936  0.935562         1  0.954980
# KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION                   1        0.965131             0.999996    0.075797       1  0.930191  0.023075  0.007096           1  6.141022e-21        0.933925  0.853638         1  0.881805
# REACTOME_TRANSMEMBRANE_TRANSPORT_OF_SMALL_MOLECULES           1        1.000000             0.999996    0.070979       1  0.229438  0.015605  0.036159           1  2.294445e-19        0.590001  0.994348         1  0.723224
# KEGG_NEUROACTIVE_LIGAND_RECEPTOR_INTERACTION                  1        1.000000             0.999996    0.128067       1  0.753199  0.043686  0.112584           1  4.078552e-19        0.722380  0.965761         1  0.794303
# REACTOME_RHO_GTPASE_CYCLE                                     1        0.890298             0.999996    0.017206       1  0.805156  0.006024  0.013757           1  1.339097e-18        0.887844  0.746571         1  0.831938
# REACTOME_METABOLISM_OF_LIPIDS_AND_LIPOPROTEINS                1        0.950778             0.999996    0.098607       1  0.534314  0.000854  0.038049           1  2.461684e-18        1.000000  0.857320         1  1.000000

# %%
scatter(*clinical[['days','event_free_survival']].as_matrix().T)
